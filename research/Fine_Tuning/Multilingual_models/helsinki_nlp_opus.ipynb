# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline

# Load translation models
model_en_hi = "Helsinki-NLP/opus-mt-en-hi"  # English → Hindi
model_hi_en = "Helsinki-NLP/opus-mt-hi-en"  # Hindi → English

tokenizer_en_hi = AutoTokenizer.from_pretrained(model_en_hi)
translator_en_hi = pipeline("translation", model=model_en_hi, tokenizer=tokenizer_en_hi)

tokenizer_hi_en = AutoTokenizer.from_pretrained(model_hi_en)
translator_hi_en = pipeline("translation", model=model_hi_en, tokenizer=tokenizer_hi_en)

# File paths
input_file = "/content/gemma-2b-it_recipes.txt"  # Change this to your input file path
translated_file = "translated_recipe_hi.txt"
back_translated_file = "back_translated_recipe.txt"

# Read the English recipes
with open(input_file, "r", encoding="utf-8") as f:
    recipes = f.readlines()

# Translate, back-translate, and save results
translated_recipes = []
back_translated_recipes = []

for recipe in recipes:
    if recipe.strip():  # Skip empty lines
        # Step 1: English → Hindi
        translated = translator_en_hi(recipe.strip())[0]['translation_text']
        translated_recipes.append(translated)

        # Step 2: Hindi → English (Back Translation)
        back_translated = translator_hi_en(translated)[0]['translation_text']
        back_translated_recipes.append(back_translated)

        # Print for monitoring
        print(f"\nOriginal: {recipe.strip()}")
        print(f"Translated (EN → HI): {translated}")
        print(f"Back-Translated (HI → EN): {back_translated}")

# Save translated Hindi recipes
with open(translated_file, "w", encoding="utf-8") as f:
    f.write("\n".join(translated_recipes))

# Save back-translated English recipes
with open(back_translated_file, "w", encoding="utf-8") as f:
    f.write("\n".join(back_translated_recipes))

print(f"\nTranslation and back-translation completed! Files saved:\n- Hindi Recipes: '{translated_file}'\n- Back-Translated English Recipes: '{back_translated_file}'")
# Out:
# Device set to use cpu
# Device set to use cpu
# Original: Recipe 1:
# Translated (EN → HI): रेसिपि 1:
# Back-Translated (HI → EN): Recipe 1:
#
# Original: **The Dish:**
# Translated (EN → HI): ** दिश:
# Back-Translated (HI → EN): ** Dish:
#
# Original: **Spicy Carrot Bread with Strawberry Glaze**
# Translated (EN → HI): ** ट्रॉर्मरी ग्लाइडर के साथ रोटी
# Back-Translated (HI → EN): ** Bread with Tramary Glauder
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 loaf (12 slices) bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 रोटी (12 स्लाइस) की रोटी, जो 1/2 मोटी स्लाइसों में विभाजित थी
# Back-Translated (HI → EN): * 1 loaf (12's) bread, which was divided into 1/2 thick slices
#
# Original: * 1 large carrot, diced
# Translated (EN → HI): * 1 बड़ा काररोट, पॉड
# Back-Translated (HI → EN): * 1 Big Carroot, Pod
#
# Original: * 1/2 cup chocolate chips
# Translated (EN → HI): * 1/2 कप चिप
# Back-Translated (HI → EN): * 1/2 cup chip
#
# Original: * 1 tablespoon flour
# Translated (EN → HI): * 1 मेज़ के मैदा
# Back-Translated (HI → EN): * Let us take a closer look at the example of the apostle Paul, who wrote: "Let us consider one another to incite to love and fine works, not forsaking the gathering of ourselves together, as some have the custom, but encouraging one another, and all the more so as you behold the day drawing near. "
#
# Original: * 1 tablespoon green_beans, chopped
# Translated (EN → HI): * 1 मेज़ें हरे रंग की हैं ।
# Back-Translated (HI → EN): * 1 tables are green.
#
# Original: * 1 tablespoon ground_beef
# Translated (EN → HI): * 1 मेज़ोपोल्फ (_b)
# Back-Translated (HI → EN): * 1 table _bophs
#
# Original: * 1/2 lime, juiced
# Translated (EN → HI): * 1/2 पकाई, रसद
# Back-Translated (HI → EN): * 1/2 cooking, cheese
#
# Original: * 1/4 cup strawberries, diced
# Translated (EN → HI): * 1/4 कपीबर, पॉग्ड
# Back-Translated (HI → EN): * observed: "It's all right, we're going to have to go to the police station.
#
# Original: * 1 tablespoon sugars
# Translated (EN → HI): [ पेज 1 पर बक्स / तसवीर]
# Back-Translated (HI → EN): [ Box / Picture on page 18]
#
# Original: * 1 tablespoon tomato paste
# Translated (EN → HI): * 1 रापोटेप की पेस्ट
# Back-Translated (HI → EN): * 1 Ruppox circum
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
# Back-Translated (HI → EN): 1.75 degrees to F (199 degrees C).
#
# Original: 2. In a large skillet, cook the carrot and green_beans over medium heat until tender and slightly browned.
# Translated (EN → HI): 2 बड़े कौशल के साथ, मिरोचट और हरा हरे रंग का बना लीजिए, जब तक कि गर्मी कम न हो जाए और कम - से - कम भूरे रंग के हो जाएँ ।
# Back-Translated (HI → EN): 2 With great skill, make a greener and green color until the heat is low and at least brown.
#
# Original: 3. Add the ground_beef to the skillet and cook until browned.
# Translated (EN → HI): इसके अलावा, उन्हें अच्छी तरह से तैयार किया जाता है ।
# Back-Translated (HI → EN): In addition, they are prepared well.
#
# Original: 4. Add the lime juice, strawberries, and sugars to the skillet and simmer for 5 minutes.
# Translated (EN → HI): इसके अलावा, यह रस रस, स्टीबर और चीनी को 5 मिनट तक इस्तेमाल किया जाता है ।
# Back-Translated (HI → EN): In addition, the juice is used for 5 minutes.
#
# Original: 5. Spread the mixture evenly over the bread slices.
# Translated (EN → HI): 5 रोटी के टुकड़े के ऊपर भी मिश्रण का प्रचार कीजिए ।
# Back-Translated (HI → EN): 5 Also preach the mixture over the pieces of bread.
#
# Original: 6. Bake for 10 minutes, or until the bread is golden brown and the filling is cooked through.
# Translated (EN → HI): या जब तक रोटी सोने के भूरे भूरे भूरे रंग की होती है और उसे अच्छी तरह तैयार किया जाता है ।
# Back-Translated (HI → EN): Or as long as bread is of gold, brown brown and well - prepared.
#
# Original: 7. Serve with a drizzle of strawberry glaze.
# Translated (EN → HI): 7 स्टॉंबर फ़ॉयर की फुहार के साथ सेवा कीजिए ।
# Back-Translated (HI → EN): 7 Serve with the drizzle of the St. Pauleberfier.
#
# Original: **Tips:**
# Translated (EN → HI): ** एजेंट:
# Back-Translated (HI → EN): ** Agent:
#
# Original: * For a richer bread, use high-quality bread.
# Translated (EN → HI): * एक बड़ी रोटी के लिए, बड़ी मात्रा में रोटी का इस्तेमाल कीजिए ।
# Back-Translated (HI → EN): * For a large loaf of bread, use a large quantity of bread.
#
# Original: * To make a gluten-free bread, use gluten-free flour.
# Translated (EN → HI): * एक खाली रोटी बनाने के लिए, Galln- fon- फ्री मैदा इस्तेमाल करें.
# Back-Translated (HI → EN): * To create an empty bread, use the Galln-fone-free fine.
#
# Original: * Serve with a side of your favorite dipping sauce, such as ranch dressing or pesto.
# Translated (EN → HI): * अपने पसंदीदा पानी के एक तरफ रहकर सेवा कीजिए, जैसे कपड़े धोना या पेशाब करना ।
# Back-Translated (HI → EN): * Serve on the side of your favorite water, such as a washing of clothes or a piss.
#
# Original: Recipe 2:
# Translated (EN → HI): रेसिपि 2:
# Back-Translated (HI → EN): Recipe 2:
#
# Original: **Beef and Vegetable Stir-Fry with Sweet and Spicy Glaze**
# Translated (EN → HI): ** बेटफ और वेटर्मर- फ़िटरी के साथ मीठा और स्पीज के साथ
# Back-Translated (HI → EN): ** BRIF and Wetor-Siter with sweet and snip.
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1 pound beef, thinly sliced
# Translated (EN → HI): * 1 किलो केक, पतली बालों का टुकड़ा
# Back-Translated (HI → EN): * 1 pound [16 kg] of fine hair
#
# Original: * 1 tablespoon chopped onion, diced
# Translated (EN → HI): * 1 पॉंडोन पर कब्ज़ा किया गया, ओनेड
# Back-Translated (HI → EN): * 1 Pondon was captured, Onidad
#
# Original: * 1 tablespoon chopped carrots, diced
# Translated (EN → HI): * 1 मेज़ोनेड्‌स, पॉलैंड
# Back-Translated (HI → EN): * 1 circulars, Poland
#
# Original: * 1 tablespoon chopped chicken, diced
# Translated (EN → HI): * 1 मेज़ों में मुर्गी का गोश्‍त, ओनेड
# Back-Translated (HI → EN): * The meat of chicken in 1 tables, Oned
#
# Original: * 1 tablespoon chopped ground beef
# Translated (EN → HI): * 1 मेज़ों से ज़मीन के टुकड़े
# Back-Translated (HI → EN): * Debates on Earth From 1 Table
#
# Original: * 1 tablespoon chopped spinach
# Translated (EN → HI): * 1 मेज़ों के छेदे की घंटी
# Back-Translated (HI → EN): * 1 table hole
#
# Original: * 1 tablespoon chopped strawberries
# Translated (EN → HI): * 1 मेज़ों की स्टॉथियाँ
# Back-Translated (HI → EN): * 1 tables of tables
#
# Original: * 1 tablespoon sugar
# Translated (EN → HI): * 1 मेज़ोटोन चीनी
# Back-Translated (HI → EN): * 1 Mazotone Chinese
#
# Original: * 1 tablespoon soy sauce
# Translated (EN → HI): * 1 मेज़ोटोन सोपोन
# Back-Translated (HI → EN): * 1 Coro Soponson
#
# Original: * 1 tablespoon honey
# Translated (EN → HI): [ पेज 1 पर बक्स]
# Back-Translated (HI → EN): [ Box on page 18]
#
# Original: * 1 tablespoon sesame oil
# Translated (EN → HI): * 1 मेज़ोलीन तेल
# Back-Translated (HI → EN): * 1 Mazele oil
#
# Original: * 1 tablespoon ground black pepper
# Translated (EN → HI): * 1 मैक्लोटोन जमीन काली मिर्च
# Back-Translated (HI → EN): * 1 Maciton ground black chirping
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Heat the olive oil in a large skillet or wok over medium-high heat.
# Translated (EN → HI): 1. जलपाई का तेल एक बड़े कौशल में या मध्यम गर्मी में रखता है.
# Back-Translated (HI → EN): 1. olive oil keeps in a large skill or in the hot heat.
#
# Original: 2. Add the beef and cook until browned on all sides.
# Translated (EN → HI): 2 मांस और पकाओ... ... सभी पक्ष में भूरे रंग तक.
# Back-Translated (HI → EN): 2 flesh and boil until the brown color in all favor.
#
# Original: 3. Add the onion, carrots, and chicken to the skillet and cook until tender and slightly browned.
# Translated (EN → HI): इसके अलावा, जब तक कि छोटे - छोटे भूरे - भूरे और भूरे रंग के हो जाते हैं, मुर्गी और मुर्गी का स्वाद बढ़ जाता है ।
# Back-Translated (HI → EN): Furthermore, as little brown - brown and brown - colored, chicken and chicken increase.
#
# Original: 4. Add the ground beef, spinach, and strawberries to the skillet and cook until heated through.
# Translated (EN → HI): इसके अलावा, इन्हें गरम रखने के लिए इन्हें अच्छी तरह से तैयार किया जाता है ।
# Back-Translated (HI → EN): In addition, they are designed to keep warm.
#
# Original: 5. In a small bowl, whisk together the sugar, soy sauce, honey, and sesame oil.
# Translated (EN → HI): 5 एक छोटे कटोरे में चीनी, सोकी, मधु, और उसी तरह का तेल इकट्ठे किया जाता है ।
# Back-Translated (HI → EN): 5 One cup contains sugar, soybe, honey, and similar oil.
#
# Original: 6. Add the sauce to the skillet and cook until heated through.
# Translated (EN → HI): जब तक कि गरम नहीं हो जाता, तब तक काम करने के लिए काम कीजिए ।
# Back-Translated (HI → EN): Work until it is hot.
#
# Original: 7. Serve over rice and garnish with fresh cilantro.
# Translated (EN → HI): 7 चावल और लचीली के साथ मिलकर काम कीजिए ।
# Back-Translated (HI → EN): 7 Work together with rice and beans.
#
# Original: Recipe 3:
# Translated (EN → HI): रेसिपि ३:
# Back-Translated (HI → EN): Recipe 3:
#
# Original: **Beef and Green Bean Stuffed Sweet Potatoes**
# Translated (EN → HI): ** बेनेफ और हरा बीज़ेन में मीठा पानी भरा हुआ माल
# Back-Translated (HI → EN): ** Sweet water full of goods in Benef and Green Bezen
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 2 tablespoons of butter
# Translated (EN → HI): * मक्खन की 2 पटियाएँ
# Back-Translated (HI → EN): * 2 tables of butter
#
# Original: * 1 large egg, beaten
# Translated (EN → HI): * 1 बड़े अंडे, पीटा
# Back-Translated (HI → EN): * 1 large eggs, strike
#
# Original: * 1/2 cup of chopped green beans
# Translated (EN → HI): * 1/2 कप हरीकेन का कप
# Back-Translated (HI → EN): * 1/2 cups cup
#
# Original: * 1 pound of ground beef
# Translated (EN → HI): * ज़मीन के एक पाउंड
# Back-Translated (HI → EN): * A pound of land
#
# Original: * 1/2 cup of chopped mushrooms
# Translated (EN → HI): * 1/2 कप में बड़े - बड़े मशगूल होते हैं
# Back-Translated (HI → EN): * The 1/2 cup contains a large caliber
#
# Original: * 1/4 cup of chopped onions
# Translated (EN → HI): [ पेज 29 पर बड़े अक्षरों में लेख की खास बात]
# Back-Translated (HI → EN): [ Blurb on page 29]
#
# Original: * 1/4 cup of chopped spinach
# Translated (EN → HI): [ पेज 29 पर बड़े अक्षरों में लेख की खास बात]
# Back-Translated (HI → EN): [ Blurb on page 29]
#
# Original: * 1/4 cup of chopped strawberries
# Translated (EN → HI): * 1/4 पन्‍ने की झीलों का कप
# Back-Translated (HI → EN): * refuse a cup of lakes of one quarter page
#
# Original: * 1/2 cup of heavy cream
# Translated (EN → HI): * 1/2 कप जो भारी है
# Back-Translated (HI → EN): * 1/2 cup that's heavy
#
# Original: * 1 tablespoon of chopped fresh parsley
# Translated (EN → HI): * 1 नए सिरे के क्लैम्पली की पटियाएँ
# Back-Translated (HI → EN): * 1 Tables of Clample
#
# Original: * Salt and pepper to taste
# Translated (EN → HI): * नमक और काली मिर्च का स्वाद लेने के लिए
# Back-Translated (HI → EN): * To taste salt and pepper
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
# Back-Translated (HI → EN): 1.75 degrees to F (199 degrees C).
#
# Original: 2. In a large skillet over medium heat, melt the butter.
# Translated (EN → HI): 2. मीडिया गर्मी पर एक बड़े कौशल में, मक्खन पिघल जाता है.
# Back-Translated (HI → EN): 2. In a great skill on the media heat, butter melts.
#
# Original: 3. Add the egg and cook until cooked through.
# Translated (EN → HI): 3 अंडे और खाना दीजिए, जब तक कि उसे पका न हो ।
# Back-Translated (HI → EN): 3 Give eggs and food until it is cooked.
#
# Original: 4. Add the green beans, mushrooms, onions, and spinach to the skillet and cook until tender.
# Translated (EN → HI): इसके अलावा, ये फल - फूल - फूलकर छोटे - छोटे पौधे भी तैयार करते हैं ।
# Back-Translated (HI → EN): In addition, they thrive and prepare small plants.
#
# Original: 5. Add the ground beef to the skillet and cook until browned.
# Translated (EN → HI): 5 भूरे रंग के जीव को अच्छी तरह पकाइए और अच्छी तरह पकाइए ।
# Back-Translated (HI → EN): Make sure you cook and thoroughly cook 5 brown meats.
#
# Original: 6. Add the heavy cream, parsley, salt, and pepper to the skillet and simmer for 5 minutes.
# Translated (EN → HI): 6. भारी आइसक्रीम, पर्सली, नमक और काली मिर्च को 5 मिनट के लिए इस्तेमाल करते हैं ।
# Back-Translated (HI → EN): 6. heavy ice cream, purses, salt, and black beaks use for 5 minutes.
#
# Original: 7. Transfer the filling to a baking dish.
# Translated (EN → HI): 7. खाना पकाने के लिए तैयार कीजिए ।
# Back-Translated (HI → EN): 7. Prepare for cooking.
#
# Original: 8. Top with the sweet potatoes and bake for 20 minutes, or until the potatoes are golden brown and the filling is heated through.
# Translated (EN → HI): यह बहुत ही मीठा आलू है और 20 मिनट तक पका रहता है, या जब तक आलू सुनहरे भूरे भूरे रंग की होती है और उसे गरम नहीं किया जाता ।
# Back-Translated (HI → EN): It is very sweet and is cooked for 20 minutes or until it has a golden brown color and is not heated.
#
# Original: 9. Serve immediately.
# Translated (EN → HI): 9. तुरंत सेवा कीजिए ।
# Back-Translated (HI → EN): 9. Serve immediately.
#
# Original: Recipe 4:
# Translated (EN → HI): रेसिपि 4:
# Back-Translated (HI → EN): Recipe 4:
#
# Original: **Blueberry Bread with Sweet Potato Filling**
# Translated (EN → HI): ** मेलिया भरने के साथ ब्लूबेरी रोटी
# Back-Translated (HI → EN): ** Blueberries bread with fill
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 loaf (1 pound) white bread, sliced into 1-inch thick slices
# Translated (EN → HI): * 1 रोटी (1 किलो) सफेद रोटी, जो 1 इंच मोटी होती है
# Back-Translated (HI → EN): * 1 loaf of bread (1 kg) white bread, thick with 1 inch [3 cm] thick
#
# Original: * 1 cup blueberries
# Translated (EN → HI): * 1 कपीबर
# Back-Translated (HI → EN): * 1 cuprs
#
# Original: * 1/2 cup sugar
# Translated (EN → HI): * 1/2 कप चीनी
# Back-Translated (HI → EN): * 1/2 cup sugar
#
# Original: * 1/4 teaspoon salt
# Translated (EN → HI): * 1/4 चाय - नमक
# Back-Translated (HI → EN): * 1/4 Tea - Salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1/2 teaspoon vanilla extract
# Translated (EN → HI): * 1/2 चाय के पौधों का पता लगाने के लिए
# Back-Translated (HI → EN): * 1/2 to locate plants of tea
#
# Original: * 1/4 cup chopped onion
# Translated (EN → HI): [ पेज 29 पर तसवीर]
# Back-Translated (HI → EN): [ Picture on page 29]
#
# Original: * 1/2 cup chopped spinach
# Translated (EN → HI): * 1/2 कप केक
# Back-Translated (HI → EN): * 1/2 cup cake
#
# Original: * 1/4 cup chopped strawberries
# Translated (EN → HI): * 1/4 कप्डेदार स्टीबर
# Back-Translated (HI → EN): * point out, however, that this is the beginning of the 20th century and that it is the beginning of the 20th century of the 20th century.
#
# Original: * 1/4 cup chocolate chips
# Translated (EN → HI): * 1/4 कप चॉकलेट्स
# Back-Translated (HI → EN): * reachable cups of chocolates
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
# Back-Translated (HI → EN): 1.75 degrees to F (199 degrees C).
#
# Original: 2. In a large bowl, combine the bread slices, blueberries, sugar, salt, and black pepper.
# Translated (EN → HI): 2 बड़े - बड़े कटोरे में, रोटी के टुकड़े, नीले रंग की घास, चीनी, नमक और काली मिर्च साथ दीजिए ।
# Back-Translated (HI → EN): 2 In large cup, fill in bread, along with blue grass, sugar, salt, and pepper.
#
# Original: 3. In a separate bowl, whisk together the olive oil, vanilla extract, onion, spinach, and strawberries.
# Translated (EN → HI): एक अलग कटोरे में जैतून का तेल, वैनीला का फलना - फूलना, खेती - बाड़ी करना और स्टूचियाँ साथ - साथ सुखाया जाता है ।
# Back-Translated (HI → EN): A separate cup contains olive oil, vanilla beans, farming, and farmers.
#
# Original: 4. Add the wet ingredients to the dry ingredients and stir until just combined. Do not overmix.
# Translated (EN → HI): 4 सूखे पदार्थों को जोड़िए और उन्हें हिलाइए, जब तक कि सिर्फ एक - दूसरे से जुदा न हो जाए ।
# Back-Translated (HI → EN): 4 mix and shake food, until there is only one separation.
#
# Original: 5. Pour the batter into a greased 9x13-inch baking dish.
# Translated (EN → HI): 5. तेलित 9x13-घन खाना में बल्ले.
# Back-Translated (HI → EN): 5.l through 9x13-hut.
#
# Original: 6. Bake for 30-35 minutes, or until the bread is golden brown and the filling is set.
# Translated (EN → HI): 6. 3035 मिनट के लिए बकक, या जब तक रोटी सोने के भूरे रंग की होती है और भर दिया जाता है.
# Back-Translated (HI → EN): 6.3035 minutes, or while the bread is brown and full.
#
# Original: 7. Serve warm with a scoop of vanilla ice cream or whipped cream.
# Translated (EN → HI): 7 खजूर की आइसक्रीम से गर्म रहिए ।
# Back-Translated (HI → EN): 7 Keep warm with palm - nut ice cream.
#
# Original: Recipe 5:
# Translated (EN → HI): रेसिपि 5:
# Back-Translated (HI → EN): Recipe 5:
#
# Original: **Chicken and Sweet Potato Hash with Chocolate Glaze**
# Translated (EN → HI): ** Cokiken और मीठा आलू हैकलेटिन के साथ
# Back-Translated (HI → EN): ** Corkiken and sweet beautin
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 loaf of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 रोटी का एक टुकड़ा, जो 1/2-inch मोटी स्लाइस में काटा गया था
# Back-Translated (HI → EN): * 1 piece of bread, which was cut into the 1/2-inch thick slice
#
# Original: * 1/2 pound of chicken breast, cut into 1-inch cubes
# Translated (EN → HI): * 1/2 किलो मुर्गी स्तन, 1-inch के घनों में कटौती
# Back-Translated (HI → EN): * 1/2 pound of chicken cuts to breast, 1-10 pounds
#
# Original: * 1/4 cup of grated cheese
# Translated (EN → HI): * सन्‌ 1/4 में बनायी गयी पनीर का कप
# Back-Translated (HI → EN): * The cheese cup made in Vienna
#
# Original: * 1/4 cup of chopped chocolate
# Translated (EN → HI): * 1/4 कप जो चॉकलेट का कप है
# Back-Translated (HI → EN): * point out that it's a chocolate cup.
#
# Original: * 2 large eggs, beaten
# Translated (EN → HI): * 2 बड़े अंडे, पीटा
# Back-Translated (HI → EN): * 2 Big eggs, strike
#
# Original: * 1/2 cup of chopped potato
# Translated (EN → HI): * 1/2 कप ।
# Back-Translated (HI → EN): * 1/2 cups.
#
# Original: * 1/4 cup of chopped strawberries
# Translated (EN → HI): * 1/4 पन्‍ने की झीलों का कप
# Back-Translated (HI → EN): * refuse a cup of lakes of one quarter page
#
# Original: * 1 tablespoon of sugar
# Translated (EN → HI): * 1 चीनी की पटियाएँ
# Back-Translated (HI → EN): * 1 Chinese tablets
#
# Original: * 1 tablespoon of sweet potato, mashed and cooled
# Translated (EN → HI): * 1 मीठे पानी की पटियाएँ, साफ - सुथरा और ठंडा
# Back-Translated (HI → EN): * 1 Sweet water tablets, clean and cold
#
# Original: * 1 tablespoon of melted chocolate
# Translated (EN → HI): * 1 चॉकलेट की पटियाएँ
# Back-Translated (HI → EN): * 1 chocolate tablets
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
# Back-Translated (HI → EN): 1.75 degrees to F (199 degrees C).
#
# Original: 2. Toast the bread slices lightly on both sides until golden brown.
# Translated (EN → HI): 2, सोने के भूरे रंग के होते तक रोटी के टुकड़े - टुकड़े को हलकी बात समझा जाता है ।
# Back-Translated (HI → EN): 2, through the brown color of gold, bread is considered to be light.
#
# Original: 3. In a large skillet over medium heat, cook the chicken for 5-7 minutes per side, or until cooked through.
# Translated (EN → HI): 3. मीडिया की गर्मी के दौरान एक बड़े कौशल में, मुर्गी को हर तरफ से 5 मिनट के लिए पकाओ, या जब तक कि पानी भर न जाए.
# Back-Translated (HI → EN): In a great skill in the heat of the media, cook the chicken from every side for 5 minutes, or until the water is filled.
#
# Original: 4. Add the cheese, chocolate, eggs, potato, and strawberries to a baking dish.
# Translated (EN → HI): इसके अलावा, पनीर, चॉकलेट, अंडे, अंडे, और स्टूबरों को एक स्वादिष्ट व्यंजन में जोड़ दीजिए ।
# Back-Translated (HI → EN): In addition, add cheese, chocolate, eggs, eggs, and students to a delicious meal.
#
# Original: 5. Pour the chicken over the topping.
# Translated (EN → HI): 5. मुर्गी को ऊपर की ओर फैलाओ.
# Back-Translated (HI → EN): proclaim the 5.E to the chicken up.
#
# Original: 6. Bake for 20-25 minutes, or until the chicken is cooked through and the vegetables are tender.
# Translated (EN → HI): 6. 20 25 मिनट तक , या जब तक मुर्गी को पकाकर पकाया जाता है और सब्ज़ियाँ कोमल होती हैं.
# Back-Translated (HI → EN): 6.20 minutes, or as long as the chicken is cooked and the vegetables are gentle.
#
# Original: 7. Serve with a drizzle of chocolate glaze.
# Translated (EN → HI): 7 चॉकलेट ग्रीप की फुहार के साथ सेवा कीजिए ।
# Back-Translated (HI → EN): 7 Serve With the Drizzle of chocolate Grep.
#
# Original: Recipe 6:
# Translated (EN → HI): रेसिपि 6:
# Back-Translated (HI → EN): Recipe 6:
#
# Original: **Blueberry Chicken with Green Bean Mash**
# Translated (EN → HI): ** हरे बेसैन के साथ ब्लूबेरी चाउन
# Back-Translated (HI → EN): ** Blueberi keys with green base
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 pound boneless, skinless chicken breasts, cut into 1-inch pieces
# Translated (EN → HI): * 1 किलो हड्डी, त्वचाहीन मुर्गी स्तन, 1 बांच के टुकड़ों में कटौती
# Back-Translated (HI → EN): * One pound of bone, skinless chicken cuts in pieces of 1st glass
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चायदार नमक
# Back-Translated (HI → EN): * 1/2 teat salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: * 1 cup blueberries
# Translated (EN → HI): * 1 कपीबर
# Back-Translated (HI → EN): * 1 cuprs
#
# Original: * 1 tablespoon lemon juice
# Translated (EN → HI): * 1 मेज़ के रस
# Back-Translated (HI → EN): * 1 table juice
#
# Original: * 1 tablespoon butter
# Translated (EN → HI): * 1 मेज़ों के मक्खन
# Back-Translated (HI → EN): * The butter of 1 tables
#
# Original: * 1 tablespoon flour
# Translated (EN → HI): * 1 मेज़ के मैदा
# Back-Translated (HI → EN): * Let us take a closer look at the example of the apostle Paul, who wrote: "Let us consider one another to incite to love and fine works, not forsaking the gathering of ourselves together, as some have the custom, but encouraging one another, and all the more so as you behold the day drawing near. "
#
# Original: * 1/2 cup green beans, trimmed and cut into 1-inch pieces
# Translated (EN → HI): * 1/2 कप हरा बीन्स, सिलिना और 1 इंच काट
# Back-Translated (HI → EN): * 1/2 cups green beans, Silinas, and 1 cut
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चायदार नमक
# Back-Translated (HI → EN): * 1/2 teat salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 400 degrees F (200 degrees C).
# Translated (EN → HI): 1. प्रीफनेक्यूज से 400 डिग्री F (200 डिग्री सी.)
# Back-Translated (HI → EN): 1.400 degrees (200 degrees C).
#
# Original: 2. In a large skillet over medium heat, heat olive oil. Season chicken with salt and pepper. Cook chicken for 5 minutes per side, or until cooked through.
# Translated (EN → HI): 2 बड़े कौशल से भरे तेल में, तेल को गरम करता है ।
# Back-Translated (HI → EN): 2 In high - quality oil, oil warms down the oil.
#
# Original: 3. Transfer chicken to a baking dish. Top with blueberries, lemon juice, and butter.
# Translated (EN → HI): 3 मुर्गी को स्वादिष्ट खाना दीजिए ।
# Back-Translated (HI → EN): 3 Let the chicken eat deliciously.
#
# Original: 4. Bake for 20-25 minutes, or until the chicken is cooked through and the blueberries are tender.
# Translated (EN → HI): 4. 20 25 मिनट के लिए , या जब तक मुर्गी पकाई जाती है और नीले रंग के पेड़ कोमल होते हैं.
# Back-Translated (HI → EN): 4.20 minutes, or as long as the chicken is cooked and the blue tree is soft.
#
# Original: 5. Serve with green beans and mashed potatoes.
# Translated (EN → HI): 5 हरी घास और गिरी हुई आलू के साथ मिलकर सेवा कीजिए ।
# Back-Translated (HI → EN): 5 Serve together with green grass and nuts.
#
# Original: **Tips:**
# Translated (EN → HI): ** एजेंट:
# Back-Translated (HI → EN): ** Agent:
#
# Original: * For a more flavorful dish, use a variety of different berries, such as raspberries or strawberries.
# Translated (EN → HI): * ज़्यादा स्वादप्रद व्यंजनों के लिए, विभिन्‍न प्रकार के व्यंजनों का प्रयोग कीजिए, जैसे राइसबरों या स्टूबरों का ।
# Back-Translated (HI → EN): * For more flavorings, use various types of dyes, such as the Reich's or the Students.
#
# Original: * Serve with a dipping sauce, such as a balsamic glaze or a honey mustard sauce.
# Translated (EN → HI): * जैसे कि बलसान या राई के दाने के बराबर ।
# Back-Translated (HI → EN): * Such as balm, or mustard grain.
#
# Original: * Serve with a side of crusty bread to soak up the juices.
# Translated (EN → HI): * रस को भरने के लिए हरी रोटी की एक तरफ रहकर सेवा कीजिए ।
# Back-Translated (HI → EN): * Serve on one side of the green bread to feed the juice.
#
# Original: Recipe 7:
# Translated (EN → HI): रेसिपि 7:
# Back-Translated (HI → EN): Recipe 7:
#
# Original: **Chicken and Cheese Stuffed Corn with Heavy Cream Sauce**
# Translated (EN → HI): **CKKen और चीज सामग्री भारी क्रीम के साथ cratack
# Back-Translated (HI → EN): **CKKen and Cheese stuff with heavy cream
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 boneless, skinless chicken breast, cut into 1-inch cubes
# Translated (EN → HI): * 1 हड्डीहीन, त्वचाहीन मुर्गी स्तन, 1 सेमी घन में कटौती
# Back-Translated (HI → EN): * 1 Die in bone, skinless chicken breast, 1 tomi cubic
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): [ पेज 1 पर तसवीर]
# Back-Translated (HI → EN): [ Picture on page 1]
#
# Original: * 2 cloves garlic, minced
# Translated (EN → HI): * 2 cscates, मि.
# Back-Translated (HI → EN): * 2 ccasss, Mr.
#
# Original: * 1/2 teaspoon black pepper
# Translated (EN → HI): * 1/2 चाय काली मिर्च
# Back-Translated (HI → EN): * 1/2 tea capper
#
# Original: * 1/4 teaspoon salt
# Translated (EN → HI): * 1/4 चाय - नमक
# Back-Translated (HI → EN): * 1/4 Tea - Salt
#
# Original: * 1/4 cup heavy cream
# Translated (EN → HI): * 1/4 कप
# Back-Translated (HI → EN): * point out, however, that this type of cup is a different type of cup.
#
# Original: * 1/2 cup grated mozzarella cheese
# Translated (EN → HI): * 1/2 कप का रसाला पनीर
# Back-Translated (HI → EN): * 1/2 cup cheese
#
# Original: * 1/2 cup chopped fresh corn
# Translated (EN → HI): * 1/2 कप में ताज़ी बालें
# Back-Translated (HI → EN): * The fresh ears in 1/2 cup.
#
# Original: * 1/2 cup chopped mushrooms
# Translated (EN → HI): * 1/2 कप के टुकड़े बहुत बढ़ गए
# Back-Translated (HI → EN): * 1/2 cups were too large
#
# Original: * 1/2 teaspoon dried oregano
# Translated (EN → HI): * 1/2 चाय सूखेया याgougo
# Back-Translated (HI → EN): * 1/2 Tea Dy or Gogogo
#
# Original: * 1/4 teaspoon salt
# Translated (EN → HI): * 1/4 चाय - नमक
# Back-Translated (HI → EN): * 1/4 Tea - Salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Heat olive oil in a large skillet over medium heat.
# Translated (EN → HI): 1. जैतून तेल में तेल को गरम धूप से भी ज़्यादा इस्तेमाल किया जा सकता है ।
# Back-Translated (HI → EN): The oil oil in the olive oil can be used more than hoter heat.
#
# Original: 2. Season chicken with black pepper and salt.
# Translated (EN → HI): 2. गर्म मुर्गी काली मिर्च और नमक के साथ.
# Back-Translated (HI → EN): 2. With hot chicken black capper and salt.
#
# Original: 3. Add chicken to the skillet and cook until browned on all sides.
# Translated (EN → HI): 3 मुर्गी को हर तरफ भूरे रंग के फूल और पकाइए ।
# Back-Translated (HI → EN): 3 Assuminate the chicken - brown and brown - brown.
#
# Original: 4. Add onion and garlic to the skillet and cook until softened, about 5 minutes.
# Translated (EN → HI): इसके अलावा, करीब 5 मिनट के अंदर, काम के लिए अच्छी तरह तैयार हो जाती है और उसे अच्छी तरह तैयार किया जाता है ।
# Back-Translated (HI → EN): In addition, within about 5 minutes, it is prepared and prepared well.
#
# Original: 5. Add mushrooms and potato to the skillet and cook until tender, about 10 minutes.
# Translated (EN → HI): इसके अलावा, करीब 10 मिनट तक बड़े - बड़े हुनर और खाना भी तैयार कीजिए ।
# Back-Translated (HI → EN): In addition, prepare skills and food for about 10 minutes.
#
# Original: 6. Add heavy cream, mozzarella cheese, and oregano to the skillet.
# Translated (EN → HI): 6 भारी आइसक्रीम, मोज़ाएली पनीर, और यागनो को कौशल के साथ जोड़िए ।
# Back-Translated (HI → EN): associate 6 heavy ice cream, Mosleley cheese, and Yagano with skill.
#
# Original: 7. Bring to a simmer and cook for 5 minutes, or until the cheese is melted and bubbly.
# Translated (EN → HI): 7 एक बोरर और 5 मिनट के लिए खाना लाने के लिए, या जब तक पनीर पिघल जाता है और मोमबती जाती है.
# Back-Translated (HI → EN): 7 to bring food for a sacker and 5 minutes, or as long as cheese is melted and waxed.
#
# Original: 8. Serve over a bed of roasted corn.
# Translated (EN → HI): भोजन के ढेर के ऊपर सेवा कीजिए ।
# Back-Translated (HI → EN): Serve on top of a meal heap.
#
# Original: Recipe 8:
# Translated (EN → HI): रेसिपि 8:
# Back-Translated (HI → EN): Recipe 8:
#
# Original: **Chicken and Sweet Potato Hash with Green Beans**
# Translated (EN → HI): ** बैरन और स्वीशियम हरा बेरन के साथ हैश
# Back-Translated (HI → EN): ** Bishnen and symbium Greenen
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 loaf of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 रोटी का एक टुकड़ा, जो 1/2-inch मोटी स्लाइस में काटा गया था
# Back-Translated (HI → EN): * 1 piece of bread, which was cut into the 1/2-inch thick slice
#
# Original: * 1/4 cup of butter
# Translated (EN → HI): * 1/4 मक्खन का कप
# Back-Translated (HI → EN): * point to a cup of butter
#
# Original: * 1/2 pound of chicken_breast, cut into 1-inch pieces
# Translated (EN → HI): * 1/2 पाउंड _BAR_ मुर्गी, 1-inch के टुकड़ों में कटौती
# Back-Translated (HI → EN): * 1/2 pounds _BAR_ chicken, 1-inch pieces
#
# Original: * 1/4 cup of green_beans, trimmed and cut into 1/2-inch pieces
# Translated (EN → HI): * 1/4 हरे रंग के कप, डिम्पली और 1/2- hhys में कटौती
# Back-Translated (HI → EN): * 1/4 cuts into green cup, dishys and 1/2-huys
#
# Original: * 1/4 cup of chopped strawberries
# Translated (EN → HI): * 1/4 पन्‍ने की झीलों का कप
# Back-Translated (HI → EN): * refuse a cup of lakes of one quarter page
#
# Original: * 1/4 cup of chopped sweet_potato, diced
# Translated (EN → HI): * 1/4 के कप में मीठा_ थॉटो, पॉंटो
# Back-Translated (HI → EN): *, sweet_Toto, Poto, inseto's cup.
#
# Original: * 1/4 cup of flour
# Translated (EN → HI): * 1/4 फलों का प्याला
# Back-Translated (HI → EN): *second cup of fruit
#
# Original: * 1/2 teaspoon of salt
# Translated (EN → HI): * 1/2 नमक का चाय
# Back-Translated (HI → EN): * 1/2 salt tea
#
# Original: * 1/4 teaspoon of black pepper
# Translated (EN → HI): * 1/4 काली मिर्च का चाय
# Back-Translated (HI → EN): * point out, "I'm not going to have anything to do with it. "
#
# Original: * 1/4 cup of milk
# Translated (EN → HI): * माँ का दूध
# Back-Translated (HI → EN): * Mother's milk
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
# Back-Translated (HI → EN): 1.75 degrees to F (199 degrees C).
#
# Original: 2. In a large skillet over medium heat, melt the butter.
# Translated (EN → HI): 2. मीडिया गर्मी पर एक बड़े कौशल में, मक्खन पिघल जाता है.
# Back-Translated (HI → EN): 2. In a great skill on the media heat, butter melts.
#
# Original: 3. Add the chicken and cook until browned on all sides.
# Translated (EN → HI): 3 मुर्गी और खाना दीजिए जब तक कि सभी पक्ष में भूरे रंग के हो जाते हैं ।
# Back-Translated (HI → EN): 3 Give chicken and food as long as it is brown on all sides.
#
# Original: 4. Add the green beans and cook until tender and slightly crisp.
# Translated (EN → HI): हर गुच्छे में फल और सब्ज़ियाँ दीजिए, यहाँ तक कि कम - से - कम बालों को भी ।
# Back-Translated (HI → EN): Give fruit and vegetables in each cluster, including at least the hair.
#
# Original: 5. Add the strawberries, sweet potato, flour, salt, and black pepper. Cook until heated through.
# Translated (EN → HI): यह भोजन तब तक गरम रहता है जब तक कि वह गरम नहीं हो जाता ।
# Back-Translated (HI → EN): This food remains hot until it is hot.
#
# Original: 6. Spoon the hash into a baking dish.
# Translated (EN → HI): 6. स्पून एक व्यंजन में आता है.
# Back-Translated (HI → EN): 6. Spoon comes into a dish.
#
# Original: 7. Pour the milk over the hash and bake for 15-20 minutes, or until the potatoes are tender and the sauce is heated through.
# Translated (EN → HI): 7.के ऊपर दूध डालो और 15-20 मिनट के लिए पकाओ, या जब तक आलू कोमल नहीं हो जाती, तब तक उसे गरम रखा जाता है.
# Back-Translated (HI → EN): Cast milk on top of 7. And cook for 15-20 minutes, or keep the cheese hot until it's ready.
#
# Original: 8. Serve immediately with a side of crusty bread.
# Translated (EN → HI): 8 छोटी - छोटी रोटी लेकर तुरंत सेवा कीजिए ।
# Back-Translated (HI → EN): 8 Serve immediately with small loaves.
#
# Original: Recipe 9:
# Translated (EN → HI): रेसिपि 9:
# Back-Translated (HI → EN): Recipe 9:
#
# Original: **Green Bean and Mushroom Bread**
# Translated (EN → HI): ** हरा बीनन तथा मिशमित रोटी
# Back-Translated (HI → EN): ** Green Bean and Mishnant Bread
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 loaf (1 pound) of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 रोटी का (1 पाउंड), जो 1/2-inch मोटी टहनियाँ में विभाजित हुआ
# Back-Translated (HI → EN): * 1 1 pound of bread, divided into 1/2-10 thick rods
#
# Original: * 1/2 cup of grated mozzarella cheese
# Translated (EN → HI): * 1/2 फलों का कप
# Back-Translated (HI → EN): * 1/2 cup of fruit
#
# Original: * 4 large eggs
# Translated (EN → HI): * 4 बड़े अंडे
# Back-Translated (HI → EN): * 4 large eggs
#
# Original: * 1 tablespoon of olive oil
# Translated (EN → HI): * 1 जैतून के तेल की पटियाएँ
# Back-Translated (HI → EN): * 1 The tablets of the olive oil
#
# Original: * 1 tablespoon of chopped onion
# Translated (EN → HI): [ पेज 1 पर चित्र का श्रेय]
# Back-Translated (HI → EN): [ Picture Credit Line on page 15]
#
# Original: * 1/2 teaspoon of dried oregano
# Translated (EN → HI): * 1/2 चाय याँगो की चाय
# Back-Translated (HI → EN): * 1/2 Teas or Choongo's tea
#
# Original: * 1/4 teaspoon of salt
# Translated (EN → HI): * 1/4 नमक का चाय
# Back-Translated (HI → EN): * point to salt's tea
#
# Original: * 1/4 teaspoon of black pepper
# Translated (EN → HI): * 1/4 काली मिर्च का चाय
# Back-Translated (HI → EN): * point out, "I'm not going to have anything to do with it. "
#
# Original: * 1/4 cup of green beans, trimmed and cut into 1/2-inch pieces
# Translated (EN → HI): * हर्क का 1/4 कप, सिलेक और 1/2-घन में काट
# Back-Translated (HI → EN): * Hack of Sakkax, caliber and 1/2-hun
#
# Original: * 1/4 cup of sliced mushrooms
# Translated (EN → HI): * 1/4 टुकड़े - टुकड़े का कप
# Back-Translated (HI → EN): * point to pieces with pieces
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
# Back-Translated (HI → EN): 1.75 degrees to F (199 degrees C).
#
# Original: 2. In a large bowl, combine the bread slices, mozzarella cheese, eggs, olive oil, onion, oregano, salt, and black pepper.
# Translated (EN → HI): 2 बड़े - बड़े कटोरे में, रोटी का टुकड़ा, मोज़ेला पनीर, अंडे, जैतून का तेल, ऊपर का तेल, लोन, नमक और काली मिर्च साथ दीजिए ।
# Back-Translated (HI → EN): 2 In large cup, carry a piece of bread, Mosle cheese, eggs, olive oil, high - above oil, salt, salt, and bitter.
#
# Original: 3. Spread the bread mixture out on a baking sheet lined with parchment paper.
# Translated (EN → HI): एक पन्‍ने पर रखी गयी रोटी को अलग - अलग पन्‍ने पर रखिए ।
# Back-Translated (HI → EN): Keep the bread set on one page after another.
#
# Original: 4. Bake for 15-20 minutes, or until the bread is golden brown and the cheese is melted and bubbly.
# Translated (EN → HI): 4. 1520 मिनट के लिए बकवास, या जब तक रोटी सोने के भूरे रंग की है और पनीर पिघल जाता है.
# Back-Translated (HI → EN): 4.1520 minutes the fuck, or while the bread is brown and the cheese is melted.
#
# Original: 5. Serve hot with the green beans and mushrooms.
# Translated (EN → HI): 5 हरी - हरी टहनियाँ और बढ़ जाती हैं ।
# Back-Translated (HI → EN): 5 Green - green twigs grow.
#
# Original: Recipe 10:
# Translated (EN → HI): रेसिपि 10:
# Back-Translated (HI → EN): Recipe 10:
#
# Original: **Green Bean and Mushroom Bread**
# Translated (EN → HI): ** हरा बीनन तथा मिशमित रोटी
# Back-Translated (HI → EN): ** Green Bean and Mishnant Bread
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 loaf (1 pound) of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 रोटी का (1 पाउंड), जो 1/2-inch मोटी टहनियाँ में विभाजित हुआ
# Back-Translated (HI → EN): * 1 1 pound of bread, divided into 1/2-10 thick rods
#
# Original: * 1/2 cup of grated mozzarella cheese
# Translated (EN → HI): * 1/2 फलों का कप
# Back-Translated (HI → EN): * 1/2 cup of fruit
#
# Original: * 4 large eggs
# Translated (EN → HI): * 4 बड़े अंडे
# Back-Translated (HI → EN): * 4 large eggs
#
# Original: * 1 tablespoon of olive oil
# Translated (EN → HI): * 1 जैतून के तेल की पटियाएँ
# Back-Translated (HI → EN): * 1 The tablets of the olive oil
#
# Original: * 1 tablespoon of chopped onion
# Translated (EN → HI): [ पेज 1 पर चित्र का श्रेय]
# Back-Translated (HI → EN): [ Picture Credit Line on page 15]
#
# Original: * 1/2 teaspoon of dried oregano
# Translated (EN → HI): * 1/2 चाय याँगो की चाय
# Back-Translated (HI → EN): * 1/2 Teas or Choongo's tea
#
# Original: * 1/4 teaspoon of salt
# Translated (EN → HI): * 1/4 नमक का चाय
# Back-Translated (HI → EN): * point to salt's tea
#
# Original: * 1/4 teaspoon of black pepper
# Translated (EN → HI): * 1/4 काली मिर्च का चाय
# Back-Translated (HI → EN): * point out, "I'm not going to have anything to do with it. "
#
# Original: * 1/4 cup of green beans, trimmed and cut into 1/2-inch pieces
# Translated (EN → HI): * हर्क का 1/4 कप, सिलेक और 1/2-घन में काट
# Back-Translated (HI → EN): * Hack of Sakkax, caliber and 1/2-hun
#
# Original: * 1/4 cup of sliced mushrooms
# Translated (EN → HI): * 1/4 टुकड़े - टुकड़े का कप
# Back-Translated (HI → EN): * point to pieces with pieces
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
# Back-Translated (HI → EN): 1.75 degrees to F (199 degrees C).
#
# Original: 2. In a large bowl, combine the bread slices, mozzarella cheese, eggs, olive oil, onion, oregano, salt, and black pepper.
# Translated (EN → HI): 2 बड़े - बड़े कटोरे में, रोटी का टुकड़ा, मोज़ेला पनीर, अंडे, जैतून का तेल, ऊपर का तेल, लोन, नमक और काली मिर्च साथ दीजिए ।
# Back-Translated (HI → EN): 2 In large cup, carry a piece of bread, Mosle cheese, eggs, olive oil, high - above oil, salt, salt, and bitter.
#
# Original: 3. Spread the bread mixture out on a baking sheet lined with parchment paper.
# Translated (EN → HI): एक पन्‍ने पर रखी गयी रोटी को अलग - अलग पन्‍ने पर रखिए ।
# Back-Translated (HI → EN): Keep the bread set on one page after another.
#
# Original: 4. Bake for 15-20 minutes, or until the bread is golden brown and the cheese is melted and bubbly.
# Translated (EN → HI): 4. 1520 मिनट के लिए बकवास, या जब तक रोटी सोने के भूरे रंग की है और पनीर पिघल जाता है.
# Back-Translated (HI → EN): 4.1520 minutes the fuck, or while the bread is brown and the cheese is melted.
#
# Original: 5. Serve hot with the green beans and mushrooms.
# Translated (EN → HI): 5 हरी - हरी टहनियाँ और बढ़ जाती हैं ।
# Back-Translated (HI → EN): 5 Green - green twigs grow.
#
# Original: Recipe 11:
# Translated (EN → HI): रेसिपि ११:
# Back-Translated (HI → EN): Recipe 11:
#
# Original: **Mushroom and Cheese Bread with Green Bean Mash**
# Translated (EN → HI): ** बेल्जियम और चीज़ हरा बंबॉर के साथ की रोटी
# Back-Translated (HI → EN): ** Hibbling and green bread with Brumbarbarer
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 loaf (1 pound) of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 रोटी का (1 पाउंड), जो 1/2-inch मोटी टहनियाँ में विभाजित हुआ
# Back-Translated (HI → EN): * 1 1 pound of bread, divided into 1/2-10 thick rods
#
# Original: * 1/2 pound of grated mozzarella cheese
# Translated (EN → HI): * 70 किलो का गर्माएली पनीर
# Back-Translated (HI → EN): * An estimated 70 pounds [70 kg] of hot cheese
#
# Original: * 1/4 cup of chopped green beans
# Translated (EN → HI): * 1/4 कप, जो हरे - भरे गन्‍ने से तैयार किया जाता है
# Back-Translated (HI → EN): * 1/4 cups prepared with green cane
#
# Original: * 1/4 cup of chopped mushrooms
# Translated (EN → HI): [ पेज 18 पर बड़े अक्षरों में लेख की खास बात]
# Back-Translated (HI → EN): [ Blurb on page 18]
#
# Original: * 2 large eggs, beaten
# Translated (EN → HI): * 2 बड़े अंडे, पीटा
# Back-Translated (HI → EN): * 2 Big eggs, strike
#
# Original: * 1 tablespoon of olive oil
# Translated (EN → HI): * 1 जैतून के तेल की पटियाएँ
# Back-Translated (HI → EN): * 1 The tablets of the olive oil
#
# Original: * 1/2 teaspoon of salt
# Translated (EN → HI): * 1/2 नमक का चाय
# Back-Translated (HI → EN): * 1/2 salt tea
#
# Original: * 1/4 teaspoon of black pepper
# Translated (EN → HI): * 1/4 काली मिर्च का चाय
# Back-Translated (HI → EN): * point out, "I'm not going to have anything to do with it. "
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
# Back-Translated (HI → EN): 1.75 degrees to F (199 degrees C).
#
# Original: 2. In a large bowl, combine the bread slices, mozzarella cheese, and green beans.
# Translated (EN → HI): 2 एक बड़े कटोरे में, रोटी का टुकड़ा, मोज़ेला पनीर और हरी घास साथ दीजिए ।
# Back-Translated (HI → EN): 2 In a large cup, add a piece of bread, Mosla cheese, and green grass.
#
# Original: 3. In a separate bowl, whisk together the eggs, olive oil, salt, and black pepper.
# Translated (EN → HI): एक अलग कटोरा में, अंडे, जैतून का तेल, नमक और काली मिर्च साथ ले जाया जाता है ।
# Back-Translated (HI → EN): In a separate cup, eggs are taken along with the olive oil, salt, and cassia.
#
# Original: 4. Add the wet ingredients to the dry ingredients and stir until just combined. Do not overmix.
# Translated (EN → HI): 4 सूखे पदार्थों को जोड़िए और उन्हें हिलाइए, जब तक कि सिर्फ एक - दूसरे से जुदा न हो जाए ।
# Back-Translated (HI → EN): 4 mix and shake food, until there is only one separation.
#
# Original: 5. Pour the mixture into a greased 9x13-inch baking dish.
# Translated (EN → HI): 5. मिश्रण को तेलित 9x13-घन थाली में डुबाओ.
# Back-Translated (HI → EN): Fill the 5.dative mix at 9x13-ggrin.
#
# Original: 6. Bake for 20-25 minutes, or until the bread is golden brown and the cheese is melted and bubbly.
# Translated (EN → HI): 6. 20 25 मिनट के लिए , या जब तक रोटी सोने के भूरे रंग की होती है और पनीर पिघल जाता है.
# Back-Translated (HI → EN): 6.20 minutes for 25 minutes, or while the bread is white and the cheese is melted.
#
# Original: 7. Serve hot with a side of green bean mash.
# Translated (EN → HI): 7. हरे रंग के हरे रंग के साथ गर्म की सेवा करते हैं.
# Back-Translated (HI → EN): 7.ar serve hot with green.
#
# Original: **Green Bean Mash:**
# Translated (EN → HI): ** हरा बंबॉर्न:
# Back-Translated (HI → EN): ** Green Brann:
#
# Original: * 1 tablespoon of olive oil
# Translated (EN → HI): * 1 जैतून के तेल की पटियाएँ
# Back-Translated (HI → EN): * 1 The tablets of the olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): [ पेज 1 पर तसवीर]
# Back-Translated (HI → EN): [ Picture on page 1]
#
# Original: * 2 cloves of garlic, minced
# Translated (EN → HI): * 2 cacate, मि.
# Back-Translated (HI → EN): * 2cape, min
#
# Original: * 1 (15-ounce) can of green beans, drained and rinsed
# Translated (EN → HI): * 1 (15- ऊपर) हरीकेन, पकाई और धोई हुई हरी घास का हो सकता है
# Back-Translated (HI → EN): * 1 (Up) The rose, dry, and washed green grass
#
# Original: * 1/2 cup of milk
# Translated (EN → HI): * दूध का 1/2 कप
# Back-Translated (HI → EN): * A 1/2 cup of milk
#
# Original: * 1/4 cup of grated mozzarella cheese
# Translated (EN → HI): * सन्‌ 1/4 का कप
# Back-Translated (HI → EN): * A cup of header
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Heat the olive oil in a large pot or Dutch oven over medium heat.
# Translated (EN → HI): 1. जैतून के तेल में तेल या तेल को गरम धूप पर रखिए ।
# Back-Translated (HI → EN): 1. . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
# Original: 2. Add the onion and garlic and cook until softened, about 5 minutes.
# Translated (EN → HI): 2 खाने - पीने की चीज़ें और खाना दीजिए, यहाँ तक कि 5 मिनट के अंदर ।
# Back-Translated (HI → EN): 2 Provide food and food, even in 5 minutes.
#
# Original: 3. Add the green beans and milk and bring to a boil.
# Translated (EN → HI): इसके अलावा, हरीकेन और दूध भी दीजिए और उसे फोड़े में डाल दीजिए ।
# Back-Translated (HI → EN): If you are not sure how to handle this situation, you may find it helpful to read the Bible daily and meditate on what you read in it.
#
# Original: 4. Reduce heat to low and simmer for 10 minutes, or until the green beans are tender.
# Translated (EN → HI): ४. गर्मी को कम कीजिए और १० मिनट तक कम करें, या जब तक कि हरा बीन फूल कोमल नहीं होते ।
# Back-Translated (HI → EN): So keep warm and lower for 10 minutes, or as long as green flowers are not gentle.
#
# Original: 5. Stir in the mozzarella cheese and serve immediately.
# Translated (EN → HI): 5 मोज़ेरेला पनीर में दम तोड़ो और तुरंत सेवा कीजिए ।
# Back-Translated (HI → EN): 5 Die in the Moslela cheese and serve immediately.
#
# Original: Recipe 12:
# Translated (EN → HI): रेसिपि 12:
# Back-Translated (HI → EN): Recipe 12:
#
# Original: **The Dish:**
# Translated (EN → HI): ** दिश:
# Back-Translated (HI → EN): ** Dish:
#
# Original: **Mushroom and Cheese Bread with Green Bean and Onion Filling**
# Translated (EN → HI): ** मेलेनमेंट और चीज़ साथ की रोटी
# Back-Translated (HI → EN): ** Mellenant and everything with bread
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 loaf (12 slices) bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 रोटी (12 स्लाइस) की रोटी, जो 1/2 मोटी स्लाइसों में विभाजित थी
# Back-Translated (HI → EN): * 1 loaf (12's) bread, which was divided into 1/2 thick slices
#
# Original: * 1/4 cup (60g) unsalted butter, melted and cooled slightly
# Translated (EN → HI): * 1/4 कप (60g) बिना - खून के मक्खन, थोड़ा ठंडा और ठंडा
# Back-Translated (HI → EN): * 1/4 cup (60g) without blood, little cold and cold
#
# Original: * 1/4 cup (60g) grated mozzarella cheese
# Translated (EN → HI): * 1/4 कप (60g)
# ...
# Translated (EN → HI): 6. रोटी और हरा बीनन की रोटी को एक थाली में रखना.
# Back-Translated (HI → EN): 6. put the bread of bread and green Bean in a dish.
#
# Original: 7. Bake for 20-25 minutes, or until the cheese is melted and bubbly.
# Translated (EN → HI): 20- 25 मिनट के लिए 7. या जब तक पनीर पिघल जाता है ... ... और .
# Back-Translated (HI → EN): 7. or as long as the cheese is melted for 20-25 minutes... and.
#
# Original: Recipe 17:
# Translated (EN → HI): रेसिपि 17:
# Back-Translated (HI → EN): Recipe 17:
#
# Original: **Blueberry Potato Green Bean Hash**
# Translated (EN → HI): ** ब्लूबर हरा बेगन
# Back-Translated (HI → EN): ** Blueber Green Began
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 2 large potatoes, peeled and diced into 1/2-inch cubes
# Translated (EN → HI): * 2 बड़े आलू, बहुमोल और ओका उनपर 1/2-inch
# Back-Translated (HI → EN): * 2 big coconuts, expensive and o'clock on them 1/2-10
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): [ पेज 1 पर तसवीर]
# Back-Translated (HI → EN): [ Picture on page 1]
#
# Original: * 2 cloves garlic, minced
# Translated (EN → HI): * 2 cscates, मि.
# Back-Translated (HI → EN): * 2 ccasss, Mr.
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चायदार नमक
# Back-Translated (HI → EN): * 1/2 teat salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: * 1/2 cup blueberries
# Translated (EN → HI): * 1/2 कप ब्लूबेरीज
# Back-Translated (HI → EN): * 1/2 cup blueberries
#
# Original: * 1/4 cup grated cheese
# Translated (EN → HI): * 1/4 कप
# Back-Translated (HI → EN): * point out, however, that this type of cup is a different type of cup.
#
# Original: * 1/4 cup green beans, trimmed and cut into 1/2-inch pieces
# Translated (EN → HI): * 1/4 कप कप कीट, सिलिना और 1/2-inch - भाग में कटौती
# Back-Translated (HI → EN): * 1/4 cup cupet, goatina and 1/2-05 cut in part
#
# Original: * 1/4 cup lime juice
# Translated (EN → HI): [ पेज 29 पर तसवीर]
# Back-Translated (HI → EN): [ Picture on page 29]
#
# Original: * 1 tablespoon flour
# Translated (EN → HI): * 1 मेज़ के मैदा
# Back-Translated (HI → EN): * Let us take a closer look at the example of the apostle Paul, who wrote: "Let us consider one another to incite to love and fine works, not forsaking the gathering of ourselves together, as some have the custom, but encouraging one another, and all the more so as you behold the day drawing near. "
#
# Original: * 1/2 teaspoon baking powder
# Translated (EN → HI): * 1/2 चाय पीसकर पीसना
# Back-Translated (HI → EN): * 1/2 Teas and fillers
#
# Original: * 1/4 teaspoon salt
# Translated (EN → HI): * 1/4 चाय - नमक
# Back-Translated (HI → EN): * 1/4 Tea - Salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Heat the olive oil in a large skillet or Dutch oven over medium heat.
# Translated (EN → HI): 1. जैतून तेल को बड़ी कुशलता से या तेल में डालकर गरमा - गरम धूप में रखिए ।
# Back-Translated (HI → EN): 1. Keep the olive oil thoroughly in hot heat with oil or with oil.
#
# Original: 2. Add the onion and garlic and cook until softened, about 5 minutes.
# Translated (EN → HI): 2 खाने - पीने की चीज़ें और खाना दीजिए, यहाँ तक कि 5 मिनट के अंदर ।
# Back-Translated (HI → EN): 2 Provide food and food, even in 5 minutes.
#
# Original: 3. Add the potatoes and cook until tender and golden brown, about 15 minutes.
# Translated (EN → HI): 3 आलू और खाना दीजिए जब तक कि कोमल और सुनहरे भूरे रंग के होते हैं, करीब 15 मिनट ।
# Back-Translated (HI → EN): 3 Platelets and food until they are soft and sweet - brown, about 15 minutes.
#
# Original: 4. Add the blueberries, cheese, green beans, lime juice, flour, baking powder, salt, and black pepper.
# Translated (EN → HI): इसके अलावा, ब्लूबरों, पनीर, हरीकेन, पका हुआ रस, आटा, नमक, नमक और काली मिर्च भी जोड़े जाते हैं ।
# Back-Translated (HI → EN): In addition, blue beans, cheeses, cheeses, cooking juices, flour, salt, salt, and cold are added.
#
# Original: 5. Bring to a simmer and cook for 10 minutes, or until the potatoes are cooked through and the greens are tender.
# Translated (EN → HI): 5 एक बड़े जहाज़ में ले आओ और 10 मिनट तक खाना पकाने के लिए, या जब तक आलू कम न हो और हरे - भरे होते हैं, तब तक वे कोमल होते हैं ।
# Back-Translated (HI → EN): 5 Bring a huge ship to cook for 10 minutes, or until the coconuts are few and full.
#
# Original: 6. Serve immediately.
# Translated (EN → HI): 6 तुरंत सेवा कीजिए ।
# Back-Translated (HI → EN): 6 Serve immediately.
#
# Original: Recipe 18:
# Translated (EN → HI): रेसिपि 18:
# Back-Translated (HI → EN): Recipe 18:
#
# Original: **Blueberry-Cheese-Green Bean Hash with Potato and Spinach**
# Translated (EN → HI): ** ब्लूबर- हरा बेबेन, आलू तथा स्पिनर के साथ हैक
# Back-Translated (HI → EN): ** Blober-Green Beean, spooky and Crab
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): [ पेज 1 पर तसवीर]
# Back-Translated (HI → EN): [ Picture on page 1]
#
# Original: * 1 green bean, diced
# Translated (EN → HI): * 1 हरा बेरा, पाँसा फेंकें
# Back-Translated (HI → EN): * 1 Greenberry, roll the dice
#
# Original: * 4 eggs, beaten
# Translated (EN → HI): * 4 अंडे, पीटा
# Back-Translated (HI → EN): * 4 eggs, strike
#
# Original: * 1/2 cup shredded cheese
# Translated (EN → HI): * 1/2 कप में डाली गयी पनीर
# Back-Translated (HI → EN): * 1/2 cups thrown in cup.
#
# Original: * 1/4 cup chopped blueberries
# Translated (EN → HI): * 1/4 कप में नीले रंग की छटियाँ
# Back-Translated (HI → EN): * point out that the size of blue would be different from the size of a flower in the sky.
#
# Original: * 1 tablespoon lime juice
# Translated (EN → HI): * 1 मेज़ के रस
# Back-Translated (HI → EN): * 1 table juice
#
# Original: * 1 tablespoon chopped fresh parsley
# Translated (EN → HI): * 1 मैकेन ने नए सिरे तक चीरा - फाड़ डाला
# Back-Translated (HI → EN): * 1 Mines were torn to new ground
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चायदार नमक
# Back-Translated (HI → EN): * 1/2 teat salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Heat olive oil in a large skillet over medium heat.
# Translated (EN → HI): 1. जैतून तेल में तेल को गरम धूप से भी ज़्यादा इस्तेमाल किया जा सकता है ।
# Back-Translated (HI → EN): The oil oil in the olive oil can be used more than hoter heat.
#
# Original: 2. Add onion and green bean and cook until tender, about 5 minutes.
# Translated (EN → HI): 2 स्फीन और हरा बीन और छोटे बच्चे तक खाना दीजिए, लगभग 5 मिनट.
# Back-Translated (HI → EN): 2 Sfches and greens and food to small children, about 5 minutes.
#
# Original: 3. Add eggs and cook until sunny-side up.
# Translated (EN → HI): 3 अंडे और खाना जोड़ें धूप के किनारे तक.
# Back-Translated (HI → EN): 3 Add eggs and food until the sun shore.
#
# Original: 4. Add cheese, blueberries, lime juice, parsley, salt, and pepper to the skillet.
# Translated (EN → HI): इसके अलावा, पनीर, ब्लूबरों, रस, पर्सली, नमक और काली मिर्च को हुनर में भी जोड़िए ।
# Back-Translated (HI → EN): In addition, add cheeses, blues, juices, purses, salts, and peppers in skills.
#
# Original: 5. Cook for 5 minutes, or until the potatoes are tender and the sauce is heated through.
# Translated (EN → HI): जब तक आलू कोमल नहीं हो जाती, तब तक 5 मिनट का खाना ठंडा हो जाता है ।
# Back-Translated (HI → EN): By the time it gets cold, there are 5 minutes of cold food.
#
# Original: 6. Serve immediately.
# Translated (EN → HI): 6 तुरंत सेवा कीजिए ।
# Back-Translated (HI → EN): 6 Serve immediately.
#
# Original: Recipe 19:
# Translated (EN → HI): रेसिपि 19:
# Back-Translated (HI → EN): Recipe 19:
#
# Original: **Blueberry-Cheese-Green Bean Hash with Potato and Spinach**
# Translated (EN → HI): ** ब्लूबर- हरा बेबेन, आलू तथा स्पिनर के साथ हैक
# Back-Translated (HI → EN): ** Blober-Green Beean, spooky and Crab
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): [ पेज 1 पर तसवीर]
# Back-Translated (HI → EN): [ Picture on page 1]
#
# Original: * 1 green bean, diced
# Translated (EN → HI): * 1 हरा बेरा, पाँसा फेंकें
# Back-Translated (HI → EN): * 1 Greenberry, roll the dice
#
# Original: * 1/2 pound potatoes, diced
# Translated (EN → HI): * 1/2 पाउंड, पॉडड
# Back-Translated (HI → EN): * 1/2 pounds, Pod
#
# Original: * 1/2 pound fresh spinach
# Translated (EN → HI): * 1/2 किलो ताजा स्पिन
# Back-Translated (HI → EN): * 1/2 pounds fresh spin
#
# Original: * 1/4 cup grated mozzarella cheese
# Translated (EN → HI): * 1/4 कप का पेय
# Back-Translated (HI → EN): * point out that a drink of one's cup will be used for the next two and a half years.
#
# Original: * 2 large eggs
# Translated (EN → HI): * 2 बड़े अंडे
# Back-Translated (HI → EN): * 2 Big eggs
#
# Original: * 1 tablespoon lime juice
# Translated (EN → HI): * 1 मेज़ के रस
# Back-Translated (HI → EN): * 1 table juice
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चायदार नमक
# Back-Translated (HI → EN): * 1/2 teat salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Heat olive oil in a large skillet over medium heat.
# Translated (EN → HI): 1. जैतून तेल में तेल को गरम धूप से भी ज़्यादा इस्तेमाल किया जा सकता है ।
# Back-Translated (HI → EN): The oil oil in the olive oil can be used more than hoter heat.
#
# Original: 2. Add onion and green bean and cook until tender, about 5 minutes.
# Translated (EN → HI): 2 स्फीन और हरा बीन और छोटे बच्चे तक खाना दीजिए, लगभग 5 मिनट.
# Back-Translated (HI → EN): 2 Sfches and greens and food to small children, about 5 minutes.
#
# Original: 3. Add potatoes and spinach to the skillet and cook until tender, about 10 minutes.
# Translated (EN → HI): इसके अलावा, कम - से - कम 10 मिनट तक अंडे दीजिए ।
# Back-Translated (HI → EN): In addition, take at least 10 minutes of eggs.
#
# Original: 4. Add eggs and lime juice to the skillet and cook until the eggs are cooked through.
# Translated (EN → HI): जब तक अंडे न पक जाते हैं तब तक अंडे दीजिए ।
# Back-Translated (HI → EN): As long as the eggs are ripe, lay eggs until they are ripe.
#
# Original: 5. Season with salt and pepper to taste.
# Translated (EN → HI): 5 नमक और काली मिर्च से स्वाद लेने के लिए .
# Back-Translated (HI → EN): 5 to taste with salt and pepper.
#
# Original: 6. Serve immediately with cheese on top.
# Translated (EN → HI): पर पनीर के साथ तुरंत सेवा कीजिए ।
# Back-Translated (HI → EN): But serve immediately with cheese.
#
# Original: Recipe 20:
# Translated (EN → HI): रेसिपि 20:
# Back-Translated (HI → EN): Recipe 20:
#
# Original: **Blueberry Chicken with Green Bean Mash**
# Translated (EN → HI): ** हरे बेसैन के साथ ब्लूबेरी चाउन
# Back-Translated (HI → EN): ** Blueberi keys with green base
#
# Original: **Ingredients:**
# Translated (EN → HI): ** इंडिक्स:
# Back-Translated (HI → EN): ** Indix:
#
# Original: * 1 boneless, skinless chicken breast, cut into 4 equal pieces
# Translated (EN → HI): * एक हड्डीहीन, त्वचाहीन मुर्गी स्तन, 4 बराबर के टुकड़ों में कटौती
# Back-Translated (HI → EN): * A boneless, skinless chicken cuts, 4 equal pieces of pieces
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 मेज़ी जैतून के तेल
# Back-Translated (HI → EN): * 1 Maze Olive oil
#
# Original: * 1/2 onion, diced
# Translated (EN → HI): * 1/2 उनपर, पॉलैंड
# Back-Translated (HI → EN): * 1/2 at them,
#
# Original: * 1/4 green bean, trimmed and cut into 1-inch pieces
# Translated (EN → HI): * 1/4 हरे रंग का होता है और 1 इंच काटता है
# Back-Translated (HI → EN): * 1/4 is green and cuts 1 inches
#
# Original: * 1/4 cup fresh spinach
# Translated (EN → HI): [ पेज 29 पर बड़े अक्षरों में लेख की खास बात]
# Back-Translated (HI → EN): [ Blurb on page 29]
#
# Original: * 1/4 cup grated mozzarella cheese
# Translated (EN → HI): * 1/4 कप का पेय
# Back-Translated (HI → EN): * point out that a drink of one's cup will be used for the next two and a half years.
#
# Original: * 2 large eggs, beaten
# Translated (EN → HI): * 2 बड़े अंडे, पीटा
# Back-Translated (HI → EN): * 2 Big eggs, strike
#
# Original: * 1 tablespoon lime juice
# Translated (EN → HI): * 1 मेज़ के रस
# Back-Translated (HI → EN): * 1 table juice
#
# Original: * 1 tablespoon flour
# Translated (EN → HI): * 1 मेज़ के मैदा
# Back-Translated (HI → EN): * Let us take a closer look at the example of the apostle Paul, who wrote: "Let us consider one another to incite to love and fine works, not forsaking the gathering of ourselves together, as some have the custom, but encouraging one another, and all the more so as you behold the day drawing near. "
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चायदार नमक
# Back-Translated (HI → EN): * 1/2 teat salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चाय काली मिर्च
# Back-Translated (HI → EN): * point out, however, that it's a bit too late.
#
# Original: **Instructions:**
# Translated (EN → HI): ** पहलः
# Back-Translated (HI → EN): ** Startup:
#
# Original: 1. Heat olive oil in a large skillet or Dutch oven over medium heat.
# Translated (EN → HI): 1. जैतून तेल को बड़ी कुशलता से या तेल में डालकर गरम किया जा सकता है ।
# Back-Translated (HI → EN): The olive oil, which is used in a variety of ways, can be used effectively in oil or oil.
#
# Original: 2. Season chicken with salt and pepper.
# Translated (EN → HI): 2, नमक और काली मिर्च के साथ.
# Back-Translated (HI → EN): 2, with salt and pepper.
#
# Original: 3. Add chicken to the skillet and cook for 5-7 minutes per side, or until cooked through.
# Translated (EN → HI): 3. मुर्गी को हर तरफ 5 मिनट के लिए खाना दीजिए, या जब तक कि उसे पका न हो ।
# Back-Translated (HI → EN): 3. Feed the chicken for 5 minutes, or until it is cooked.
#
# Original: 4. Remove chicken from the skillet and set aside.
# Translated (EN → HI): 4. मुर्गी को हुनर से निकाल दीजिए और अलग रखिए ।
# Back-Translated (HI → EN): Put the chicken aside with skill and keep it apart.
#
# Original: 5. Add onion and green bean to the skillet and cook until tender, about 5 minutes.
# Translated (EN → HI): 5 छोटे - छोटे बच्चे पैदा कीजिए ।
# Back-Translated (HI → EN): 5 Cultivate Children.
#
# Original: 6. Add spinach and cook until wilted, about 2 minutes.
# Translated (EN → HI): 6 करीब 2 मिनट के लिए , जब तक कि जब तक हम थक न जाएँ, खाना पकाने के लिए और खाना दीजिए ।
# Back-Translated (HI → EN): For about six minutes, supply food and food until we are tired.
#
# Original: 7. Add mozzarella cheese, eggs, lime juice, flour, and salt and pepper to the skillet.
# Translated (EN → HI): 7. ब्लॉएली पनीर, अंडे, रस, मैदा, नमक और नमक भी वगैरह में पाए जाते हैं ।
# Back-Translated (HI → EN): 7. blouse cheese, eggs, juice, flour, salt, and salt are found in the same category.
#
# Original: 8. Cook for 5 minutes, or until heated through.
# Translated (EN → HI): 5 मिनट के लिए खाना, या फिर गर्म होने तक.
# Back-Translated (HI → EN): Food for 5 minutes, or until it's warm.
#
# Original: 9. Serve chicken over green bean mash.
# Translated (EN → HI): 9 हरे रंग से अधिक मुर्गी की सेवा करो.
# Back-Translated (HI → EN): Serve more chicken than 9 green.
#
# Translation and back-translation completed! Files saved:
# - Hindi Recipes: 'translated_recipe_hi.txt'
# - Back-Translated English Recipes: 'back_translated_recipe.txt'

# %%
# !pip install scarebleu
# Out:
# ERROR: Could not find a version that satisfies the requirement scarebleu (from versions: none)
# ERROR: No matching distribution found for scarebleu

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install --upgrade transformers
# Out:
# Found existing installation: torch 1.13.1
# Uninstalling torch-1.13.1:
#   Successfully uninstalled torch-1.13.1
# Found existing installation: torchvision 0.21.0+cpu
# Uninstalling torchvision-0.21.0+cpu:
#   Successfully uninstalled torchvision-0.21.0+cpu
# Found existing installation: torchaudio 2.6.0+cpu
# Uninstalling torchaudio-2.6.0+cpu:
#   Successfully uninstalled torchaudio-2.6.0+cpu
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (26 kB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.21.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.2.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Using cached https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl (178.7 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchvision-0.21.0%2Bcpu-cp311-cp311-linux_x86_64.whl (1.8 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl (1.7 MB)
# Installing collected packages: torch, torchvision, torchaudio
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# laserembeddings 1.1.2 requires numpy<2.0.0,>=1.15.4, but you have numpy 2.2.4 which is incompatible.
# laserembeddings 1.1.2 requires torch<2.0.0,>=1.0.1.post2, but you have torch 2.6.0+cpu which is incompatible.
# Successfully installed torch-2.6.0+cpu torchaudio-2.6.0+cpu torchvision-0.21.0+cpu
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
# !pip install laserembeddings
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# Collecting laserembeddings
#   Downloading laserembeddings-1.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy<2.0.0,>=1.15.4 (from laserembeddings)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Collecting sacremoses==0.0.35 (from laserembeddings)
#   Downloading sacremoses-0.0.35.tar.gz (859 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.8/859.8 kB 14.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting subword-nmt<0.4.0,>=0.3.6 (from laserembeddings)
#   Downloading subword_nmt-0.3.8-py3-none-any.whl.metadata (9.2 kB)
# Collecting torch<2.0.0,>=1.0.1.post2 (from laserembeddings)
#   Downloading torch-1.13.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting transliterate==1.10.2 (from laserembeddings)
#   Downloading transliterate-1.10.2-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from sacremoses==0.0.35->laserembeddings) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sacremoses==0.0.35->laserembeddings) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses==0.0.35->laserembeddings) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sacremoses==0.0.35->laserembeddings) (4.67.1)
# Collecting mock (from subword-nmt<0.4.0,>=0.3.6->laserembeddings)
#   Downloading mock-5.2.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch<2.0.0,>=1.0.1.post2->laserembeddings) (4.12.2)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<2.0.0,>=1.0.1.post2->laserembeddings)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<2.0.0,>=1.0.1.post2->laserembeddings)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<2.0.0,>=1.0.1.post2->laserembeddings)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<2.0.0,>=1.0.1.post2->laserembeddings)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.0.1.post2->laserembeddings) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.0.1.post2->laserembeddings) (0.45.1)
# Downloading laserembeddings-1.1.2-py3-none-any.whl (13 kB)
# Downloading transliterate-1.10.2-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 59.9 MB/s eta 0:00:00
# Downloading subword_nmt-0.3.8-py3-none-any.whl (27 kB)
# Downloading torch-1.13.1-cp311-cp311-manylinux1_x86_64.whl (887.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 1.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 76.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 37.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.4 MB/s eta 0:00:00
# Downloading mock-5.2.0-py3-none-any.whl (31 kB)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.35-py3-none-any.whl size=883961 sha256=65aac17f5487fb2e122c9be3f9eebd6220203812223bebe77f97d07bf6b407cc
#   Stored in directory: /root/.cache/pip/wheels/38/dd/61/9feb9767a39c2d6683b4cf2eb4e568d9c0a8228e9120c80e27
# Successfully built sacremoses
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: transliterate, sacremoses, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, mock, subword-nmt, nvidia-cudnn-cu11, torch, laserembeddings
#   Attempting uninstall: numpy
#     WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: torch
#     WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
#     Found existing installation: torch 2.6.0+cpu
#     Uninstalling torch-2.6.0+cpu:
#       Successfully uninstalled torch-2.6.0+cpu
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# sentence-transformers 3.4.1 requires transformers<5.0.0,>=4.41.0, which is not installed.
# peft 0.14.0 requires transformers, which is not installed.
# torchaudio 2.6.0+cpu requires torch==2.6.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.21.0+cpu requires torch==2.6.0, but you have torch 1.13.1 which is incompatible.
# accelerate 1.5.2 requires torch>=2.0.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed laserembeddings-1.1.2 mock-5.2.0 numpy-1.26.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 sacremoses-0.0.35 subword-nmt-0.3.8 torch-1.13.1 transliterate-1.10.2

# %%
# !python -m laserembeddings download-models
# Out:
# Downloading models into /usr/local/lib/python3.11/dist-packages/laserembeddings/data
#
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/93langs.fcodes
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/93langs.fvocab
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/bilstm.93langs.2018-12-26.pt
#
# ✨ You're all set!

# %%
# !pip install sacrebleu
# Out:
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 2.5 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (1.26.4)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.3.1)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 5.5 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# Installing collected packages: portalocker, colorama, sacrebleu
# WARNING: Ignoring invalid distribution ~ransformers (/usr/local/lib/python3.11/dist-packages)
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1

# %%
# !pip uninstall numpy -y
# !pip install numpy --no-cache-dir
# !pip install --upgrade --no-cache-dir transformers
# Out:
# Found existing installation: numpy 2.2.4
# Uninstalling numpy-2.2.4:
#   Successfully uninstalled numpy-2.2.4
# Collecting numpy
#   Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.0 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 247.5 MB/s eta 0:00:00
# Installing collected packages: numpy
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# laserembeddings 1.1.2 requires numpy<2.0.0,>=1.15.4, but you have numpy 2.2.4 which is incompatible.
# torchvision 0.21.0+cpu requires torch==2.6.0, but you have torch 1.13.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.4 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.4 which is incompatible.
# accelerate 1.5.2 requires torch>=2.0.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed numpy-2.2.4
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
import sacrebleu
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cosine

# File paths
original_file = "/content/gemma-2b-it_recipes.txt"  # Original English recipes
back_translated_file = "back_translated_recipe.txt"  # Back-translated English recipes

# Read files
with open(original_file, "r", encoding="utf-8") as f:
    original_recipes = [line.strip() for line in f.readlines() if line.strip()]

with open(back_translated_file, "r", encoding="utf-8") as f:
    back_translated_recipes = [line.strip() for line in f.readlines() if line.strip()]

# Ensure both files have the same number of lines
assert len(original_recipes) == len(back_translated_recipes), "Mismatch in number of lines!"

# BLEU Score Evaluation
bleu = sacrebleu.corpus_bleu(back_translated_recipes, [original_recipes])
print(f"\nBLEU Score: {bleu.score:.2f}")

# CHRF Score Evaluation
chrf = sacrebleu.corpus_chrf(back_translated_recipes, [original_recipes])
print(f"CHRF Score: {chrf.score:.2f}")

# Cosine Similarity Evaluation using LaBSE
model = SentenceTransformer("sentence-transformers/LaBSE")

def get_similarity(text1, text2):
    emb1 = model.encode(text1, convert_to_tensor=True)
    emb2 = model.encode(text2, convert_to_tensor=True)
    return 1 - cosine(emb1, emb2)

# Compute similarity for all recipes
similarities = [get_similarity(orig, back) for orig, back in zip(original_recipes, back_translated_recipes)]
average_similarity = sum(similarities) / len(similarities)

print(f"Average Cosine Similarity: {average_similarity:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1975         try:
# -> 1976             return importlib.import_module("." + module_name, self.__name__)
#    1977         except Exception as e:
#
# /usr/lib/python3.11/importlib/__init__.py in import_module(name, package)
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.11/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer_callback.py in <module>
#      27 from .trainer_utils import HPSearchBackend, IntervalStrategy, SaveStrategy, has_length
# ---> 28 from .training_args import TrainingArguments
#      29 from .utils import logging
#
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py in <module>
#      78
# ---> 79     from .trainer_pt_utils import AcceleratorConfig
#      80
#
# /usr/local/lib/python3.11/dist-packages/transformers/trainer_pt_utils.py in <module>
#      57 if is_torch_available():
# ---> 58     from torch.optim.lr_scheduler import LRScheduler
#      59
#
# ImportError: cannot import name 'LRScheduler' from 'torch.optim.lr_scheduler' (/usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-1f4dd145a5e2> in <cell line: 0>()
#       1 import sacrebleu
# ----> 2 from sentence_transformers import SentenceTransformer
#       3 from scipy.spatial.distance import cosine
#       4
#       5 # File paths
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/__init__.py in <module>
#      12     export_static_quantized_openvino_model,
#      13 )
# ---> 14 from sentence_transformers.cross_encoder.CrossEncoder import CrossEncoder
#      15 from sentence_transformers.datasets import ParallelSentencesDataset, SentencesDataset
#      16 from sentence_transformers.LoggingHandler import LoggingHandler
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/__init__.py in <module>
#       1 from __future__ import annotations
#       2
# ----> 3 from .CrossEncoder import CrossEncoder
#       4
#       5 __all__ = ["CrossEncoder"]
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py in <module>
#      18 from sentence_transformers.evaluation.SentenceEvaluator import SentenceEvaluator
#      19 from sentence_transformers.readers import InputExample
# ---> 20 from sentence_transformers.SentenceTransformer import SentenceTransformer
#      21 from sentence_transformers.util import fullname, get_device_name, import_from_string
#      22
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/SentenceTransformer.py in <module>
#      31 from transformers.dynamic_module_utils import get_class_from_dynamic_module, get_relative_import_files
#      32
# ---> 33 from sentence_transformers.model_card import SentenceTransformerModelCardData, generate_model_card
#      34 from sentence_transformers.similarity_functions import SimilarityFunction
#      35
#
# /usr/local/lib/python3.11/dist-packages/sentence_transformers/model_card.py in <module>
#      22 from torch import nn
#      23 from tqdm.autonotebook import tqdm
# ---> 24 from transformers import TrainerCallback
#      25 from transformers.integrations import CodeCarbonCallback
#      26 from transformers.modelcard import make_markdown_table
#
# /usr/lib/python3.11/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in __getattr__(self, name)
#    1962             value = Placeholder
#    1963         elif name in self._class_to_module.keys():
# -> 1964             module = self._get_module(self._class_to_module[name])
#    1965             value = getattr(module, name)
#    1966         elif name in self._modules:
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/import_utils.py in _get_module(self, module_name)
#    1976             return importlib.import_module("." + module_name, self.__name__)
#    1977         except Exception as e:
# -> 1978             raise RuntimeError(
#    1979                 f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1980                 f" traceback):\n{e}"
#
# RuntimeError: Failed to import transformers.trainer_callback because of the following error (look up to see its traceback):
# cannot import name 'LRScheduler' from 'torch.optim.lr_scheduler' (/usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py)

# %%
import torch
from transformers import AutoModel, AutoTokenizer
import numpy as np
from sentence_transformers import SentenceTransformer
from laserembeddings import Laser
from sklearn.metrics.pairwise import cosine_similarity

# Load Recipe Texts
def load_text(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        return [line.strip() for line in f.readlines() if line.strip()]

# Load English and Hindi recipes
english_recipes = load_text("/content/gemma-2b-it_recipes.txt")
hindi_recipes = load_text("/content/translated_recipe_hi.txt")

assert len(english_recipes) == len(hindi_recipes), "Mismatch in number of recipes!"

# ------------------- LaBSE -------------------
def get_labse_embeddings(sentences):
    model_name = "sentence-transformers/LaBSE"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)

    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1)  # Average pooling
    return embeddings.numpy()

# ------------------- XLM-R -------------------
def get_xlmr_embeddings(sentences):
    model_name = "xlm-roberta-large"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)

    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1)  # Average pooling
    return embeddings.numpy()

# ------------------- LASER -------------------
def get_laser_embeddings(sentences):
    laser = Laser()
    return laser.embed_sentences(sentences, lang="en")  # Detects language automatically

# ------------------- Compute Similarity -------------------
def compute_similarity(embeddings1, embeddings2):
    return cosine_similarity(embeddings1, embeddings2).diagonal()

# ------------------- Run All Models -------------------
labse_en = get_labse_embeddings(english_recipes)
labse_hi = get_labse_embeddings(hindi_recipes)
labse_sim = compute_similarity(labse_en, labse_hi)

xlmr_en = get_xlmr_embeddings(english_recipes)
xlmr_hi = get_xlmr_embeddings(hindi_recipes)
xlmr_sim = compute_similarity(xlmr_en, xlmr_hi)

laser_en = get_laser_embeddings(english_recipes)
laser_hi = get_laser_embeddings(hindi_recipes)
laser_sim = compute_similarity(laser_en, laser_hi)

# ------------------- Display Results -------------------
for i, (eng, hin, s1, s2, s3) in enumerate(zip(english_recipes, hindi_recipes, labse_sim, xlmr_sim, laser_sim)):
    print(f"🔹 Recipe {i+1}")
    print(f"   English: {eng}")
    print(f"   Hindi: {hin}")
    print(f"   🔹 LaBSE Similarity: {s1:.4f}")
    print(f"   🔹 XLM-R Similarity: {s2:.4f}")s
    print(f"   🔹 LASER Similarity: {s3:.4f}")
    print("-" * 50)

# ------------------- Summary -------------------
print("\n✅ Average Similarity Scores:")
print(f"   🔹 LaBSE: {np.mean(labse_sim):.4f}")
print(f"   🔹 XLM-R: {np.mean(xlmr_sim):.4f}")
print(f"   🔹 LASER: {np.mean(laser_sim):.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/804 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/5.22M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.62M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# 🔹 Recipe 1
#    English: Recipe 1:
#    Hindi: रेसिपि 1:
#    🔹 LaBSE Similarity: 0.8706
#    🔹 XLM-R Similarity: 0.9959
#    🔹 LASER Similarity: 0.8752
# --------------------------------------------------
# 🔹 Recipe 2
#    English: **The Dish:**
#    Hindi: ** दिश:
#    🔹 LaBSE Similarity: 0.8687
#    🔹 XLM-R Similarity: 0.9965
#    🔹 LASER Similarity: 0.7350
# --------------------------------------------------
# 🔹 Recipe 3
#    English: **Spicy Carrot Bread with Strawberry Glaze**
#    Hindi: ** ट्रॉर्मरी ग्लाइडर के साथ रोटी
#    🔹 LaBSE Similarity: 0.8201
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7622
# --------------------------------------------------
# 🔹 Recipe 4
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 5
#    English: * 1 loaf (12 slices) bread, sliced into 1/2-inch thick slices
#    Hindi: * 1 रोटी (12 स्लाइस) की रोटी, जो 1/2 मोटी स्लाइसों में विभाजित थी
#    🔹 LaBSE Similarity: 0.9416
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.8707
# --------------------------------------------------
# 🔹 Recipe 6
#    English: * 1 large carrot, diced
#    Hindi: * 1 बड़ा काररोट, पॉड
#    🔹 LaBSE Similarity: 0.8704
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.8126
# --------------------------------------------------
# 🔹 Recipe 7
#    English: * 1/2 cup chocolate chips
#    Hindi: * 1/2 कप चिप
#    🔹 LaBSE Similarity: 0.8759
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8714
# --------------------------------------------------
# 🔹 Recipe 8
#    English: * 1 tablespoon flour
#    Hindi: * 1 मेज़ के मैदा
#    🔹 LaBSE Similarity: 0.8895
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.7020
# --------------------------------------------------
# 🔹 Recipe 9
#    English: * 1 tablespoon green_beans, chopped
#    Hindi: * 1 मेज़ें हरे रंग की हैं ।
#    🔹 LaBSE Similarity: 0.7717
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.6315
# --------------------------------------------------
# 🔹 Recipe 10
#    English: * 1 tablespoon ground_beef
#    Hindi: * 1 मेज़ोपोल्फ (_b)
#    🔹 LaBSE Similarity: 0.7671
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7860
# --------------------------------------------------
# 🔹 Recipe 11
#    English: * 1/2 lime, juiced
#    Hindi: * 1/2 पकाई, रसद
#    🔹 LaBSE Similarity: 0.9384
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.8408
# --------------------------------------------------
# 🔹 Recipe 12
#    English: * 1/4 cup strawberries, diced
#    Hindi: * 1/4 कपीबर, पॉग्ड
#    🔹 LaBSE Similarity: 0.8869
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.7670
# --------------------------------------------------
# 🔹 Recipe 13
#    English: * 1 tablespoon sugars
#    Hindi: [ पेज 1 पर बक्स / तसवीर]
#    🔹 LaBSE Similarity: 0.5777
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.6248
# --------------------------------------------------
# 🔹 Recipe 14
#    English: * 1 tablespoon tomato paste
#    Hindi: * 1 रापोटेप की पेस्ट
#    🔹 LaBSE Similarity: 0.8398
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.7691
# --------------------------------------------------
# 🔹 Recipe 15
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 16
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
#    🔹 LaBSE Similarity: 0.8518
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8434
# --------------------------------------------------
# 🔹 Recipe 17
#    English: 2. In a large skillet, cook the carrot and green_beans over medium heat until tender and slightly browned.
#    Hindi: 2 बड़े कौशल के साथ, मिरोचट और हरा हरे रंग का बना लीजिए, जब तक कि गर्मी कम न हो जाए और कम - से - कम भूरे रंग के हो जाएँ ।
#    🔹 LaBSE Similarity: 0.7657
#    🔹 XLM-R Similarity: 0.9953
#    🔹 LASER Similarity: 0.7891
# --------------------------------------------------
# 🔹 Recipe 18
#    English: 3. Add the ground_beef to the skillet and cook until browned.
#    Hindi: इसके अलावा, उन्हें अच्छी तरह से तैयार किया जाता है ।
#    🔹 LaBSE Similarity: 0.3770
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.3579
# --------------------------------------------------
# 🔹 Recipe 19
#    English: 4. Add the lime juice, strawberries, and sugars to the skillet and simmer for 5 minutes.
#    Hindi: इसके अलावा, यह रस रस, स्टीबर और चीनी को 5 मिनट तक इस्तेमाल किया जाता है ।
#    🔹 LaBSE Similarity: 0.7810
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7102
# --------------------------------------------------
# 🔹 Recipe 20
#    English: 5. Spread the mixture evenly over the bread slices.
#    Hindi: 5 रोटी के टुकड़े के ऊपर भी मिश्रण का प्रचार कीजिए ।
#    🔹 LaBSE Similarity: 0.8393
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.7261
# --------------------------------------------------
# 🔹 Recipe 21
#    English: 6. Bake for 10 minutes, or until the bread is golden brown and the filling is cooked through.
#    Hindi: या जब तक रोटी सोने के भूरे भूरे भूरे रंग की होती है और उसे अच्छी तरह तैयार किया जाता है ।
#    🔹 LaBSE Similarity: 0.6911
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.7236
# --------------------------------------------------
# 🔹 Recipe 22
#    English: 7. Serve with a drizzle of strawberry glaze.
#    Hindi: 7 स्टॉंबर फ़ॉयर की फुहार के साथ सेवा कीजिए ।
#    🔹 LaBSE Similarity: 0.8310
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 23
#    English: **Tips:**
#    Hindi: ** एजेंट:
#    🔹 LaBSE Similarity: 0.7356
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7030
# --------------------------------------------------
# 🔹 Recipe 24
#    English: * For a richer bread, use high-quality bread.
#    Hindi: * एक बड़ी रोटी के लिए, बड़ी मात्रा में रोटी का इस्तेमाल कीजिए ।
#    🔹 LaBSE Similarity: 0.8122
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.8291
# --------------------------------------------------
# 🔹 Recipe 25
#    English: * To make a gluten-free bread, use gluten-free flour.
#    Hindi: * एक खाली रोटी बनाने के लिए, Galln- fon- फ्री मैदा इस्तेमाल करें.
#    🔹 LaBSE Similarity: 0.8365
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.8393
# --------------------------------------------------
# 🔹 Recipe 26
#    English: * Serve with a side of your favorite dipping sauce, such as ranch dressing or pesto.
#    Hindi: * अपने पसंदीदा पानी के एक तरफ रहकर सेवा कीजिए, जैसे कपड़े धोना या पेशाब करना ।
#    🔹 LaBSE Similarity: 0.6746
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7959
# --------------------------------------------------
# 🔹 Recipe 27
#    English: Recipe 2:
#    Hindi: रेसिपि 2:
#    🔹 LaBSE Similarity: 0.8710
#    🔹 XLM-R Similarity: 0.9964
#    🔹 LASER Similarity: 0.8723
# --------------------------------------------------
# 🔹 Recipe 28
#    English: **Beef and Vegetable Stir-Fry with Sweet and Spicy Glaze**
#    Hindi: ** बेटफ और वेटर्मर- फ़िटरी के साथ मीठा और स्पीज के साथ
#    🔹 LaBSE Similarity: 0.7905
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8071
# --------------------------------------------------
# 🔹 Recipe 29
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 30
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 मेज़ी जैतून के तेल
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7365
# --------------------------------------------------
# 🔹 Recipe 31
#    English: * 1 pound beef, thinly sliced
#    Hindi: * 1 किलो केक, पतली बालों का टुकड़ा
#    🔹 LaBSE Similarity: 0.7709
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.7618
# --------------------------------------------------
# 🔹 Recipe 32
#    English: * 1 tablespoon chopped onion, diced
#    Hindi: * 1 पॉंडोन पर कब्ज़ा किया गया, ओनेड
#    🔹 LaBSE Similarity: 0.6859
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7330
# --------------------------------------------------
# 🔹 Recipe 33
#    English: * 1 tablespoon chopped carrots, diced
#    Hindi: * 1 मेज़ोनेड्‌स, पॉलैंड
#    🔹 LaBSE Similarity: 0.6838
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.7100
# --------------------------------------------------
# 🔹 Recipe 34
#    English: * 1 tablespoon chopped chicken, diced
#    Hindi: * 1 मेज़ों में मुर्गी का गोश्‍त, ओनेड
#    🔹 LaBSE Similarity: 0.8518
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.6772
# --------------------------------------------------
# 🔹 Recipe 35
#    English: * 1 tablespoon chopped ground beef
#    Hindi: * 1 मेज़ों से ज़मीन के टुकड़े
#    🔹 LaBSE Similarity: 0.8045
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.6330
# --------------------------------------------------
# 🔹 Recipe 36
#    English: * 1 tablespoon chopped spinach
#    Hindi: * 1 मेज़ों के छेदे की घंटी
#    🔹 LaBSE Similarity: 0.7750
#    🔹 XLM-R Similarity: 0.9965
#    🔹 LASER Similarity: 0.6516
# --------------------------------------------------
# 🔹 Recipe 37
#    English: * 1 tablespoon chopped strawberries
#    Hindi: * 1 मेज़ों की स्टॉथियाँ
#    🔹 LaBSE Similarity: 0.7617
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.6593
# --------------------------------------------------
# 🔹 Recipe 38
#    English: * 1 tablespoon sugar
#    Hindi: * 1 मेज़ोटोन चीनी
#    🔹 LaBSE Similarity: 0.7550
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.7413
# --------------------------------------------------
# 🔹 Recipe 39
#    English: * 1 tablespoon soy sauce
#    Hindi: * 1 मेज़ोटोन सोपोन
#    🔹 LaBSE Similarity: 0.7499
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.7588
# --------------------------------------------------
# 🔹 Recipe 40
#    English: * 1 tablespoon honey
#    Hindi: [ पेज 1 पर बक्स]
#    🔹 LaBSE Similarity: 0.5463
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.6096
# --------------------------------------------------
# 🔹 Recipe 41
#    English: * 1 tablespoon sesame oil
#    Hindi: * 1 मेज़ोलीन तेल
#    🔹 LaBSE Similarity: 0.8275
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7456
# --------------------------------------------------
# 🔹 Recipe 42
#    English: * 1 tablespoon ground black pepper
#    Hindi: * 1 मैक्लोटोन जमीन काली मिर्च
#    🔹 LaBSE Similarity: 0.8364
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8022
# --------------------------------------------------
# 🔹 Recipe 43
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 44
#    English: 1. Heat the olive oil in a large skillet or wok over medium-high heat.
#    Hindi: 1. जलपाई का तेल एक बड़े कौशल में या मध्यम गर्मी में रखता है.
#    🔹 LaBSE Similarity: 0.8411
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8255
# --------------------------------------------------
# 🔹 Recipe 45
#    English: 2. Add the beef and cook until browned on all sides.
#    Hindi: 2 मांस और पकाओ... ... सभी पक्ष में भूरे रंग तक.
#    🔹 LaBSE Similarity: 0.7972
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7597
# --------------------------------------------------
# 🔹 Recipe 46
#    English: 3. Add the onion, carrots, and chicken to the skillet and cook until tender and slightly browned.
#    Hindi: इसके अलावा, जब तक कि छोटे - छोटे भूरे - भूरे और भूरे रंग के हो जाते हैं, मुर्गी और मुर्गी का स्वाद बढ़ जाता है ।
#    🔹 LaBSE Similarity: 0.6595
#    🔹 XLM-R Similarity: 0.9965
#    🔹 LASER Similarity: 0.6909
# --------------------------------------------------
# 🔹 Recipe 47
#    English: 4. Add the ground beef, spinach, and strawberries to the skillet and cook until heated through.
#    Hindi: इसके अलावा, इन्हें गरम रखने के लिए इन्हें अच्छी तरह से तैयार किया जाता है ।
#    🔹 LaBSE Similarity: 0.4509
#    🔹 XLM-R Similarity: 0.9959
#    🔹 LASER Similarity: 0.4709
# --------------------------------------------------
# 🔹 Recipe 48
#    English: 5. In a small bowl, whisk together the sugar, soy sauce, honey, and sesame oil.
#    Hindi: 5 एक छोटे कटोरे में चीनी, सोकी, मधु, और उसी तरह का तेल इकट्ठे किया जाता है ।
#    🔹 LaBSE Similarity: 0.8745
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.7455
# --------------------------------------------------
# 🔹 Recipe 49
#    English: 6. Add the sauce to the skillet and cook until heated through.
#    Hindi: जब तक कि गरम नहीं हो जाता, तब तक काम करने के लिए काम कीजिए ।
#    🔹 LaBSE Similarity: 0.5335
#    🔹 XLM-R Similarity: 0.9961
#    🔹 LASER Similarity: 0.5076
# --------------------------------------------------
# 🔹 Recipe 50
#    English: 7. Serve over rice and garnish with fresh cilantro.
#    Hindi: 7 चावल और लचीली के साथ मिलकर काम कीजिए ।
#    🔹 LaBSE Similarity: 0.6972
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.6644
# --------------------------------------------------
# 🔹 Recipe 51
#    English: Recipe 3:
#    Hindi: रेसिपि ३:
#    🔹 LaBSE Similarity: 0.8573
#    🔹 XLM-R Similarity: 0.9965
#    🔹 LASER Similarity: 0.8683
# --------------------------------------------------
# 🔹 Recipe 52
#    English: **Beef and Green Bean Stuffed Sweet Potatoes**
#    Hindi: ** बेनेफ और हरा बीज़ेन में मीठा पानी भरा हुआ माल
#    🔹 LaBSE Similarity: 0.7936
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.7181
# --------------------------------------------------
# 🔹 Recipe 53
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 54
#    English: * 2 tablespoons of butter
#    Hindi: * मक्खन की 2 पटियाएँ
#    🔹 LaBSE Similarity: 0.9077
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8096
# --------------------------------------------------
# 🔹 Recipe 55
#    English: * 1 large egg, beaten
#    Hindi: * 1 बड़े अंडे, पीटा
#    🔹 LaBSE Similarity: 0.9689
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.9099
# --------------------------------------------------
# 🔹 Recipe 56
#    English: * 1/2 cup of chopped green beans
#    Hindi: * 1/2 कप हरीकेन का कप
#    🔹 LaBSE Similarity: 0.8903
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8045
# --------------------------------------------------
# 🔹 Recipe 57
#    English: * 1 pound of ground beef
#    Hindi: * ज़मीन के एक पाउंड
#    🔹 LaBSE Similarity: 0.8177
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7700
# --------------------------------------------------
# 🔹 Recipe 58
#    English: * 1/2 cup of chopped mushrooms
#    Hindi: * 1/2 कप में बड़े - बड़े मशगूल होते हैं
#    🔹 LaBSE Similarity: 0.8579
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7195
# --------------------------------------------------
# 🔹 Recipe 59
#    English: * 1/4 cup of chopped onions
#    Hindi: [ पेज 29 पर बड़े अक्षरों में लेख की खास बात]
#    🔹 LaBSE Similarity: 0.4154
#    🔹 XLM-R Similarity: 0.9957
#    🔹 LASER Similarity: 0.5008
# --------------------------------------------------
# 🔹 Recipe 60
#    English: * 1/4 cup of chopped spinach
#    Hindi: [ पेज 29 पर बड़े अक्षरों में लेख की खास बात]
#    🔹 LaBSE Similarity: 0.4308
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.5170
# --------------------------------------------------
# 🔹 Recipe 61
#    English: * 1/4 cup of chopped strawberries
#    Hindi: * 1/4 पन्‍ने की झीलों का कप
#    🔹 LaBSE Similarity: 0.8410
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7947
# --------------------------------------------------
# 🔹 Recipe 62
#    English: * 1/2 cup of heavy cream
#    Hindi: * 1/2 कप जो भारी है
#    🔹 LaBSE Similarity: 0.8749
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.8115
# --------------------------------------------------
# 🔹 Recipe 63
#    English: * 1 tablespoon of chopped fresh parsley
#    Hindi: * 1 नए सिरे के क्लैम्पली की पटियाएँ
#    🔹 LaBSE Similarity: 0.7312
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7270
# --------------------------------------------------
# 🔹 Recipe 64
#    English: * Salt and pepper to taste
#    Hindi: * नमक और काली मिर्च का स्वाद लेने के लिए
#    🔹 LaBSE Similarity: 0.8893
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.6348
# --------------------------------------------------
# 🔹 Recipe 65
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 66
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
#    🔹 LaBSE Similarity: 0.8518
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8434
# --------------------------------------------------
# 🔹 Recipe 67
#    English: 2. In a large skillet over medium heat, melt the butter.
#    Hindi: 2. मीडिया गर्मी पर एक बड़े कौशल में, मक्खन पिघल जाता है.
#    🔹 LaBSE Similarity: 0.8385
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.8636
# --------------------------------------------------
# 🔹 Recipe 68
#    English: 3. Add the egg and cook until cooked through.
#    Hindi: 3 अंडे और खाना दीजिए, जब तक कि उसे पका न हो ।
#    🔹 LaBSE Similarity: 0.8223
#    🔹 XLM-R Similarity: 0.9962
#    🔹 LASER Similarity: 0.7574
# --------------------------------------------------
# 🔹 Recipe 69
#    English: 4. Add the green beans, mushrooms, onions, and spinach to the skillet and cook until tender.
#    Hindi: इसके अलावा, ये फल - फूल - फूलकर छोटे - छोटे पौधे भी तैयार करते हैं ।
#    🔹 LaBSE Similarity: 0.4744
#    🔹 XLM-R Similarity: 0.9956
#    🔹 LASER Similarity: 0.6547
# --------------------------------------------------
# 🔹 Recipe 70
#    English: 5. Add the ground beef to the skillet and cook until browned.
#    Hindi: 5 भूरे रंग के जीव को अच्छी तरह पकाइए और अच्छी तरह पकाइए ।
#    🔹 LaBSE Similarity: 0.6984
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.6515
# --------------------------------------------------
# 🔹 Recipe 71
#    English: 6. Add the heavy cream, parsley, salt, and pepper to the skillet and simmer for 5 minutes.
#    Hindi: 6. भारी आइसक्रीम, पर्सली, नमक और काली मिर्च को 5 मिनट के लिए इस्तेमाल करते हैं ।
#    🔹 LaBSE Similarity: 0.8683
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.8083
# --------------------------------------------------
# 🔹 Recipe 72
#    English: 7. Transfer the filling to a baking dish.
#    Hindi: 7. खाना पकाने के लिए तैयार कीजिए ।
#    🔹 LaBSE Similarity: 0.6280
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.5835
# --------------------------------------------------
# 🔹 Recipe 73
#    English: 8. Top with the sweet potatoes and bake for 20 minutes, or until the potatoes are golden brown and the filling is heated through.
#    Hindi: यह बहुत ही मीठा आलू है और 20 मिनट तक पका रहता है, या जब तक आलू सुनहरे भूरे भूरे रंग की होती है और उसे गरम नहीं किया जाता ।
#    🔹 LaBSE Similarity: 0.7437
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.7986
# --------------------------------------------------
# 🔹 Recipe 74
#    English: 9. Serve immediately.
#    Hindi: 9. तुरंत सेवा कीजिए ।
#    🔹 LaBSE Similarity: 0.9257
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8750
# --------------------------------------------------
# 🔹 Recipe 75
#    English: Recipe 4:
#    Hindi: रेसिपि 4:
#    🔹 LaBSE Similarity: 0.8805
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.8715
# --------------------------------------------------
# 🔹 Recipe 76
#    English: **Blueberry Bread with Sweet Potato Filling**
#    Hindi: ** मेलिया भरने के साथ ब्लूबेरी रोटी
#    🔹 LaBSE Similarity: 0.8837
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7836
# --------------------------------------------------
# 🔹 Recipe 77
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 78
#    English: * 1 loaf (1 pound) white bread, sliced into 1-inch thick slices
#    Hindi: * 1 रोटी (1 किलो) सफेद रोटी, जो 1 इंच मोटी होती है
#    🔹 LaBSE Similarity: 0.9224
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8489
# --------------------------------------------------
# 🔹 Recipe 79
#    English: * 1 cup blueberries
#    Hindi: * 1 कपीबर
#    🔹 LaBSE Similarity: 0.8719
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.7013
# --------------------------------------------------
# 🔹 Recipe 80
#    English: * 1/2 cup sugar
#    Hindi: * 1/2 कप चीनी
#    🔹 LaBSE Similarity: 0.9269
#    🔹 XLM-R Similarity: 0.9990
#    🔹 LASER Similarity: 0.8348
# --------------------------------------------------
# 🔹 Recipe 81
#    English: * 1/4 teaspoon salt
#    Hindi: * 1/4 चाय - नमक
#    🔹 LaBSE Similarity: 0.9356
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7070
# --------------------------------------------------
# 🔹 Recipe 82
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चाय काली मिर्च
#    🔹 LaBSE Similarity: 0.9391
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7533
# --------------------------------------------------
# 🔹 Recipe 83
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 मेज़ी जैतून के तेल
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7365
# --------------------------------------------------
# 🔹 Recipe 84
#    English: * 1/2 teaspoon vanilla extract
#    Hindi: * 1/2 चाय के पौधों का पता लगाने के लिए
#    🔹 LaBSE Similarity: 0.7269
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.6574
# --------------------------------------------------
# 🔹 Recipe 85
#    English: * 1/4 cup chopped onion
#    Hindi: [ पेज 29 पर तसवीर]
#    🔹 LaBSE Similarity: 0.3978
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.4852
# --------------------------------------------------
# 🔹 Recipe 86
#    English: * 1/2 cup chopped spinach
#    Hindi: * 1/2 कप केक
#    🔹 LaBSE Similarity: 0.7825
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.7659
# --------------------------------------------------
# 🔹 Recipe 87
#    English: * 1/4 cup chopped strawberries
#    Hindi: * 1/4 कप्डेदार स्टीबर
#    🔹 LaBSE Similarity: 0.8626
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7385
# --------------------------------------------------
# 🔹 Recipe 88
#    English: * 1/4 cup chocolate chips
#    Hindi: * 1/4 कप चॉकलेट्स
#    🔹 LaBSE Similarity: 0.9553
#    🔹 XLM-R Similarity: 0.9983
#    🔹 LASER Similarity: 0.9144
# --------------------------------------------------
# 🔹 Recipe 89
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 90
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
#    🔹 LaBSE Similarity: 0.8518
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8434
# --------------------------------------------------
# 🔹 Recipe 91
#    English: 2. In a large bowl, combine the bread slices, blueberries, sugar, salt, and black pepper.
#    Hindi: 2 बड़े - बड़े कटोरे में, रोटी के टुकड़े, नीले रंग की घास, चीनी, नमक और काली मिर्च साथ दीजिए ।
#    🔹 LaBSE Similarity: 0.8300
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8373
# --------------------------------------------------
# 🔹 Recipe 92
#    English: 3. In a separate bowl, whisk together the olive oil, vanilla extract, onion, spinach, and strawberries.
#    Hindi: एक अलग कटोरे में जैतून का तेल, वैनीला का फलना - फूलना, खेती - बाड़ी करना और स्टूचियाँ साथ - साथ सुखाया जाता है ।
#    🔹 LaBSE Similarity: 0.7485
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7698
# --------------------------------------------------
# 🔹 Recipe 93
#    English: 4. Add the wet ingredients to the dry ingredients and stir until just combined. Do not overmix.
#    Hindi: 4 सूखे पदार्थों को जोड़िए और उन्हें हिलाइए, जब तक कि सिर्फ एक - दूसरे से जुदा न हो जाए ।
#    🔹 LaBSE Similarity: 0.8229
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.7415
# --------------------------------------------------
# 🔹 Recipe 94
#    English: 5. Pour the batter into a greased 9x13-inch baking dish.
#    Hindi: 5. तेलित 9x13-घन खाना में बल्ले.
#    🔹 LaBSE Similarity: 0.8536
#    🔹 XLM-R Similarity: 0.9961
#    🔹 LASER Similarity: 0.8269
# --------------------------------------------------
# 🔹 Recipe 95
#    English: 6. Bake for 30-35 minutes, or until the bread is golden brown and the filling is set.
#    Hindi: 6. 3035 मिनट के लिए बकक, या जब तक रोटी सोने के भूरे रंग की होती है और भर दिया जाता है.
#    🔹 LaBSE Similarity: 0.8063
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.8249
# --------------------------------------------------
# 🔹 Recipe 96
#    English: 7. Serve warm with a scoop of vanilla ice cream or whipped cream.
#    Hindi: 7 खजूर की आइसक्रीम से गर्म रहिए ।
#    🔹 LaBSE Similarity: 0.6996
#    🔹 XLM-R Similarity: 0.9964
#    🔹 LASER Similarity: 0.7127
# --------------------------------------------------
# 🔹 Recipe 97
#    English: Recipe 5:
#    Hindi: रेसिपि 5:
#    🔹 LaBSE Similarity: 0.8792
#    🔹 XLM-R Similarity: 0.9964
#    🔹 LASER Similarity: 0.8637
# --------------------------------------------------
# 🔹 Recipe 98
#    English: **Chicken and Sweet Potato Hash with Chocolate Glaze**
#    Hindi: ** Cokiken और मीठा आलू हैकलेटिन के साथ
#    🔹 LaBSE Similarity: 0.7536
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.7574
# --------------------------------------------------
# 🔹 Recipe 99
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 100
#    English: * 1 loaf of bread, sliced into 1/2-inch thick slices
#    Hindi: * 1 रोटी का एक टुकड़ा, जो 1/2-inch मोटी स्लाइस में काटा गया था
#    🔹 LaBSE Similarity: 0.9343
#    🔹 XLM-R Similarity: 0.9961
#    🔹 LASER Similarity: 0.8550
# --------------------------------------------------
# 🔹 Recipe 101
#    English: * 1/2 pound of chicken breast, cut into 1-inch cubes
#    Hindi: * 1/2 किलो मुर्गी स्तन, 1-inch के घनों में कटौती
#    🔹 LaBSE Similarity: 0.9139
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8896
# --------------------------------------------------
# 🔹 Recipe 102
#    English: * 1/4 cup of grated cheese
#    Hindi: * सन्‌ 1/4 में बनायी गयी पनीर का कप
#    🔹 LaBSE Similarity: 0.8554
#    🔹 XLM-R Similarity: 0.9965
#    🔹 LASER Similarity: 0.6795
# --------------------------------------------------
# 🔹 Recipe 103
#    English: * 1/4 cup of chopped chocolate
#    Hindi: * 1/4 कप जो चॉकलेट का कप है
#    🔹 LaBSE Similarity: 0.9231
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8641
# --------------------------------------------------
# 🔹 Recipe 104
#    English: * 2 large eggs, beaten
#    Hindi: * 2 बड़े अंडे, पीटा
#    🔹 LaBSE Similarity: 0.9679
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.9228
# --------------------------------------------------
# 🔹 Recipe 105
#    English: * 1/2 cup of chopped potato
#    Hindi: * 1/2 कप ।
#    🔹 LaBSE Similarity: 0.7858
#    🔹 XLM-R Similarity: 0.9961
#    🔹 LASER Similarity: 0.7184
# --------------------------------------------------
# 🔹 Recipe 106
#    English: * 1/4 cup of chopped strawberries
#    Hindi: * 1/4 पन्‍ने की झीलों का कप
#    🔹 LaBSE Similarity: 0.8410
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7947
# --------------------------------------------------
# 🔹 Recipe 107
#    English: * 1 tablespoon of sugar
#    Hindi: * 1 चीनी की पटियाएँ
#    🔹 LaBSE Similarity: 0.7988
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7258
# --------------------------------------------------
# 🔹 Recipe 108
#    English: * 1 tablespoon of sweet potato, mashed and cooled
#    Hindi: * 1 मीठे पानी की पटियाएँ, साफ - सुथरा और ठंडा
#    🔹 LaBSE Similarity: 0.8013
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8173
# --------------------------------------------------
# 🔹 Recipe 109
#    English: * 1 tablespoon of melted chocolate
#    Hindi: * 1 चॉकलेट की पटियाएँ
#    🔹 LaBSE Similarity: 0.8771
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8054
# --------------------------------------------------
# 🔹 Recipe 110
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 111
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
#    🔹 LaBSE Similarity: 0.8518
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8434
# --------------------------------------------------
# 🔹 Recipe 112
#    English: 2. Toast the bread slices lightly on both sides until golden brown.
#    Hindi: 2, सोने के भूरे रंग के होते तक रोटी के टुकड़े - टुकड़े को हलकी बात समझा जाता है ।
#    🔹 LaBSE Similarity: 0.8227
#    🔹 XLM-R Similarity: 0.9957
#    🔹 LASER Similarity: 0.6828
# --------------------------------------------------
# 🔹 Recipe 113
#    English: 3. In a large skillet over medium heat, cook the chicken for 5-7 minutes per side, or until cooked through.
#    Hindi: 3. मीडिया की गर्मी के दौरान एक बड़े कौशल में, मुर्गी को हर तरफ से 5 मिनट के लिए पकाओ, या जब तक कि पानी भर न जाए.
#    🔹 LaBSE Similarity: 0.8219
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.8289
# --------------------------------------------------
# 🔹 Recipe 114
#    English: 4. Add the cheese, chocolate, eggs, potato, and strawberries to a baking dish.
#    Hindi: इसके अलावा, पनीर, चॉकलेट, अंडे, अंडे, और स्टूबरों को एक स्वादिष्ट व्यंजन में जोड़ दीजिए ।
#    🔹 LaBSE Similarity: 0.7664
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8593
# --------------------------------------------------
# 🔹 Recipe 115
#    English: 5. Pour the chicken over the topping.
#    Hindi: 5. मुर्गी को ऊपर की ओर फैलाओ.
#    🔹 LaBSE Similarity: 0.8564
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.6742
# --------------------------------------------------
# 🔹 Recipe 116
#    English: 6. Bake for 20-25 minutes, or until the chicken is cooked through and the vegetables are tender.
#    Hindi: 6. 20 25 मिनट तक , या जब तक मुर्गी को पकाकर पकाया जाता है और सब्ज़ियाँ कोमल होती हैं.
#    🔹 LaBSE Similarity: 0.8858
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.8634
# --------------------------------------------------
# 🔹 Recipe 117
#    English: 7. Serve with a drizzle of chocolate glaze.
#    Hindi: 7 चॉकलेट ग्रीप की फुहार के साथ सेवा कीजिए ।
#    🔹 LaBSE Similarity: 0.8892
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.7612
# --------------------------------------------------
# 🔹 Recipe 118
#    English: Recipe 6:
#    Hindi: रेसिपि 6:
#    🔹 LaBSE Similarity: 0.8858
#    🔹 XLM-R Similarity: 0.9964
#    🔹 LASER Similarity: 0.8456
# --------------------------------------------------
# 🔹 Recipe 119
#    English: **Blueberry Chicken with Green Bean Mash**
#    Hindi: ** हरे बेसैन के साथ ब्लूबेरी चाउन
#    🔹 LaBSE Similarity: 0.8721
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.7464
# --------------------------------------------------
# 🔹 Recipe 120
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 121
#    English: * 1 pound boneless, skinless chicken breasts, cut into 1-inch pieces
#    Hindi: * 1 किलो हड्डी, त्वचाहीन मुर्गी स्तन, 1 बांच के टुकड़ों में कटौती
#    🔹 LaBSE Similarity: 0.8963
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8627
# --------------------------------------------------
# 🔹 Recipe 122
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 मेज़ी जैतून के तेल
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7365
# --------------------------------------------------
# 🔹 Recipe 123
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चायदार नमक
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.6794
# --------------------------------------------------
# 🔹 Recipe 124
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चाय काली मिर्च
#    🔹 LaBSE Similarity: 0.9391
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7533
# --------------------------------------------------
# 🔹 Recipe 125
#    English: * 1 cup blueberries
#    Hindi: * 1 कपीबर
#    🔹 LaBSE Similarity: 0.8719
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.7013
# --------------------------------------------------
# 🔹 Recipe 126
#    English: * 1 tablespoon lemon juice
#    Hindi: * 1 मेज़ के रस
#    🔹 LaBSE Similarity: 0.8512
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.6457
# --------------------------------------------------
# 🔹 Recipe 127
#    English: * 1 tablespoon butter
#    Hindi: * 1 मेज़ों के मक्खन
#    🔹 LaBSE Similarity: 0.8790
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7566
# --------------------------------------------------
# 🔹 Recipe 128
#    English: * 1 tablespoon flour
#    Hindi: * 1 मेज़ के मैदा
#    🔹 LaBSE Similarity: 0.8895
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.7020
# --------------------------------------------------
# 🔹 Recipe 129
#    English: * 1/2 cup green beans, trimmed and cut into 1-inch pieces
#    Hindi: * 1/2 कप हरा बीन्स, सिलिना और 1 इंच काट
#    🔹 LaBSE Similarity: 0.8931
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8395
# --------------------------------------------------
# 🔹 Recipe 130
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चायदार नमक
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.6794
# --------------------------------------------------
# 🔹 Recipe 131
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चाय काली मिर्च
#    🔹 LaBSE Similarity: 0.9391
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7533
# --------------------------------------------------
# 🔹 Recipe 132
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 133
#    English: 1. Preheat oven to 400 degrees F (200 degrees C).
#    Hindi: 1. प्रीफनेक्यूज से 400 डिग्री F (200 डिग्री सी.)
#    🔹 LaBSE Similarity: 0.8915
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8350
# --------------------------------------------------
# 🔹 Recipe 134
#    English: 2. In a large skillet over medium heat, heat olive oil. Season chicken with salt and pepper. Cook chicken for 5 minutes per side, or until cooked through.
#    Hindi: 2 बड़े कौशल से भरे तेल में, तेल को गरम करता है ।
#    🔹 LaBSE Similarity: 0.6073
#    🔹 XLM-R Similarity: 0.9908
#    🔹 LASER Similarity: 0.6688
# --------------------------------------------------
# 🔹 Recipe 135
#    English: 3. Transfer chicken to a baking dish. Top with blueberries, lemon juice, and butter.
#    Hindi: 3 मुर्गी को स्वादिष्ट खाना दीजिए ।
#    🔹 LaBSE Similarity: 0.5930
#    🔹 XLM-R Similarity: 0.9953
#    🔹 LASER Similarity: 0.5900
# --------------------------------------------------
# 🔹 Recipe 136
#    English: 4. Bake for 20-25 minutes, or until the chicken is cooked through and the blueberries are tender.
#    Hindi: 4. 20 25 मिनट के लिए , या जब तक मुर्गी पकाई जाती है और नीले रंग के पेड़ कोमल होते हैं.
#    🔹 LaBSE Similarity: 0.8443
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.8566
# --------------------------------------------------
# 🔹 Recipe 137
#    English: 5. Serve with green beans and mashed potatoes.
#    Hindi: 5 हरी घास और गिरी हुई आलू के साथ मिलकर सेवा कीजिए ।
#    🔹 LaBSE Similarity: 0.8530
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7118
# --------------------------------------------------
# 🔹 Recipe 138
#    English: **Tips:**
#    Hindi: ** एजेंट:
#    🔹 LaBSE Similarity: 0.7356
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7030
# --------------------------------------------------
# 🔹 Recipe 139
#    English: * For a more flavorful dish, use a variety of different berries, such as raspberries or strawberries.
#    Hindi: * ज़्यादा स्वादप्रद व्यंजनों के लिए, विभिन्‍न प्रकार के व्यंजनों का प्रयोग कीजिए, जैसे राइसबरों या स्टूबरों का ।
#    🔹 LaBSE Similarity: 0.8308
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7952
# --------------------------------------------------
# 🔹 Recipe 140
#    English: * Serve with a dipping sauce, such as a balsamic glaze or a honey mustard sauce.
#    Hindi: * जैसे कि बलसान या राई के दाने के बराबर ।
#    🔹 LaBSE Similarity: 0.7013
#    🔹 XLM-R Similarity: 0.9948
#    🔹 LASER Similarity: 0.6524
# --------------------------------------------------
# 🔹 Recipe 141
#    English: * Serve with a side of crusty bread to soak up the juices.
#    Hindi: * रस को भरने के लिए हरी रोटी की एक तरफ रहकर सेवा कीजिए ।
#    🔹 LaBSE Similarity: 0.7932
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7327
# --------------------------------------------------
# 🔹 Recipe 142
#    English: Recipe 7:
#    Hindi: रेसिपि 7:
#    🔹 LaBSE Similarity: 0.8984
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8554
# --------------------------------------------------
# 🔹 Recipe 143
#    English: **Chicken and Cheese Stuffed Corn with Heavy Cream Sauce**
#    Hindi: **CKKen और चीज सामग्री भारी क्रीम के साथ cratack
#    🔹 LaBSE Similarity: 0.7577
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7368
# --------------------------------------------------
# 🔹 Recipe 144
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 145
#    English: * 1 boneless, skinless chicken breast, cut into 1-inch cubes
#    Hindi: * 1 हड्डीहीन, त्वचाहीन मुर्गी स्तन, 1 सेमी घन में कटौती
#    🔹 LaBSE Similarity: 0.9297
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8140
# --------------------------------------------------
# 🔹 Recipe 146
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 मेज़ी जैतून के तेल
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7365
# --------------------------------------------------
# 🔹 Recipe 147
#    English: * 1 onion, diced
#    Hindi: [ पेज 1 पर तसवीर]
#    🔹 LaBSE Similarity: 0.5823
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.5454
# --------------------------------------------------
# 🔹 Recipe 148
#    English: * 2 cloves garlic, minced
#    Hindi: * 2 cscates, मि.
#    🔹 LaBSE Similarity: 0.7926
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.6872
# --------------------------------------------------
# 🔹 Recipe 149
#    English: * 1/2 teaspoon black pepper
#    Hindi: * 1/2 चाय काली मिर्च
#    🔹 LaBSE Similarity: 0.9312
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7531
# --------------------------------------------------
# 🔹 Recipe 150
#    English: * 1/4 teaspoon salt
#    Hindi: * 1/4 चाय - नमक
#    🔹 LaBSE Similarity: 0.9356
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7070
# --------------------------------------------------
# 🔹 Recipe 151
#    English: * 1/4 cup heavy cream
#    Hindi: * 1/4 कप
#    🔹 LaBSE Similarity: 0.8552
#    🔹 XLM-R Similarity: 0.9964
#    🔹 LASER Similarity: 0.7316
# --------------------------------------------------
# 🔹 Recipe 152
#    English: * 1/2 cup grated mozzarella cheese
#    Hindi: * 1/2 कप का रसाला पनीर
#    🔹 LaBSE Similarity: 0.8451
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.7448
# --------------------------------------------------
# 🔹 Recipe 153
#    English: * 1/2 cup chopped fresh corn
#    Hindi: * 1/2 कप में ताज़ी बालें
#    🔹 LaBSE Similarity: 0.8779
#    🔹 XLM-R Similarity: 0.9983
#    🔹 LASER Similarity: 0.7447
# --------------------------------------------------
# 🔹 Recipe 154
#    English: * 1/2 cup chopped mushrooms
#    Hindi: * 1/2 कप के टुकड़े बहुत बढ़ गए
#    🔹 LaBSE Similarity: 0.8523
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.7407
# --------------------------------------------------
# 🔹 Recipe 155
#    English: * 1/2 teaspoon dried oregano
#    Hindi: * 1/2 चाय सूखेया याgougo
#    🔹 LaBSE Similarity: 0.8844
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8050
# --------------------------------------------------
# 🔹 Recipe 156
#    English: * 1/4 teaspoon salt
#    Hindi: * 1/4 चाय - नमक
#    🔹 LaBSE Similarity: 0.9356
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7070
# --------------------------------------------------
# 🔹 Recipe 157
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चाय काली मिर्च
#    🔹 LaBSE Similarity: 0.9391
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7533
# --------------------------------------------------
# 🔹 Recipe 158
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 159
#    English: 1. Heat olive oil in a large skillet over medium heat.
#    Hindi: 1. जैतून तेल में तेल को गरम धूप से भी ज़्यादा इस्तेमाल किया जा सकता है ।
#    🔹 LaBSE Similarity: 0.7485
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7226
# --------------------------------------------------
# 🔹 Recipe 160
#    English: 2. Season chicken with black pepper and salt.
#    Hindi: 2. गर्म मुर्गी काली मिर्च और नमक के साथ.
#    🔹 LaBSE Similarity: 0.8575
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8232
# --------------------------------------------------
# 🔹 Recipe 161
#    English: 3. Add chicken to the skillet and cook until browned on all sides.
#    Hindi: 3 मुर्गी को हर तरफ भूरे रंग के फूल और पकाइए ।
#    🔹 LaBSE Similarity: 0.7552
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.6801
# --------------------------------------------------
# 🔹 Recipe 162
#    English: 4. Add onion and garlic to the skillet and cook until softened, about 5 minutes.
#    Hindi: इसके अलावा, करीब 5 मिनट के अंदर, काम के लिए अच्छी तरह तैयार हो जाती है और उसे अच्छी तरह तैयार किया जाता है ।
#    🔹 LaBSE Similarity: 0.6327
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.5661
# --------------------------------------------------
# 🔹 Recipe 163
#    English: 5. Add mushrooms and potato to the skillet and cook until tender, about 10 minutes.
#    Hindi: इसके अलावा, करीब 10 मिनट तक बड़े - बड़े हुनर और खाना भी तैयार कीजिए ।
#    🔹 LaBSE Similarity: 0.6768
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7023
# --------------------------------------------------
# 🔹 Recipe 164
#    English: 6. Add heavy cream, mozzarella cheese, and oregano to the skillet.
#    Hindi: 6 भारी आइसक्रीम, मोज़ाएली पनीर, और यागनो को कौशल के साथ जोड़िए ।
#    🔹 LaBSE Similarity: 0.8365
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7906
# --------------------------------------------------
# 🔹 Recipe 165
#    English: 7. Bring to a simmer and cook for 5 minutes, or until the cheese is melted and bubbly.
#    Hindi: 7 एक बोरर और 5 मिनट के लिए खाना लाने के लिए, या जब तक पनीर पिघल जाता है और मोमबती जाती है.
#    🔹 LaBSE Similarity: 0.8840
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8424
# --------------------------------------------------
# 🔹 Recipe 166
#    English: 8. Serve over a bed of roasted corn.
#    Hindi: भोजन के ढेर के ऊपर सेवा कीजिए ।
#    🔹 LaBSE Similarity: 0.6776
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.5826
# --------------------------------------------------
# 🔹 Recipe 167
#    English: Recipe 8:
#    Hindi: रेसिपि 8:
#    🔹 LaBSE Similarity: 0.8932
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8470
# --------------------------------------------------
# 🔹 Recipe 168
#    English: **Chicken and Sweet Potato Hash with Green Beans**
#    Hindi: ** बैरन और स्वीशियम हरा बेरन के साथ हैश
#    🔹 LaBSE Similarity: 0.7901
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.7246
# --------------------------------------------------
# 🔹 Recipe 169
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 170
#    English: * 1 loaf of bread, sliced into 1/2-inch thick slices
#    Hindi: * 1 रोटी का एक टुकड़ा, जो 1/2-inch मोटी स्लाइस में काटा गया था
#    🔹 LaBSE Similarity: 0.9343
#    🔹 XLM-R Similarity: 0.9961
#    🔹 LASER Similarity: 0.8550
# --------------------------------------------------
# 🔹 Recipe 171
#    English: * 1/4 cup of butter
#    Hindi: * 1/4 मक्खन का कप
#    🔹 LaBSE Similarity: 0.9480
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.8806
# --------------------------------------------------
# 🔹 Recipe 172
#    English: * 1/2 pound of chicken_breast, cut into 1-inch pieces
#    Hindi: * 1/2 पाउंड _BAR_ मुर्गी, 1-inch के टुकड़ों में कटौती
#    🔹 LaBSE Similarity: 0.9033
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.9018
# --------------------------------------------------
# 🔹 Recipe 173
#    English: * 1/4 cup of green_beans, trimmed and cut into 1/2-inch pieces
#    Hindi: * 1/4 हरे रंग के कप, डिम्पली और 1/2- hhys में कटौती
#    🔹 LaBSE Similarity: 0.8787
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8423
# --------------------------------------------------
# 🔹 Recipe 174
#    English: * 1/4 cup of chopped strawberries
#    Hindi: * 1/4 पन्‍ने की झीलों का कप
#    🔹 LaBSE Similarity: 0.8410
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7947
# --------------------------------------------------
# 🔹 Recipe 175
#    English: * 1/4 cup of chopped sweet_potato, diced
#    Hindi: * 1/4 के कप में मीठा_ थॉटो, पॉंटो
#    🔹 LaBSE Similarity: 0.8473
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8222
# --------------------------------------------------
# 🔹 Recipe 176
#    English: * 1/4 cup of flour
#    Hindi: * 1/4 फलों का प्याला
#    🔹 LaBSE Similarity: 0.8277
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8833
# --------------------------------------------------
# 🔹 Recipe 177
#    English: * 1/2 teaspoon of salt
#    Hindi: * 1/2 नमक का चाय
#    🔹 LaBSE Similarity: 0.8921
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7032
# --------------------------------------------------
# 🔹 Recipe 178
#    English: * 1/4 teaspoon of black pepper
#    Hindi: * 1/4 काली मिर्च का चाय
#    🔹 LaBSE Similarity: 0.9060
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7464
# --------------------------------------------------
# 🔹 Recipe 179
#    English: * 1/4 cup of milk
#    Hindi: * माँ का दूध
#    🔹 LaBSE Similarity: 0.6763
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.6315
# --------------------------------------------------
# 🔹 Recipe 180
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 181
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. पहले से 0.75 डिग्री F (190 डिग्री सी) तक.
#    🔹 LaBSE Similarity: 0.8518
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8434
# --------------------------------------------------
# 🔹 Recipe 182
#    English: 2. In a large skillet over medium heat, melt the butter.
#    Hindi: 2. मीडिया गर्मी पर एक बड़े कौशल में, मक्खन पिघल जाता है.
#    🔹 LaBSE Similarity: 0.8385
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.8636
# --------------------------------------------------
# 🔹 Recipe 183
#    English: 3. Add the chicken and cook until browned on all sides.
#    Hindi: 3 मुर्गी और खाना दीजिए जब तक कि सभी पक्ष में भूरे रंग के हो जाते हैं ।
#    🔹 LaBSE Similarity: 0.8310
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.7725
# --------------------------------------------------
# 🔹 Recipe 184
#    English: 4. Add the green beans and cook until tender and slightly crisp.
# ...
#    🔹 LASER Similarity: 0.8675
# --------------------------------------------------
# 🔹 Recipe 400
#    English: **Blueberry-Cheese-Green Bean Hash with Potato and Spinach**
#    Hindi: ** ब्लूबर- हरा बेबेन, आलू तथा स्पिनर के साथ हैक
#    🔹 LaBSE Similarity: 0.8405
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8039
# --------------------------------------------------
# 🔹 Recipe 401
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 402
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 मेज़ी जैतून के तेल
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7365
# --------------------------------------------------
# 🔹 Recipe 403
#    English: * 1 onion, diced
#    Hindi: [ पेज 1 पर तसवीर]
#    🔹 LaBSE Similarity: 0.5823
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.5454
# --------------------------------------------------
# 🔹 Recipe 404
#    English: * 1 green bean, diced
#    Hindi: * 1 हरा बेरा, पाँसा फेंकें
#    🔹 LaBSE Similarity: 0.9183
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7234
# --------------------------------------------------
# 🔹 Recipe 405
#    English: * 4 eggs, beaten
#    Hindi: * 4 अंडे, पीटा
#    🔹 LaBSE Similarity: 0.9652
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.9105
# --------------------------------------------------
# 🔹 Recipe 406
#    English: * 1/2 cup shredded cheese
#    Hindi: * 1/2 कप में डाली गयी पनीर
#    🔹 LaBSE Similarity: 0.9062
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7207
# --------------------------------------------------
# 🔹 Recipe 407
#    English: * 1/4 cup chopped blueberries
#    Hindi: * 1/4 कप में नीले रंग की छटियाँ
#    🔹 LaBSE Similarity: 0.8802
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.7868
# --------------------------------------------------
# 🔹 Recipe 408
#    English: * 1 tablespoon lime juice
#    Hindi: * 1 मेज़ के रस
#    🔹 LaBSE Similarity: 0.8908
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.6648
# --------------------------------------------------
# 🔹 Recipe 409
#    English: * 1 tablespoon chopped fresh parsley
#    Hindi: * 1 मैकेन ने नए सिरे तक चीरा - फाड़ डाला
#    🔹 LaBSE Similarity: 0.7093
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.6368
# --------------------------------------------------
# 🔹 Recipe 410
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चायदार नमक
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.6794
# --------------------------------------------------
# 🔹 Recipe 411
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चाय काली मिर्च
#    🔹 LaBSE Similarity: 0.9391
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7533
# --------------------------------------------------
# 🔹 Recipe 412
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 413
#    English: 1. Heat olive oil in a large skillet over medium heat.
#    Hindi: 1. जैतून तेल में तेल को गरम धूप से भी ज़्यादा इस्तेमाल किया जा सकता है ।
#    🔹 LaBSE Similarity: 0.7485
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7226
# --------------------------------------------------
# 🔹 Recipe 414
#    English: 2. Add onion and green bean and cook until tender, about 5 minutes.
#    Hindi: 2 स्फीन और हरा बीन और छोटे बच्चे तक खाना दीजिए, लगभग 5 मिनट.
#    🔹 LaBSE Similarity: 0.8079
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7988
# --------------------------------------------------
# 🔹 Recipe 415
#    English: 3. Add eggs and cook until sunny-side up.
#    Hindi: 3 अंडे और खाना जोड़ें धूप के किनारे तक.
#    🔹 LaBSE Similarity: 0.8164
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7700
# --------------------------------------------------
# 🔹 Recipe 416
#    English: 4. Add cheese, blueberries, lime juice, parsley, salt, and pepper to the skillet.
#    Hindi: इसके अलावा, पनीर, ब्लूबरों, रस, पर्सली, नमक और काली मिर्च को हुनर में भी जोड़िए ।
#    🔹 LaBSE Similarity: 0.7772
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.8009
# --------------------------------------------------
# 🔹 Recipe 417
#    English: 5. Cook for 5 minutes, or until the potatoes are tender and the sauce is heated through.
#    Hindi: जब तक आलू कोमल नहीं हो जाती, तब तक 5 मिनट का खाना ठंडा हो जाता है ।
#    🔹 LaBSE Similarity: 0.7439
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.7099
# --------------------------------------------------
# 🔹 Recipe 418
#    English: 6. Serve immediately.
#    Hindi: 6 तुरंत सेवा कीजिए ।
#    🔹 LaBSE Similarity: 0.8944
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.8247
# --------------------------------------------------
# 🔹 Recipe 419
#    English: Recipe 19:
#    Hindi: रेसिपि 19:
#    🔹 LaBSE Similarity: 0.9077
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.8557
# --------------------------------------------------
# 🔹 Recipe 420
#    English: **Blueberry-Cheese-Green Bean Hash with Potato and Spinach**
#    Hindi: ** ब्लूबर- हरा बेबेन, आलू तथा स्पिनर के साथ हैक
#    🔹 LaBSE Similarity: 0.8405
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8039
# --------------------------------------------------
# 🔹 Recipe 421
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 422
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 मेज़ी जैतून के तेल
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7365
# --------------------------------------------------
# 🔹 Recipe 423
#    English: * 1 onion, diced
#    Hindi: [ पेज 1 पर तसवीर]
#    🔹 LaBSE Similarity: 0.5823
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.5454
# --------------------------------------------------
# 🔹 Recipe 424
#    English: * 1 green bean, diced
#    Hindi: * 1 हरा बेरा, पाँसा फेंकें
#    🔹 LaBSE Similarity: 0.9183
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7234
# --------------------------------------------------
# 🔹 Recipe 425
#    English: * 1/2 pound potatoes, diced
#    Hindi: * 1/2 पाउंड, पॉडड
#    🔹 LaBSE Similarity: 0.8768
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8488
# --------------------------------------------------
# 🔹 Recipe 426
#    English: * 1/2 pound fresh spinach
#    Hindi: * 1/2 किलो ताजा स्पिन
#    🔹 LaBSE Similarity: 0.9057
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.8969
# --------------------------------------------------
# 🔹 Recipe 427
#    English: * 1/4 cup grated mozzarella cheese
#    Hindi: * 1/4 कप का पेय
#    🔹 LaBSE Similarity: 0.6879
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.6960
# --------------------------------------------------
# 🔹 Recipe 428
#    English: * 2 large eggs
#    Hindi: * 2 बड़े अंडे
#    🔹 LaBSE Similarity: 0.9841
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.9443
# --------------------------------------------------
# 🔹 Recipe 429
#    English: * 1 tablespoon lime juice
#    Hindi: * 1 मेज़ के रस
#    🔹 LaBSE Similarity: 0.8908
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.6648
# --------------------------------------------------
# 🔹 Recipe 430
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 मेज़ी जैतून के तेल
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7365
# --------------------------------------------------
# 🔹 Recipe 431
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चायदार नमक
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.6794
# --------------------------------------------------
# 🔹 Recipe 432
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चाय काली मिर्च
#    🔹 LaBSE Similarity: 0.9391
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7533
# --------------------------------------------------
# 🔹 Recipe 433
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 434
#    English: 1. Heat olive oil in a large skillet over medium heat.
#    Hindi: 1. जैतून तेल में तेल को गरम धूप से भी ज़्यादा इस्तेमाल किया जा सकता है ।
#    🔹 LaBSE Similarity: 0.7485
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7226
# --------------------------------------------------
# 🔹 Recipe 435
#    English: 2. Add onion and green bean and cook until tender, about 5 minutes.
#    Hindi: 2 स्फीन और हरा बीन और छोटे बच्चे तक खाना दीजिए, लगभग 5 मिनट.
#    🔹 LaBSE Similarity: 0.8079
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7988
# --------------------------------------------------
# 🔹 Recipe 436
#    English: 3. Add potatoes and spinach to the skillet and cook until tender, about 10 minutes.
#    Hindi: इसके अलावा, कम - से - कम 10 मिनट तक अंडे दीजिए ।
#    🔹 LaBSE Similarity: 0.5782
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.6303
# --------------------------------------------------
# 🔹 Recipe 437
#    English: 4. Add eggs and lime juice to the skillet and cook until the eggs are cooked through.
#    Hindi: जब तक अंडे न पक जाते हैं तब तक अंडे दीजिए ।
#    🔹 LaBSE Similarity: 0.5739
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.6938
# --------------------------------------------------
# 🔹 Recipe 438
#    English: 5. Season with salt and pepper to taste.
#    Hindi: 5 नमक और काली मिर्च से स्वाद लेने के लिए .
#    🔹 LaBSE Similarity: 0.8779
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.6619
# --------------------------------------------------
# 🔹 Recipe 439
#    English: 6. Serve immediately with cheese on top.
#    Hindi: पर पनीर के साथ तुरंत सेवा कीजिए ।
#    🔹 LaBSE Similarity: 0.7918
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.7088
# --------------------------------------------------
# 🔹 Recipe 440
#    English: Recipe 20:
#    Hindi: रेसिपि 20:
#    🔹 LaBSE Similarity: 0.8957
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.8784
# --------------------------------------------------
# 🔹 Recipe 441
#    English: **Blueberry Chicken with Green Bean Mash**
#    Hindi: ** हरे बेसैन के साथ ब्लूबेरी चाउन
#    🔹 LaBSE Similarity: 0.8721
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.7464
# --------------------------------------------------
# 🔹 Recipe 442
#    English: **Ingredients:**
#    Hindi: ** इंडिक्स:
#    🔹 LaBSE Similarity: 0.7554
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7325
# --------------------------------------------------
# 🔹 Recipe 443
#    English: * 1 boneless, skinless chicken breast, cut into 4 equal pieces
#    Hindi: * एक हड्डीहीन, त्वचाहीन मुर्गी स्तन, 4 बराबर के टुकड़ों में कटौती
#    🔹 LaBSE Similarity: 0.9298
#    🔹 XLM-R Similarity: 0.9983
#    🔹 LASER Similarity: 0.8621
# --------------------------------------------------
# 🔹 Recipe 444
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 मेज़ी जैतून के तेल
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7365
# --------------------------------------------------
# 🔹 Recipe 445
#    English: * 1/2 onion, diced
#    Hindi: * 1/2 उनपर, पॉलैंड
#    🔹 LaBSE Similarity: 0.8329
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.7253
# --------------------------------------------------
# 🔹 Recipe 446
#    English: * 1/4 green bean, trimmed and cut into 1-inch pieces
#    Hindi: * 1/4 हरे रंग का होता है और 1 इंच काटता है
#    🔹 LaBSE Similarity: 0.8940
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.8010
# --------------------------------------------------
# 🔹 Recipe 447
#    English: * 1/4 cup fresh spinach
#    Hindi: [ पेज 29 पर बड़े अक्षरों में लेख की खास बात]
#    🔹 LaBSE Similarity: 0.4165
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.5200
# --------------------------------------------------
# 🔹 Recipe 448
#    English: * 1/4 cup grated mozzarella cheese
#    Hindi: * 1/4 कप का पेय
#    🔹 LaBSE Similarity: 0.6879
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.6960
# --------------------------------------------------
# 🔹 Recipe 449
#    English: * 2 large eggs, beaten
#    Hindi: * 2 बड़े अंडे, पीटा
#    🔹 LaBSE Similarity: 0.9679
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.9228
# --------------------------------------------------
# 🔹 Recipe 450
#    English: * 1 tablespoon lime juice
#    Hindi: * 1 मेज़ के रस
#    🔹 LaBSE Similarity: 0.8908
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.6648
# --------------------------------------------------
# 🔹 Recipe 451
#    English: * 1 tablespoon flour
#    Hindi: * 1 मेज़ के मैदा
#    🔹 LaBSE Similarity: 0.8895
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.7020
# --------------------------------------------------
# 🔹 Recipe 452
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चायदार नमक
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.6794
# --------------------------------------------------
# 🔹 Recipe 453
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चाय काली मिर्च
#    🔹 LaBSE Similarity: 0.9391
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.7533
# --------------------------------------------------
# 🔹 Recipe 454
#    English: **Instructions:**
#    Hindi: ** पहलः
#    🔹 LaBSE Similarity: 0.7973
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7060
# --------------------------------------------------
# 🔹 Recipe 455
#    English: 1. Heat olive oil in a large skillet or Dutch oven over medium heat.
#    Hindi: 1. जैतून तेल को बड़ी कुशलता से या तेल में डालकर गरम किया जा सकता है ।
#    🔹 LaBSE Similarity: 0.7678
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7305
# --------------------------------------------------
# 🔹 Recipe 456
#    English: 2. Season chicken with salt and pepper.
#    Hindi: 2, नमक और काली मिर्च के साथ.
#    🔹 LaBSE Similarity: 0.7906
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.7321
# --------------------------------------------------
# 🔹 Recipe 457
#    English: 3. Add chicken to the skillet and cook for 5-7 minutes per side, or until cooked through.
#    Hindi: 3. मुर्गी को हर तरफ 5 मिनट के लिए खाना दीजिए, या जब तक कि उसे पका न हो ।
#    🔹 LaBSE Similarity: 0.7952
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7684
# --------------------------------------------------
# 🔹 Recipe 458
#    English: 4. Remove chicken from the skillet and set aside.
#    Hindi: 4. मुर्गी को हुनर से निकाल दीजिए और अलग रखिए ।
#    🔹 LaBSE Similarity: 0.8955
#    🔹 XLM-R Similarity: 0.9965
#    🔹 LASER Similarity: 0.8120
# --------------------------------------------------
# 🔹 Recipe 459
#    English: 5. Add onion and green bean to the skillet and cook until tender, about 5 minutes.
#    Hindi: 5 छोटे - छोटे बच्चे पैदा कीजिए ।
#    🔹 LaBSE Similarity: 0.4649
#    🔹 XLM-R Similarity: 0.9953
#    🔹 LASER Similarity: 0.5043
# --------------------------------------------------
# 🔹 Recipe 460
#    English: 6. Add spinach and cook until wilted, about 2 minutes.
#    Hindi: 6 करीब 2 मिनट के लिए , जब तक कि जब तक हम थक न जाएँ, खाना पकाने के लिए और खाना दीजिए ।
#    🔹 LaBSE Similarity: 0.6978
#    🔹 XLM-R Similarity: 0.9945
#    🔹 LASER Similarity: 0.6708
# --------------------------------------------------
# 🔹 Recipe 461
#    English: 7. Add mozzarella cheese, eggs, lime juice, flour, and salt and pepper to the skillet.
#    Hindi: 7. ब्लॉएली पनीर, अंडे, रस, मैदा, नमक और नमक भी वगैरह में पाए जाते हैं ।
#    🔹 LaBSE Similarity: 0.7852
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.7834
# --------------------------------------------------
# 🔹 Recipe 462
#    English: 8. Cook for 5 minutes, or until heated through.
#    Hindi: 5 मिनट के लिए खाना, या फिर गर्म होने तक.
#    🔹 LaBSE Similarity: 0.8393
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.7540
# --------------------------------------------------
# 🔹 Recipe 463
#    English: 9. Serve chicken over green bean mash.
#    Hindi: 9 हरे रंग से अधिक मुर्गी की सेवा करो.
#    🔹 LaBSE Similarity: 0.8352
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.6523
# --------------------------------------------------
#
# ✅ Average Similarity Scores:
#    🔹 LaBSE: 0.8133
#    🔹 XLM-R: 0.9972
#    🔹 LASER: 0.7478

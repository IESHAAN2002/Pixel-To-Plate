# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, pipeline

# Load the Facebook M2M100 model and tokenizer
model_name = "facebook/m2m100_418M"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

# Define a translation pipeline
translator = pipeline("translation", model=model, tokenizer=tokenizer)

# File paths
input_file = "/content/gemma-2b-it_recipes.txt"
translated_file = "translated_recipe_hi.txt"
back_translated_file = "back_translated_recipe.txt"

# Read the English recipes
with open(input_file, "r", encoding="utf-8") as f:
    recipes = f.readlines()

# Translate and back-translate
translated_recipes = []
back_translated_recipes = []

for recipe in recipes:
    if recipe.strip():
        # Step 1: English → Hindi
        encoded_en = tokenizer(recipe.strip(), return_tensors="pt")
        translated_ids = model.generate(**encoded_en, forced_bos_token_id=tokenizer.get_lang_id("hi"))
        translated = tokenizer.batch_decode(translated_ids, skip_special_tokens=True)[0]
        translated_recipes.append(translated)

        # Step 2: Hindi → English (Back Translation)
        encoded_hi = tokenizer(translated, return_tensors="pt")
        back_translated_ids = model.generate(**encoded_hi, forced_bos_token_id=tokenizer.get_lang_id("en"))
        back_translated = tokenizer.batch_decode(back_translated_ids, skip_special_tokens=True)[0]
        back_translated_recipes.append(back_translated)

        # Print for monitoring
        print(f"\nOriginal: {recipe.strip()}")
        print(f"Translated (EN → HI): {translated}")
        print(f"Back-Translated (HI → EN): {back_translated}")

# Save translated Hindi recipes
with open(translated_file, "w", encoding="utf-8") as f:
    f.write("\n".join(translated_recipes))

# Save back-translated English recipes
with open(back_translated_file, "w", encoding="utf-8") as f:
    f.write("\n".join(back_translated_recipes))

print(f"\nTranslation and back-translation completed! Files saved:\n- Hindi Recipes: '{translated_file}'\n- Back-Translated English Recipes: '{back_translated_file}'")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/298 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/908 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/3.71M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.94G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/233 [00:00<?, ?B/s]
# Device set to use cpu
# Original: Recipe 1:
# Translated (EN → HI): नुस्खा 1 :
# Back-Translated (HI → EN): The recipe 1 :
#
# Original: **The Dish:**
# Translated (EN → HI): * डिश के बारे में: *
# Back-Translated (HI → EN): About the dish: *
#
# Original: **Spicy Carrot Bread with Strawberry Glaze**
# Translated (EN → HI): ** स्ट्रॉबेरी ग्लेज़ के साथ स्वादिष्ट कार्बोहाइड्रेट रोटी**
# Back-Translated (HI → EN): ** delicious carbohydrate bread with strawberry glaze**
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 loaf (12 slices) bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 लहसुन (12 स्लाइड्स) रोटी, 1/2 इंच मोटी स्लाइड्स में स्लाइड
# Back-Translated (HI → EN): * 1 cheese (12 slides) bread, slide in 1/2 inch thick slides
#
# Original: * 1 large carrot, diced
# Translated (EN → HI): * 1 बड़ा कार्बोहाइड्रेट, कटा हुआ
# Back-Translated (HI → EN): * 1 large carbohydrate, cut
#
# Original: * 1/2 cup chocolate chips
# Translated (EN → HI): 1/2 कप चॉकलेट चिप्स
# Back-Translated (HI → EN): 1/2 cup of chocolate chips
#
# Original: * 1 tablespoon flour
# Translated (EN → HI): * 1 टैबलेट फूल
# Back-Translated (HI → EN): 1 tablet of flowers
#
# Original: * 1 tablespoon green_beans, chopped
# Translated (EN → HI): * 1 टैबलेट green_beans, चॉपिंग
# Back-Translated (HI → EN): * 1 tablet green_beans, chopping
#
# Original: * 1 tablespoon ground_beef
# Translated (EN → HI): * 1 टैबलेट मिट्टी_बीईएफ
# Back-Translated (HI → EN): * 1 tablet of soil_BEF
#
# Original: * 1/2 lime, juiced
# Translated (EN → HI): * 1/2 लहसुन, जूस
# Back-Translated (HI → EN): * 1/2 garlic, juice
#
# Original: * 1/4 cup strawberries, diced
# Translated (EN → HI): * 1/4 गिलास अनाज, पकाया
# Back-Translated (HI → EN): 1/4 glass of grain, cooked
#
# Original: * 1 tablespoon sugars
# Translated (EN → HI): * 1 टैबलेट शर्करा
# Back-Translated (HI → EN): 1 tablet of sugar
#
# Original: * 1 tablespoon tomato paste
# Translated (EN → HI): * 1 टैबलेट टमाटर पेस्ट
# Back-Translated (HI → EN): * 1 tablet of tomato paste
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
# Back-Translated (HI → EN): Heat the oven to 375 degrees F (190 degrees C).
#
# Original: 2. In a large skillet, cook the carrot and green_beans over medium heat until tender and slightly browned.
# Translated (EN → HI): 2. एक बड़े स्केलिट में, मध्यम गर्मी पर कार्बोहाइड्रेट और ग्रीन_बेन को पकाएं, जब तक कि यह तंग और थोड़ा चमकदार न हो।
# Back-Translated (HI → EN): In a large skeleton, cook carbohydrates and green_ben at moderate heat, until it is tight and slightly bright.
#
# Original: 3. Add the ground_beef to the skillet and cook until browned.
# Translated (EN → HI): 3. स्केलिट में भूमि_बईफ जोड़ें और चमक तक पकाएं।
# Back-Translated (HI → EN): Add land_beef to the skeleton and cook until brightness.
#
# Original: 4. Add the lime juice, strawberries, and sugars to the skillet and simmer for 5 minutes.
# Translated (EN → HI): 4. स्कील में लहसुन का रस, मक्खन, और चीनी जोड़ें और 5 मिनट के लिए तैरें।
# Back-Translated (HI → EN): Add cheese juice, butter, and sugar to the scale and swim for 5 minutes.
#
# Original: 5. Spread the mixture evenly over the bread slices.
# Translated (EN → HI): 5. मिश्रण को ब्रेड स्लाइड्स के ऊपर समान रूप से फैलाएं।
# Back-Translated (HI → EN): Mix the mixture equally above the bread slides.
#
# Original: 6. Bake for 10 minutes, or until the bread is golden brown and the filling is cooked through.
# Translated (EN → HI): 6. 10 मिनट के लिए पकाएं, या जब तक कि रोटी सोने का काला हो और भरने के माध्यम से पकाया जाता है।
# Back-Translated (HI → EN): Cook for 10 minutes, or until the bread is black of gold and cooked through filling.
#
# Original: 7. Serve with a drizzle of strawberry glaze.
# Translated (EN → HI): 7. स्ट्रॉबेरी ग्लेज़ के एक ड्रिज़ल के साथ सेवा करें।
# Back-Translated (HI → EN): Service with a drizzle of stroberi glaze.
#
# Original: **Tips:**
# Translated (EN → HI): * टिप्स : *
# Back-Translated (HI → EN): The tips: *
#
# Original: * For a richer bread, use high-quality bread.
# Translated (EN → HI): * एक अमीर रोटी के लिए, उच्च गुणवत्ता वाले रोटी का उपयोग करें।
# Back-Translated (HI → EN): For a rich bread, use high quality bread.
#
# Original: * To make a gluten-free bread, use gluten-free flour.
# Translated (EN → HI): * ग्लूटेन-मुक्त रोटी बनाने के लिए, ग्लूटेन-मुक्त फूल का उपयोग करें।
# Back-Translated (HI → EN): * To make gluten-free bread, use gluten-free flowers.
#
# Original: * Serve with a side of your favorite dipping sauce, such as ranch dressing or pesto.
# Translated (EN → HI): * अपने पसंदीदा डाइपिंग सॉस के एक तरफ से सेवा करें, जैसे कि रैंच ड्रेसिंग या पेस्टो।
# Back-Translated (HI → EN): * Service on one side of your favorite dive sauce, such as ranch dressing or pasta.
#
# Original: Recipe 2:
# Translated (EN → HI): रेसिपी 2 :
# Back-Translated (HI → EN): Recipe 2 :
#
# Original: **Beef and Vegetable Stir-Fry with Sweet and Spicy Glaze**
# Translated (EN → HI): ** बीयर और सब्जियां मिठाई और चमकदार ग्लास के साथ ठंडा-फ्री**
# Back-Translated (HI → EN): * Beer and vegetables cold-free with sweets and bright glass*
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1 pound beef, thinly sliced
# Translated (EN → HI): * 1 पाउंड अनाज, पतली पतली
# Back-Translated (HI → EN): * 1 pound grain, thin thin
#
# Original: * 1 tablespoon chopped onion, diced
# Translated (EN → HI): * 1 टैबलेट चॉपिंग ओनिओन, डाइक
# Back-Translated (HI → EN): * 1 tablet chopping onion, dick
#
# Original: * 1 tablespoon chopped carrots, diced
# Translated (EN → HI): * 1 टैबलेट चॉकलेट, ड्रिलिंग
# Back-Translated (HI → EN): 1 tablet of chocolate, drilling
#
# Original: * 1 tablespoon chopped chicken, diced
# Translated (EN → HI): * 1 चॉकलेट चॉकलेट चिकन, पकाया
# Back-Translated (HI → EN): * 1 chocolate chocolate chicken, cooked
#
# Original: * 1 tablespoon chopped ground beef
# Translated (EN → HI): * 1 चम्मच चोपड़ा भूमि बीफ
# Back-Translated (HI → EN): * 1 cup of chopra land beef
#
# Original: * 1 tablespoon chopped spinach
# Translated (EN → HI): * 1 चम्मच चॉपिंग स्पाइन
# Back-Translated (HI → EN): 1 cup of chopping spine
#
# Original: * 1 tablespoon chopped strawberries
# Translated (EN → HI): * 1 चम्मच चॉकलेट स्ट्रॉबेरी
# Back-Translated (HI → EN): * 1 cup of chocolate strawberry
#
# Original: * 1 tablespoon sugar
# Translated (EN → HI): * 1 टैबलेट शर्करा
# Back-Translated (HI → EN): 1 tablet of sugar
#
# Original: * 1 tablespoon soy sauce
# Translated (EN → HI): * 1 चम्मच सोया सॉस
# Back-Translated (HI → EN): 1 cup of soya sauce
#
# Original: * 1 tablespoon honey
# Translated (EN → HI): * 1 चम्मच शहद
# Back-Translated (HI → EN): * 1 cup of honey
#
# Original: * 1 tablespoon sesame oil
# Translated (EN → HI): * 1 टैबलेट सीज़ैम तेल
# Back-Translated (HI → EN): 1 Tablet of Cezam Oil
#
# Original: * 1 tablespoon ground black pepper
# Translated (EN → HI): * 1 चम्मच भूमि काले पेपर
# Back-Translated (HI → EN): * 1 cup of land black paper
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Heat the olive oil in a large skillet or wok over medium-high heat.
# Translated (EN → HI): 1. एक बड़े स्केलिट में जैतून का तेल गर्म करें या मध्यम-उच्च गर्मी से ऊपर झुकें।
# Back-Translated (HI → EN): Warm olive oil in a large skeleton or tend above medium-high heat.
#
# Original: 2. Add the beef and cook until browned on all sides.
# Translated (EN → HI): 2. अनाज को जोड़ें और हर तरफ चमगादड़ तक पकाएं।
# Back-Translated (HI → EN): Add the grain and cook it everywhere to the straw.
#
# Original: 3. Add the onion, carrots, and chicken to the skillet and cook until tender and slightly browned.
# Translated (EN → HI): 3. अनाज, मक्खन, और चिकन को स्कीलेट में जोड़ें और तब तक पकाएं जब तक कि तंग और थोड़ा चमकदार न हो।
# Back-Translated (HI → EN): Add cereal, butter, and chicken to the skeleton and cook until it is tight and slightly bright.
#
# Original: 4. Add the ground beef, spinach, and strawberries to the skillet and cook until heated through.
# Translated (EN → HI): 4. मिट्टी के बीन्स, स्पाइना और मक्खन को स्कील में जोड़ें और गर्म होने तक पकाएं।
# Back-Translated (HI → EN): Add soil beans, spina and butter to the scale and cook until it is warm.
#
# Original: 5. In a small bowl, whisk together the sugar, soy sauce, honey, and sesame oil.
# Translated (EN → HI): 5. एक छोटे से बोतल में, शर्करा, सोया सॉस, शहद, और ससैम तेल को मिलाएं।
# Back-Translated (HI → EN): In a small bottle, mix sugar, soya sauce, honey, and sausage oil.
#
# Original: 6. Add the sauce to the skillet and cook until heated through.
# Translated (EN → HI): 6. सॉस को स्कीलेट में जोड़ें और गर्म होने तक पकाएं।
# Back-Translated (HI → EN): Add the sauce to the skeleton and cook until it is warm.
#
# Original: 7. Serve over rice and garnish with fresh cilantro.
# Translated (EN → HI): 7. चावल के ऊपर सेवा करें और ताजा सिलेंट्रो के साथ ग्रेनाइज़ करें।
# Back-Translated (HI → EN): Serv above rice and granite with fresh silentro.
#
# Original: Recipe 3:
# Translated (EN → HI): रेसिपी 3 :
# Back-Translated (HI → EN): Recipe 3 :
#
# Original: **Beef and Green Bean Stuffed Sweet Potatoes**
# Translated (EN → HI): ** बीफ और ग्रीन बीन स्टुफेड मीठे आलू**
# Back-Translated (HI → EN): * Beef and green bean stuffed sweet potato*
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 2 tablespoons of butter
# Translated (EN → HI): * 2 चम्मच मक्खन
# Back-Translated (HI → EN): * 2 cups of butter
#
# Original: * 1 large egg, beaten
# Translated (EN → HI): * 1 बड़ा अंडे, हिट
# Back-Translated (HI → EN): 1 big egg, hit
#
# Original: * 1/2 cup of chopped green beans
# Translated (EN → HI): * 1/2 कप चॉकलेट ग्रीन बीन्स
# Back-Translated (HI → EN): 1/2 cup of chocolate green beans
#
# Original: * 1 pound of ground beef
# Translated (EN → HI): * 1 पाउंड भूमि गाय
# Back-Translated (HI → EN): * 1 pound of land cows
#
# Original: * 1/2 cup of chopped mushrooms
# Translated (EN → HI): * 1/2 कप चॉकलेट मशरूम
# Back-Translated (HI → EN): 1/2 cup of chocolate mushroom
#
# Original: * 1/4 cup of chopped onions
# Translated (EN → HI): * 1 / 4 कप चॉकलेट
# Back-Translated (HI → EN): 1 / 4 cup of chocolate
#
# Original: * 1/4 cup of chopped spinach
# Translated (EN → HI): * 1/4 कप चॉपिंग स्पाइन
# Back-Translated (HI → EN): 1/4 cup of chopping spine
#
# Original: * 1/4 cup of chopped strawberries
# Translated (EN → HI): * 1 / 4 कप चॉकलेट का रस
# Back-Translated (HI → EN): * 1 / 4 cup of chocolate juice
#
# Original: * 1/2 cup of heavy cream
# Translated (EN → HI): * 1/2 कप भारी क्रीम
# Back-Translated (HI → EN): 1/2 cup of heavy cream
#
# Original: * 1 tablespoon of chopped fresh parsley
# Translated (EN → HI): * 1 चम्मच चोपड़ा ताजा मक्खन
# Back-Translated (HI → EN): * 1 cup of fresh butter
#
# Original: * Salt and pepper to taste
# Translated (EN → HI): * स्वाद के लिए नमक और पेपर
# Back-Translated (HI → EN): * Salt and paper for taste
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
# Back-Translated (HI → EN): Heat the oven to 375 degrees F (190 degrees C).
#
# Original: 2. In a large skillet over medium heat, melt the butter.
# Translated (EN → HI): 2. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में, मक्खन को मिलाएं।
# Back-Translated (HI → EN): In a large skeleton above medium heat, mix the butter.
#
# Original: 3. Add the egg and cook until cooked through.
# Translated (EN → HI): 3. अंडे को जोड़ें और पकाने तक पकाएं।
# Back-Translated (HI → EN): Add the eggs and cook until cooking.
#
# Original: 4. Add the green beans, mushrooms, onions, and spinach to the skillet and cook until tender.
# Translated (EN → HI): 4. ग्रीन बीन्स, मशरूम, अनाज, और स्पाइना को स्कीलेट में जोड़ें और तंग तक पकाएं।
# Back-Translated (HI → EN): Add green beans, mushrooms, grains, and spina to the skeleton and cook to tight.
#
# Original: 5. Add the ground beef to the skillet and cook until browned.
# Translated (EN → HI): 5. मिट्टी के बीज को स्केलिट में जोड़ें और चमकने तक पकाएं।
# Back-Translated (HI → EN): Add the seed of soil to the skeleton and cook until it shines.
#
# Original: 6. Add the heavy cream, parsley, salt, and pepper to the skillet and simmer for 5 minutes.
# Translated (EN → HI): 6. भारी क्रीम, मक्खन, नमक और पेपर को स्कीलेट में जोड़ें और 5 मिनट के लिए तैरें।
# Back-Translated (HI → EN): Add heavy cream, butter, salt and paper to the skeleton and swim for 5 minutes.
#
# Original: 7. Transfer the filling to a baking dish.
# Translated (EN → HI): 7. भंडार को एक पके हुए व्यंजन में स्थानांतरित करें।
# Back-Translated (HI → EN): 7.Move the warehouse into a cooked dish.
#
# Original: 8. Top with the sweet potatoes and bake for 20 minutes, or until the potatoes are golden brown and the filling is heated through.
# Translated (EN → HI): 8. 20 मिनट के लिए मीठे आलू और बकरी के साथ ऊपर, या जब तक आलू सोने का काला हो जाता है और भरने के माध्यम से गर्म हो जाता है।
# Back-Translated (HI → EN): For 20 minutes with sweet potatoes and cows up, or until the potatoes become black of gold and warm through filling.
#
# Original: 9. Serve immediately.
# Translated (EN → HI): 9. तुरंत सेवा करें।
# Back-Translated (HI → EN): 9 – Service immediately.
#
# Original: Recipe 4:
# Translated (EN → HI): रेसिपी 4 :
# Back-Translated (HI → EN): Recommended 4 :
#
# Original: **Blueberry Bread with Sweet Potato Filling**
# Translated (EN → HI): ** ब्लूबेरी रोटी के साथ मीठा आलू भरने**
# Back-Translated (HI → EN): * Fill sweet potato with blueberry bread*
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 loaf (1 pound) white bread, sliced into 1-inch thick slices
# Translated (EN → HI): * 1 लहसुन (1 पाउंड) सफेद रोटी, 1 इंच मोटी स्लाइड्स में स्लाइड
# Back-Translated (HI → EN): * 1 cheese (1 pound) white bread, 1 inch thick slides
#
# Original: * 1 cup blueberries
# Translated (EN → HI): 1 कप ब्लूबेरी
# Back-Translated (HI → EN): 1 cup of blueberry
#
# Original: * 1/2 cup sugar
# Translated (EN → HI): * 1/2 कप शर्करा
# Back-Translated (HI → EN): 1/2 cup of sugar
#
# Original: * 1/4 teaspoon salt
# Translated (EN → HI): * 1/4 चम्मच नमक
# Back-Translated (HI → EN): * 1/4 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1/2 teaspoon vanilla extract
# Translated (EN → HI): * 1/2 चम्मच वेनिला निकालने
# Back-Translated (HI → EN): 1/2 cup of vanilla extract
#
# Original: * 1/4 cup chopped onion
# Translated (EN → HI): * 1/4 कप चॉपिंग ओयोन
# Back-Translated (HI → EN): 1/4 cup of choping oion
#
# Original: * 1/2 cup chopped spinach
# Translated (EN → HI): * 1/2 कप चॉकलेट स्पाइन
# Back-Translated (HI → EN): 1/2 cup of chocolate spine
#
# Original: * 1/4 cup chopped strawberries
# Translated (EN → HI): * 1 / 4 कप चॉकलेट मक्खन
# Back-Translated (HI → EN): * 1 / 4 cup of chocolate butter
#
# Original: * 1/4 cup chocolate chips
# Translated (EN → HI): 1/4 कप चॉकलेट चिप्स
# Back-Translated (HI → EN): 1/4 cup of chocolate chips
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
# Back-Translated (HI → EN): Heat the oven to 375 degrees F (190 degrees C).
#
# Original: 2. In a large bowl, combine the bread slices, blueberries, sugar, salt, and black pepper.
# Translated (EN → HI): 2. एक बड़े बोतल में, रोटी स्लाइड्स, ब्लूबेरी, चीनी, नमक और काले पेपर को जोड़ें।
# Back-Translated (HI → EN): In a large bottle, add bread slides, blueberry, sugar, salt and black paper.
#
# Original: 3. In a separate bowl, whisk together the olive oil, vanilla extract, onion, spinach, and strawberries.
# Translated (EN → HI): 3. एक अलग बोतल में, जैतून का तेल, वेनिला निकालने, अनाज, स्पाइन, और मक्खन के साथ मिलाएं।
# Back-Translated (HI → EN): In a separate bottle, mix with olive oil, vanilla extract, grain, spine, and butter.
#
# Original: 4. Add the wet ingredients to the dry ingredients and stir until just combined. Do not overmix.
# Translated (EN → HI): 4. सूखे अवयवों में गीले अवयवों को जोड़ें और मिश्रित होने तक मिश्रण करें. अति मिश्रण न करें.
# Back-Translated (HI → EN): Add wet ingredients to dry ingredients and mix until they are mixed.
#
# Original: 5. Pour the batter into a greased 9x13-inch baking dish.
# Translated (EN → HI): 5. बैटरी को एक गीला 9x13-इंच पाक व्यंजन में डालें।
# Back-Translated (HI → EN): Put the battery in a wet 9x13-inch cooked dish.
#
# Original: 6. Bake for 30-35 minutes, or until the bread is golden brown and the filling is set.
# Translated (EN → HI): 6. 30-35 मिनट के लिए पकाएं, या जब तक रोटी सोने का काला नहीं है और भरने सेट किया जाता है।
# Back-Translated (HI → EN): Cook for 30-35 minutes, or until the bread is not black of gold and fill.
#
# Original: 7. Serve warm with a scoop of vanilla ice cream or whipped cream.
# Translated (EN → HI): 7. वेनिला आइसक्रीम या गीला क्रीम के एक स्कोप के साथ गर्म करें।
# Back-Translated (HI → EN): Warm with a cup of vanilla ice cream or wet cream.
#
# Original: Recipe 5:
# Translated (EN → HI): रेसिपी 5 :
# Back-Translated (HI → EN): Recommended 5 :
#
# Original: **Chicken and Sweet Potato Hash with Chocolate Glaze**
# Translated (EN → HI): ** चॉकलेट ग्लास के साथ चिकन और मीठा आलू हैश**
# Back-Translated (HI → EN): ** Chicken and sweet potato hash with chocolate glass**
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 loaf of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 कटोरा रोटी, 1/2 इंच मोटी स्लाइड्स में घुमाया
# Back-Translated (HI → EN): * 1 cup of bread, rotated in 1/2 inch thick slides
#
# Original: * 1/2 pound of chicken breast, cut into 1-inch cubes
# Translated (EN → HI): * 1/2 पाउंड चिकन स्तन, 1 इंच क्यूब में काट दिया
# Back-Translated (HI → EN): 1/2 pound chicken breasts, cut into 1 inch cubes
#
# Original: * 1/4 cup of grated cheese
# Translated (EN → HI): * 1/4 कप ग्रेड पनीर
# Back-Translated (HI → EN): 1/4 cup of grade cheese
#
# Original: * 1/4 cup of chopped chocolate
# Translated (EN → HI): * 1/4 कप चॉकलेट
# Back-Translated (HI → EN): 1/4 cup of chocolate
#
# Original: * 2 large eggs, beaten
# Translated (EN → HI): * 2 बड़े अंडे, हिट
# Back-Translated (HI → EN): 2 big eggs, hit
#
# Original: * 1/2 cup of chopped potato
# Translated (EN → HI): * 1/2 कप चूपित आलू
# Back-Translated (HI → EN): * 1/2 cup of chopped potato
#
# Original: * 1/4 cup of chopped strawberries
# Translated (EN → HI): * 1 / 4 कप चॉकलेट का रस
# Back-Translated (HI → EN): * 1 / 4 cup of chocolate juice
#
# Original: * 1 tablespoon of sugar
# Translated (EN → HI): * 1 चम्मच शर्करा
# Back-Translated (HI → EN): * 1 cup of sugar
#
# Original: * 1 tablespoon of sweet potato, mashed and cooled
# Translated (EN → HI): * 1 चम्मच मीठा आलू, मसालेदार और ठंडा
# Back-Translated (HI → EN): * 1 teaspoon of sweet potato, spicy and cold
#
# Original: * 1 tablespoon of melted chocolate
# Translated (EN → HI): * 1 चॉकलेट का मिश्रण
# Back-Translated (HI → EN): 1 mixture of chocolate
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
# Back-Translated (HI → EN): Heat the oven to 375 degrees F (190 degrees C).
#
# Original: 2. Toast the bread slices lightly on both sides until golden brown.
# Translated (EN → HI): 2. रोटी को धीरे-धीरे दोनों तरफ झुकाएं जब तक कि सोने का काला न हो जाए।
# Back-Translated (HI → EN): Slide the bread slowly on both sides until the gold becomes black.
#
# Original: 3. In a large skillet over medium heat, cook the chicken for 5-7 minutes per side, or until cooked through.
# Translated (EN → HI): 3. मध्यम गर्मी पर एक बड़े स्कील में, चिकन को 5-7 मिनट के लिए पकाया जाता है, या जब तक कि इसे पकाया जाता है।
# Back-Translated (HI → EN): In a large scale at moderate heat, the chicken is cooked for 5-7 minutes, or until it is cooked.
#
# Original: 4. Add the cheese, chocolate, eggs, potato, and strawberries to a baking dish.
# Translated (EN → HI): 4. पनीर, चॉकलेट, अंडे, आलू और मक्खन को एक पके हुए व्यंजन में जोड़ें।
# Back-Translated (HI → EN): Add cheese, chocolate, eggs, potato and butter to a cooked dish.
#
# Original: 5. Pour the chicken over the topping.
# Translated (EN → HI): 5. चिकन को ऊपर की ओर डालें।
# Back-Translated (HI → EN): Put the chicken upwards.
#
# Original: 6. Bake for 20-25 minutes, or until the chicken is cooked through and the vegetables are tender.
# Translated (EN → HI): 6. 20-25 मिनट के लिए पकाएं, या जब तक कि चिकन के माध्यम से पकाया जाता है और सब्जियां तंग हो जाती हैं।
# Back-Translated (HI → EN): Cook for 20-25 minutes, or until it is cooked through chicken and the vegetables become tired.
#
# Original: 7. Serve with a drizzle of chocolate glaze.
# Translated (EN → HI): 7. चॉकलेट ग्लास के एक ड्रिज़ल के साथ सेवा करें।
# Back-Translated (HI → EN): Served with a fridge of chocolate glass.
#
# Original: Recipe 6:
# Translated (EN → HI): नुस्खा 6 :
# Back-Translated (HI → EN): The 6th recipe:
#
# Original: **Blueberry Chicken with Green Bean Mash**
# Translated (EN → HI): ** ग्रीन बीन मश के साथ ब्लूबेरी चिकन**
# Back-Translated (HI → EN): *Blueberry chicken with green bean mush**
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 pound boneless, skinless chicken breasts, cut into 1-inch pieces
# Translated (EN → HI): * 1 पाउंड बेकार, त्वचाहीन चिकन स्तन, 1 इंच के टुकड़ों में कटौती
# Back-Translated (HI → EN): * 1 pound useless, skinless chicken breasts, cut into pieces of 1 inch
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चम्मच नमक
# Back-Translated (HI → EN): * 1/2 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: * 1 cup blueberries
# Translated (EN → HI): 1 कप ब्लूबेरी
# Back-Translated (HI → EN): 1 cup of blueberry
#
# Original: * 1 tablespoon lemon juice
# Translated (EN → HI): * 1 चम्मच नींबू का रस
# Back-Translated (HI → EN): * 1 cup of lemon juice
#
# Original: * 1 tablespoon butter
# Translated (EN → HI): * 1 चम्मच मक्खन
# Back-Translated (HI → EN): * 1 cup of butter
#
# Original: * 1 tablespoon flour
# Translated (EN → HI): * 1 टैबलेट फूल
# Back-Translated (HI → EN): 1 tablet of flowers
#
# Original: * 1/2 cup green beans, trimmed and cut into 1-inch pieces
# Translated (EN → HI): * 1/2 कप ग्रीन बीन्स, कटौती और 1 इंच टुकड़ों में कटौती
# Back-Translated (HI → EN): 1/2 cup of green beans, cut and cut in 1 inch pieces
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चम्मच नमक
# Back-Translated (HI → EN): * 1/2 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 400 degrees F (200 degrees C).
# Translated (EN → HI): 1. ओवन 400 डिग्री एफ (200 डिग्री सेल्सियस) तक पूर्व गर्म करें।
# Back-Translated (HI → EN): Preheat the oven to 400°F (200°C).
#
# Original: 2. In a large skillet over medium heat, heat olive oil. Season chicken with salt and pepper. Cook chicken for 5 minutes per side, or until cooked through.
# Translated (EN → HI): 2. मध्यम गर्मी पर एक बड़े स्केलिट में, जैतून का तेल गर्म करें. नमक और पेपर के साथ मौसमी चिकन. चिकन को 5 मिनट के लिए पकाएं, या जब तक कि इसे पकाया न जाए।
# Back-Translated (HI → EN): In a large skeleton at moderate heat, heat olive oil. seasonal chicken with salt and paper. cook the chicken for 5 minutes, or until it is cooked.
#
# Original: 3. Transfer chicken to a baking dish. Top with blueberries, lemon juice, and butter.
# Translated (EN → HI): 3. चिकन को एक पके हुए व्यंजन में स्थानांतरित करें. ब्लूबेरी, नींबू का रस, और मक्खन के साथ शीर्ष।
# Back-Translated (HI → EN): Transfer the chicken into a cooked dish. blueberry, lemon juice, and top with butter.
#
# Original: 4. Bake for 20-25 minutes, or until the chicken is cooked through and the blueberries are tender.
# Translated (EN → HI): 4. 20-25 मिनट के लिए पकाएं, या जब तक कि चिकन के माध्यम से पकाया जाता है और ब्लूबेरी तंग हो जाते हैं।
# Back-Translated (HI → EN): Cook for 20-25 minutes, or until it is cooked through chicken and blueberries become tight.
#
# Original: 5. Serve with green beans and mashed potatoes.
# Translated (EN → HI): 5. हरी बीन्स और मसालेदार आलू के साथ सेवा करें।
# Back-Translated (HI → EN): 5. serve with green beans and spicy potatoes.
#
# Original: **Tips:**
# Translated (EN → HI): * टिप्स : *
# Back-Translated (HI → EN): The tips: *
#
# Original: * For a more flavorful dish, use a variety of different berries, such as raspberries or strawberries.
# Translated (EN → HI): * एक अधिक स्वादिष्ट व्यंजन के लिए, विभिन्न व्यंजनों की एक किस्म का उपयोग करें, जैसे कि मक्खन या मक्खन।
# Back-Translated (HI → EN): * For a more delicious dish, use a variety of different dishes, such as butter or butter.
#
# Original: * Serve with a dipping sauce, such as a balsamic glaze or a honey mustard sauce.
# Translated (EN → HI): * एक डाइपिंग सॉस के साथ सेवा करें, जैसे कि एक बल्सैमिक ग्लास या एक मेनू मटार सॉस।
# Back-Translated (HI → EN): * Service with a dive sauce, such as a balsamic glass or a menu matar sauce.
#
# Original: * Serve with a side of crusty bread to soak up the juices.
# Translated (EN → HI): * जूस को पकाने के लिए क्रस्टी रोटी के एक पक्ष के साथ सेवा करें।
# Back-Translated (HI → EN): * To cook the juice serve with one side of crocodile bread.
#
# Original: Recipe 7:
# Translated (EN → HI): रेसिपी 7 :
# Back-Translated (HI → EN): The Recipe 7 :
#
# Original: **Chicken and Cheese Stuffed Corn with Heavy Cream Sauce**
# Translated (EN → HI): ** चिकन और पनीर भारी क्रीम सॉस के साथ कच्चे मक्खन**
# Back-Translated (HI → EN): ** Chicken and cheese raw butter with heavy cream sauce**
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 boneless, skinless chicken breast, cut into 1-inch cubes
# Translated (EN → HI): * 1 बेकार, त्वचाहीन चिकन स्तन, 1 इंच क्यूब में काट दिया
# Back-Translated (HI → EN): * 1 useless, skinless chicken breasts, cut into 1 inch cubes
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): * 1 ओनिओन, डाइक
# Back-Translated (HI → EN): 1 onion, dicks
#
# Original: * 2 cloves garlic, minced
# Translated (EN → HI): * 2 चम्मच ग्रीनहाउस, मिनी
# Back-Translated (HI → EN): 2 cups of greenhouse, mini
#
# Original: * 1/2 teaspoon black pepper
# Translated (EN → HI): 1/2 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/2 cup of black paper
#
# Original: * 1/4 teaspoon salt
# Translated (EN → HI): * 1/4 चम्मच नमक
# Back-Translated (HI → EN): * 1/4 cup of salt
#
# Original: * 1/4 cup heavy cream
# Translated (EN → HI): * 1/4 कप भारी क्रीम
# Back-Translated (HI → EN): 1/4 cup of heavy cream
#
# Original: * 1/2 cup grated mozzarella cheese
# Translated (EN → HI): * 1/2 कप ग्रेड मोज़ेरेला पनीर
# Back-Translated (HI → EN): 1/2 cup of grade mozzarella cheese
#
# Original: * 1/2 cup chopped fresh corn
# Translated (EN → HI): * 1/2 कप चॉकलेट ताजा मक्खन
# Back-Translated (HI → EN): 1/2 cup of chocolate fresh butter
#
# Original: * 1/2 cup chopped mushrooms
# Translated (EN → HI): * 1/2 कप चॉकलेट चॉकलेट
# Back-Translated (HI → EN): 1/2 cup of chocolate
#
# Original: * 1/2 teaspoon dried oregano
# Translated (EN → HI): * 1/2 चम्मच सूखे ओरेगानो
# Back-Translated (HI → EN): 1/2 cup of dry oregano
#
# Original: * 1/4 teaspoon salt
# Translated (EN → HI): * 1/4 चम्मच नमक
# Back-Translated (HI → EN): * 1/4 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Heat olive oil in a large skillet over medium heat.
# Translated (EN → HI): 1. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में तेल गर्म करें।
# Back-Translated (HI → EN): Heat the oil in a large skeleton above medium heat.
#
# Original: 2. Season chicken with black pepper and salt.
# Translated (EN → HI): 2. काले पेपर और नमक के साथ मौसम चिकन।
# Back-Translated (HI → EN): Weather chicken with black paper and salt.
#
# Original: 3. Add chicken to the skillet and cook until browned on all sides.
# Translated (EN → HI): 3. चिकन को स्केलिट में जोड़ें और सभी पक्षों पर चमकने तक पकाएं।
# Back-Translated (HI → EN): Add the chicken to the skeleton and cook until it shines on all sides.
#
# Original: 4. Add onion and garlic to the skillet and cook until softened, about 5 minutes.
# Translated (EN → HI): 4. स्केलिट में अनाज और मक्खन जोड़ें और लगभग 5 मिनट के लिए नरम होने तक पकाएं।
# Back-Translated (HI → EN): Add cereal and butter to the skeleton and cook until it is soft for about 5 minutes.
#
# Original: 5. Add mushrooms and potato to the skillet and cook until tender, about 10 minutes.
# Translated (EN → HI): 5. मूंगफली और आलू को स्कीलेट में जोड़ें और लगभग 10 मिनट तक पकाएं।
# Back-Translated (HI → EN): Add garlic and potato to the skeleton and cook for about 10 minutes.
#
# Original: 6. Add heavy cream, mozzarella cheese, and oregano to the skillet.
# Translated (EN → HI): 6. भारी क्रीम, मोज़ेरेला पनीर और ओरेगानो को स्कीलेट में जोड़ें।
# Back-Translated (HI → EN): Add heavy cream, mozzarella cheese and oregano to the skeleton.
#
# Original: 7. Bring to a simmer and cook for 5 minutes, or until the cheese is melted and bubbly.
# Translated (EN → HI): 7. एक स्विमर में लाएं और 5 मिनट के लिए पकाएं, या जब तक कि पनीर मिट जाए और ब्लेड हो जाए।
# Back-Translated (HI → EN): Bring in a swimmer and cook for 5 minutes, or until cheese is dried and bleed.
#
# Original: 8. Serve over a bed of roasted corn.
# Translated (EN → HI): 8. एक बिस्तर पर चमकदार मक्खन का सेवन करें।
# Back-Translated (HI → EN): Consume bright butter on one bed.
#
# Original: Recipe 8:
# Translated (EN → HI): रेसिपी 8 :
# Back-Translated (HI → EN): Recommended 8 :
#
# Original: **Chicken and Sweet Potato Hash with Green Beans**
# Translated (EN → HI): ** चिकन और मीठे आलू हश ग्रीन बीन्स के साथ**
# Back-Translated (HI → EN): ** Chicken and sweet potato hash with green beans**
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 loaf of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 कटोरा रोटी, 1/2 इंच मोटी स्लाइड्स में घुमाया
# Back-Translated (HI → EN): * 1 cup of bread, rotated in 1/2 inch thick slides
#
# Original: * 1/4 cup of butter
# Translated (EN → HI): * 1/4 कप मक्खन
# Back-Translated (HI → EN): 1/4 cup of butter
#
# Original: * 1/2 pound of chicken_breast, cut into 1-inch pieces
# Translated (EN → HI): * 1/2 पाउंड चिकन_ब्रेस्ट, 1 इंच टुकड़ों में काट दिया
# Back-Translated (HI → EN): * 1/2 pound chicken_breast, cut into 1 inch pieces
#
# Original: * 1/4 cup of green_beans, trimmed and cut into 1/2-inch pieces
# Translated (EN → HI): * 1/4 कप ग्रीन_बेन, कटौती और 1/2 इंच टुकड़ों में कटौती
# Back-Translated (HI → EN): * 1/4 cup green_ben, cut and cut in 1/2 inch pieces
#
# Original: * 1/4 cup of chopped strawberries
# Translated (EN → HI): * 1 / 4 कप चॉकलेट का रस
# Back-Translated (HI → EN): * 1 / 4 cup of chocolate juice
#
# Original: * 1/4 cup of chopped sweet_potato, diced
# Translated (EN → HI): * 1/4 कप चूपित मिठाई - आलू, पकाया
# Back-Translated (HI → EN): 1/4 cup of sweets - potato, cooked
#
# Original: * 1/4 cup of flour
# Translated (EN → HI): * 1 / 4 कप फूल
# Back-Translated (HI → EN): 1 / 4 cup of flowers
#
# Original: * 1/2 teaspoon of salt
# Translated (EN → HI): * 1/2 चम्मच नमक
# Back-Translated (HI → EN): * 1/2 cup of salt
#
# Original: * 1/4 teaspoon of black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: * 1/4 cup of milk
# Translated (EN → HI): * 1/4 कप दूध
# Back-Translated (HI → EN): 1/4 cup of milk
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
# Back-Translated (HI → EN): Heat the oven to 375 degrees F (190 degrees C).
#
# Original: 2. In a large skillet over medium heat, melt the butter.
# Translated (EN → HI): 2. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में, मक्खन को मिलाएं।
# Back-Translated (HI → EN): In a large skeleton above medium heat, mix the butter.
#
# Original: 3. Add the chicken and cook until browned on all sides.
# Translated (EN → HI): 3. चिकन जोड़ें और सभी पक्षों पर चमगादड़ तक पकाएं।
# Back-Translated (HI → EN): Add chicken and cook on all sides.
#
# Original: 4. Add the green beans and cook until tender and slightly crisp.
# Translated (EN → HI): 4. ग्रीन बीन्स जोड़ें और तब तक पकाएं जब तक कि पतला और थोड़ा खरपतवार न हो।
# Back-Translated (HI → EN): Add green beans and cook until they are thin and slightly crusted.
#
# Original: 5. Add the strawberries, sweet potato, flour, salt, and black pepper. Cook until heated through.
# Translated (EN → HI): 5. अनाज, मीठा आलू, फूल, नमक, और काले पेपर जोड़ें. गर्म होने तक पकाएं।
# Back-Translated (HI → EN): Add grains, sweet potatoes, flowers, salt, and black paper. cook until it is warm.
#
# Original: 6. Spoon the hash into a baking dish.
# Translated (EN → HI): 6. हश को एक बेकिंग डिश में जोड़ें।
# Back-Translated (HI → EN): Add the hash to a baking dish.
#
# Original: 7. Pour the milk over the hash and bake for 15-20 minutes, or until the potatoes are tender and the sauce is heated through.
# Translated (EN → HI): 7. हश के ऊपर दूध डालें और 15-20 मिनट के लिए पकाएं, या जब तक कि आलू तंग न हो जाएं और सॉस गर्म हो जाए।
# Back-Translated (HI → EN): Put milk over the shell and cook for 15-20 minutes, or until the potato becomes tight and the sauce becomes hot.
#
# Original: 8. Serve immediately with a side of crusty bread.
# Translated (EN → HI): 8. तुरंत क्रस्टी रोटी के एक पक्ष के साथ सेवा करें।
# Back-Translated (HI → EN): Instantly serve with one side of crocodile bread.
#
# Original: Recipe 9:
# Translated (EN → HI): नुस्खा 9 :
# Back-Translated (HI → EN): Recommended 9 :
#
# Original: **Green Bean and Mushroom Bread**
# Translated (EN → HI): ** ग्रीन बीन और मशरूम रोटी**
# Back-Translated (HI → EN): * Green beans and fungi bread*
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 loaf (1 pound) of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 कटोरा (1 पाउंड) रोटी, 1/2 इंच मोटी स्लाइड्स में घुमाया
# Back-Translated (HI → EN): * 1 cup (1 pound) bread, rotated in 1/2 inch thick slides
#
# Original: * 1/2 cup of grated mozzarella cheese
# Translated (EN → HI): * 1/2 कप ग्रेड मोज़ेरेला पनीर
# Back-Translated (HI → EN): 1/2 cup of grade mozzarella cheese
#
# Original: * 4 large eggs
# Translated (EN → HI): * 4 बड़े अंडे
# Back-Translated (HI → EN): 4 large eggs
#
# Original: * 1 tablespoon of olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1 tablespoon of chopped onion
# Translated (EN → HI): * 1 चम्मच चॉपिंग ओनिओन
# Back-Translated (HI → EN): * 1 teaspoon of choping onion
#
# Original: * 1/2 teaspoon of dried oregano
# Translated (EN → HI): * 1/2 चम्मच सूखे ओरेगानो
# Back-Translated (HI → EN): 1/2 cup of dry oregano
#
# Original: * 1/4 teaspoon of salt
# Translated (EN → HI): * 1/4 चम्मच नमक
# Back-Translated (HI → EN): * 1/4 cup of salt
#
# Original: * 1/4 teaspoon of black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: * 1/4 cup of green beans, trimmed and cut into 1/2-inch pieces
# Translated (EN → HI): * 1/4 कप ग्रीन बीन्स, काट दिया और 1/2 इंच टुकड़ों में काट दिया
# Back-Translated (HI → EN): 1/4 cup of green beans, cut and cut into 1/2 inch pieces
#
# Original: * 1/4 cup of sliced mushrooms
# Translated (EN → HI): * 1 / 4 गिलास चमगादड़
# Back-Translated (HI → EN): * 1 / 4 glass
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
# Back-Translated (HI → EN): Heat the oven to 375 degrees F (190 degrees C).
#
# Original: 2. In a large bowl, combine the bread slices, mozzarella cheese, eggs, olive oil, onion, oregano, salt, and black pepper.
# Translated (EN → HI): 2. एक बड़े बोतल में, रोटी स्लाइड्स, मोज़ेरेला पनीर, अंडे, जैतून का तेल, अनाज, ओरेगानो, नमक, और काले पेपर को जोड़ें।
# Back-Translated (HI → EN): In a large bottle, add bread slides, mozzarella cheese, eggs, olive oil, grains, oregano, salt, and black paper.
#
# Original: 3. Spread the bread mixture out on a baking sheet lined with parchment paper.
# Translated (EN → HI): 3. रोटी मिश्रण को एक पकेजिंग शीट पर फैलाएं, जो पार्चमेंट पेपर के साथ लपेटी जाती है।
# Back-Translated (HI → EN): Spread the bread mixture on a packaging sheet, which is covered with parchment paper.
#
# Original: 4. Bake for 15-20 minutes, or until the bread is golden brown and the cheese is melted and bubbly.
# Translated (EN → HI): 4. 15-20 मिनट के लिए पकाएं, या जब तक रोटी सोने का काला नहीं है और पनीर मिश्रित और ब्लेड हो जाता है।
# Back-Translated (HI → EN): Cook for 15-20 minutes, or until the bread is not black of gold and cheese is mixed and blade.
#
# Original: 5. Serve hot with the green beans and mushrooms.
# Translated (EN → HI): 5. हरी बीन्स और मशरूम के साथ गर्म सेवा करें।
# Back-Translated (HI → EN): Served warm with green beans and fungi.
#
# Original: Recipe 10:
# Translated (EN → HI): नुस्खा 10 :
# Back-Translated (HI → EN): Recommended 10 :
#
# Original: **Green Bean and Mushroom Bread**
# Translated (EN → HI): ** ग्रीन बीन और मशरूम रोटी**
# Back-Translated (HI → EN): * Green beans and fungi bread*
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 loaf (1 pound) of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 कटोरा (1 पाउंड) रोटी, 1/2 इंच मोटी स्लाइड्स में घुमाया
# Back-Translated (HI → EN): * 1 cup (1 pound) bread, rotated in 1/2 inch thick slides
#
# Original: * 1/2 cup of grated mozzarella cheese
# Translated (EN → HI): * 1/2 कप ग्रेड मोज़ेरेला पनीर
# Back-Translated (HI → EN): 1/2 cup of grade mozzarella cheese
#
# Original: * 4 large eggs
# Translated (EN → HI): * 4 बड़े अंडे
# Back-Translated (HI → EN): 4 large eggs
#
# Original: * 1 tablespoon of olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1 tablespoon of chopped onion
# Translated (EN → HI): * 1 चम्मच चॉपिंग ओनिओन
# Back-Translated (HI → EN): * 1 teaspoon of choping onion
#
# Original: * 1/2 teaspoon of dried oregano
# Translated (EN → HI): * 1/2 चम्मच सूखे ओरेगानो
# Back-Translated (HI → EN): 1/2 cup of dry oregano
#
# Original: * 1/4 teaspoon of salt
# Translated (EN → HI): * 1/4 चम्मच नमक
# Back-Translated (HI → EN): * 1/4 cup of salt
#
# Original: * 1/4 teaspoon of black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: * 1/4 cup of green beans, trimmed and cut into 1/2-inch pieces
# Translated (EN → HI): * 1/4 कप ग्रीन बीन्स, काट दिया और 1/2 इंच टुकड़ों में काट दिया
# Back-Translated (HI → EN): 1/4 cup of green beans, cut and cut into 1/2 inch pieces
#
# Original: * 1/4 cup of sliced mushrooms
# Translated (EN → HI): * 1 / 4 गिलास चमगादड़
# Back-Translated (HI → EN): * 1 / 4 glass
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
# Back-Translated (HI → EN): Heat the oven to 375 degrees F (190 degrees C).
#
# Original: 2. In a large bowl, combine the bread slices, mozzarella cheese, eggs, olive oil, onion, oregano, salt, and black pepper.
# Translated (EN → HI): 2. एक बड़े बोतल में, रोटी स्लाइड्स, मोज़ेरेला पनीर, अंडे, जैतून का तेल, अनाज, ओरेगानो, नमक, और काले पेपर को जोड़ें।
# Back-Translated (HI → EN): In a large bottle, add bread slides, mozzarella cheese, eggs, olive oil, grains, oregano, salt, and black paper.
#
# Original: 3. Spread the bread mixture out on a baking sheet lined with parchment paper.
# Translated (EN → HI): 3. रोटी मिश्रण को एक पकेजिंग शीट पर फैलाएं, जो पार्चमेंट पेपर के साथ लपेटी जाती है।
# Back-Translated (HI → EN): Spread the bread mixture on a packaging sheet, which is covered with parchment paper.
#
# Original: 4. Bake for 15-20 minutes, or until the bread is golden brown and the cheese is melted and bubbly.
# Translated (EN → HI): 4. 15-20 मिनट के लिए पकाएं, या जब तक रोटी सोने का काला नहीं है और पनीर मिश्रित और ब्लेड हो जाता है।
# Back-Translated (HI → EN): Cook for 15-20 minutes, or until the bread is not black of gold and cheese is mixed and blade.
#
# Original: 5. Serve hot with the green beans and mushrooms.
# Translated (EN → HI): 5. हरी बीन्स और मशरूम के साथ गर्म सेवा करें।
# Back-Translated (HI → EN): Served warm with green beans and fungi.
#
# Original: Recipe 11:
# Translated (EN → HI): नुस्खा 11 :
# Back-Translated (HI → EN): The 11th edition:
#
# Original: **Mushroom and Cheese Bread with Green Bean Mash**
# Translated (EN → HI): ** ग्रीन बीन मश के साथ मशरूम और पनीर रोटी**
# Back-Translated (HI → EN): ** Mush and cheese bread with green bean*
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 loaf (1 pound) of bread, sliced into 1/2-inch thick slices
# Translated (EN → HI): * 1 कटोरा (1 पाउंड) रोटी, 1/2 इंच मोटी स्लाइड्स में घुमाया
# Back-Translated (HI → EN): * 1 cup (1 pound) bread, rotated in 1/2 inch thick slides
#
# Original: * 1/2 pound of grated mozzarella cheese
# Translated (EN → HI): * 1 पाउंड कच्चे मोज़ेरेला पनीर
# Back-Translated (HI → EN): * 1 pound raw mozzarella cheese
#
# Original: * 1/4 cup of chopped green beans
# Translated (EN → HI): * 1/4 कप चॉपिंग ग्रीन बीन्स
# Back-Translated (HI → EN): 1/4 cup of chopping green beans
#
# Original: * 1/4 cup of chopped mushrooms
# Translated (EN → HI): * 1 / 4 कप चॉकलेट
# Back-Translated (HI → EN): 1 / 4 cup of chocolate
#
# Original: * 2 large eggs, beaten
# Translated (EN → HI): * 2 बड़े अंडे, हिट
# Back-Translated (HI → EN): 2 big eggs, hit
#
# Original: * 1 tablespoon of olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1/2 teaspoon of salt
# Translated (EN → HI): * 1/2 चम्मच नमक
# Back-Translated (HI → EN): * 1/2 cup of salt
#
# Original: * 1/4 teaspoon of black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Preheat oven to 375 degrees F (190 degrees C).
# Translated (EN → HI): 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
# Back-Translated (HI → EN): Heat the oven to 375 degrees F (190 degrees C).
#
# Original: 2. In a large bowl, combine the bread slices, mozzarella cheese, and green beans.
# Translated (EN → HI): 2. एक बड़े बोतल में, रोटी के स्लाइड्स, मोज़ेरेला पनीर, और हरे बीन्स को जोड़ें।
# Back-Translated (HI → EN): In a large bottle, add bread slides, mozzarella cheese, and green beans.
#
# Original: 3. In a separate bowl, whisk together the eggs, olive oil, salt, and black pepper.
# Translated (EN → HI): 3. एक अलग बोतल में, अंडे, जैतून का तेल, नमक और काले पेपर को एक साथ मिलाएं।
# Back-Translated (HI → EN): In a separate bottle, mix eggs, olive oil, salt and black paper together.
#
# Original: 4. Add the wet ingredients to the dry ingredients and stir until just combined. Do not overmix.
# Translated (EN → HI): 4. सूखे अवयवों में गीले अवयवों को जोड़ें और मिश्रित होने तक मिश्रण करें. अति मिश्रण न करें.
# Back-Translated (HI → EN): Add wet ingredients to dry ingredients and mix until they are mixed.
#
# Original: 5. Pour the mixture into a greased 9x13-inch baking dish.
# Translated (EN → HI): 5. मिश्रण को एक गीला 9x13-इंच पाक व्यंजन में डालें।
# Back-Translated (HI → EN): Put the mixture into a wet 9x13-inch cooked dish.
#
# Original: 6. Bake for 20-25 minutes, or until the bread is golden brown and the cheese is melted and bubbly.
# Translated (EN → HI): 6. 20-25 मिनट के लिए पकाएं, या जब तक कि रोटी सोने का काला नहीं है और पनीर मिश्रित और ब्लेड हो जाता है।
# Back-Translated (HI → EN): Cook for 20-25 minutes, or until the bread is not black of gold and cheese is mixed and blade.
#
# Original: 7. Serve hot with a side of green bean mash.
# Translated (EN → HI): 7. ग्रीन बीन मश के एक पक्ष के साथ गर्म सेवा करें।
# Back-Translated (HI → EN): Heat service with one side of green beans.
#
# Original: **Green Bean Mash:**
# Translated (EN → HI): * ग्रीन बीन मश: *
# Back-Translated (HI → EN): * Green Bean Mush: *
#
# Original: * 1 tablespoon of olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): * 1 ओनिओन, डाइक
# Back-Translated (HI → EN): 1 onion, dicks
#
# Original: * 2 cloves of garlic, minced
# Translated (EN → HI): * 2 चम्मच चॉकलेट, मिनी
# Back-Translated (HI → EN): 2 cups of chocolate, mini
#
# Original: * 1 (15-ounce) can of green beans, drained and rinsed
# Translated (EN → HI): * 1 (15 औंस) कैन ग्रीन बीन्स, ड्रिलिंग और रनिंग
# Back-Translated (HI → EN): * 1 (15 ounces) can green beans, drilling and running
#
# Original: * 1/2 cup of milk
# Translated (EN → HI): * 1/2 कप दूध
# Back-Translated (HI → EN): 1/2 cup of milk
#
# Original: * 1/4 cup of grated mozzarella cheese
# Translated (EN → HI): * 1/4 कप ग्रेड मोज़ेरेला पनीर
# Back-Translated (HI → EN): 1/4 cup of grade mozzarella cheese
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Heat the olive oil in a large pot or Dutch oven over medium heat.
# Translated (EN → HI): 1. एक बड़े कटोरे में या मध्यम गर्मी पर नीदरलैंड ओवन में जैतून का तेल गर्म करें।
# Back-Translated (HI → EN): Warm olive oil in a large cup or in a medium heat in the Netherlands oven.
#
# Original: 2. Add the onion and garlic and cook until softened, about 5 minutes.
# Translated (EN → HI): 2. अनाज और चॉकलेट जोड़ें और लगभग 5 मिनट तक नरम होने तक पकाएं।
# Back-Translated (HI → EN): Add cereals and chocolate and cook until soft for about 5 minutes.
#
# Original: 3. Add the green beans and milk and bring to a boil.
# Translated (EN → HI): 3. हरी बीन्स और दूध जोड़ें और एक कटोरे में लाएं।
# Back-Translated (HI → EN): Add green beans and milk and bring in a cup.
#
# Original: 4. Reduce heat to low and simmer for 10 minutes, or until the green beans are tender.
# ...
# Translated (EN → HI): 5. मोज़ेरेला पनीर और पनीर को स्कीलेट में जोड़ें और 5 मिनट के लिए पकाएं, या जब तक मिट जाएं।
# Back-Translated (HI → EN): 5.Mozerella cheese and cheese add to the skeleton and cook for 5 minutes, or until they are dried.
#
# Original: 6. Serve the beef and green bean shepherd's pie in a baking dish.
# Translated (EN → HI): 6. बीफ और हरे बीन चरवाहे के पाई को एक पकाने के व्यंजन में सेवा करें।
# Back-Translated (HI → EN): Beef and green beans serve the pastoral cake in a cooking dish.
#
# Original: 7. Bake for 20-25 minutes, or until the cheese is melted and bubbly.
# Translated (EN → HI): 7. 20-25 मिनट के लिए उबाल लें, या जब तक कि पनीर मिट जाए और ब्लेड हो जाए।
# Back-Translated (HI → EN): Cook for 20-25 minutes, or until the cheese is dried and blade.
#
# Original: Recipe 17:
# Translated (EN → HI): अनुच्छेद 17 :
# Back-Translated (HI → EN): Article 17 :
#
# Original: **Blueberry Potato Green Bean Hash**
# Translated (EN → HI): ब्लूबेरी पाउडर ग्रीन बीन हैश
# Back-Translated (HI → EN): Blueberry Powder Green Bean Hash
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 2 large potatoes, peeled and diced into 1/2-inch cubes
# Translated (EN → HI): * 2 बड़े आलू, पिलाया और 1/2 इंच के क्यूब में डाला
# Back-Translated (HI → EN): * 2 large potatoes, pilaya and put into 1/2 inch cubes
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): * 1 ओनिओन, डाइक
# Back-Translated (HI → EN): 1 onion, dicks
#
# Original: * 2 cloves garlic, minced
# Translated (EN → HI): * 2 चम्मच ग्रीनहाउस, मिनी
# Back-Translated (HI → EN): 2 cups of greenhouse, mini
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चम्मच नमक
# Back-Translated (HI → EN): * 1/2 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: * 1/2 cup blueberries
# Translated (EN → HI): 1/2 कप ब्लूबेरी
# Back-Translated (HI → EN): 1/2 cup of blueberry
#
# Original: * 1/4 cup grated cheese
# Translated (EN → HI): * 1/4 कप ग्रेड पनीर
# Back-Translated (HI → EN): 1/4 cup of grade cheese
#
# Original: * 1/4 cup green beans, trimmed and cut into 1/2-inch pieces
# Translated (EN → HI): * 1/4 कप ग्रीन बीन्स, कटौती और 1/2 इंच टुकड़ों में कटौती
# Back-Translated (HI → EN): 1/4 cup of green beans, cut and cut in 1/2 inch pieces
#
# Original: * 1/4 cup lime juice
# Translated (EN → HI): * 1/4 कप लहसुन का रस
# Back-Translated (HI → EN): 1/4 cup of cheese juice
#
# Original: * 1 tablespoon flour
# Translated (EN → HI): * 1 टैबलेट फूल
# Back-Translated (HI → EN): 1 tablet of flowers
#
# Original: * 1/2 teaspoon baking powder
# Translated (EN → HI): * 1/2 चम्मच पके हुए पाउडर
# Back-Translated (HI → EN): * 1/2 cup of cooked powder
#
# Original: * 1/4 teaspoon salt
# Translated (EN → HI): * 1/4 चम्मच नमक
# Back-Translated (HI → EN): * 1/4 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Heat the olive oil in a large skillet or Dutch oven over medium heat.
# Translated (EN → HI): 1. ओलिव तेल को मध्यम गर्मी से ऊपर एक बड़े स्केलिट या डच ओवन में गर्म करें।
# Back-Translated (HI → EN): Heat the olive oil above moderate heat in a large skeleton or Dutch oven.
#
# Original: 2. Add the onion and garlic and cook until softened, about 5 minutes.
# Translated (EN → HI): 2. अनाज और चॉकलेट जोड़ें और लगभग 5 मिनट तक नरम होने तक पकाएं।
# Back-Translated (HI → EN): Add cereals and chocolate and cook until soft for about 5 minutes.
#
# Original: 3. Add the potatoes and cook until tender and golden brown, about 15 minutes.
# Translated (EN → HI): 3. आलू जोड़ें और पनीर और गोल्डन ब्राउन तक पकाएं, लगभग 15 मिनट।
# Back-Translated (HI → EN): Add potatoes and cook until cheese and golden brown, about 15 minutes.
#
# Original: 4. Add the blueberries, cheese, green beans, lime juice, flour, baking powder, salt, and black pepper.
# Translated (EN → HI): 4. ब्लूबेरी, पनीर, हरे बीन्स, लहसुन का रस, फूल, पाउडर, नमक, और काले पेपर जोड़ें।
# Back-Translated (HI → EN): Add blueberry, cheese, green beans, cheese juice, flowers, powder, salt, and black paper.
#
# Original: 5. Bring to a simmer and cook for 10 minutes, or until the potatoes are cooked through and the greens are tender.
# Translated (EN → HI): 5. एक समुद्र तट पर लाएं और 10 मिनट के लिए पकाएं, या जब तक कि आलू को पकाया जाता है और हरे रंग को पतला किया जाता है।
# Back-Translated (HI → EN): Bring to a beach and cook for 10 minutes, or until the potato is cooked and the green is thin.
#
# Original: 6. Serve immediately.
# Translated (EN → HI): 6. तुरंत सेवा करें।
# Back-Translated (HI → EN): Service immediately.
#
# Original: Recipe 18:
# Translated (EN → HI): रीसेट 18:
# Back-Translated (HI → EN): Recalled 18:
#
# Original: **Blueberry-Cheese-Green Bean Hash with Potato and Spinach**
# Translated (EN → HI): **Blueberry-Cheese-Green Bean Hash के साथ आलू और स्पंज**
# Back-Translated (HI → EN): **Blueberry-Cheese-Green Bean Hash with Potato and Sponge**
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): * 1 ओनिओन, डाइक
# Back-Translated (HI → EN): 1 onion, dicks
#
# Original: * 1 green bean, diced
# Translated (EN → HI): * 1 ग्रीन बीन, डाइक
# Back-Translated (HI → EN): * 1 green bean, dick
#
# Original: * 4 eggs, beaten
# Translated (EN → HI): * 4 अंडे, हिट
# Back-Translated (HI → EN): 4 eggs, hit
#
# Original: * 1/2 cup shredded cheese
# Translated (EN → HI): * 1/2 चम्मच पकाया पनीर
# Back-Translated (HI → EN): 1/2 cup of cooked cheese
#
# Original: * 1/4 cup chopped blueberries
# Translated (EN → HI): * 1/4 कप चॉपिंग ब्लूबेरी
# Back-Translated (HI → EN): 1/4 cup of chopping blueberry
#
# Original: * 1 tablespoon lime juice
# Translated (EN → HI): * 1 चम्मच लहसुन का रस
# Back-Translated (HI → EN): * 1 cup of cheese juice
#
# Original: * 1 tablespoon chopped fresh parsley
# Translated (EN → HI): * 1 चॉकलेट चॉकलेट ताजा पेंसिल
# Back-Translated (HI → EN): 1 Chocolate Chocolate Fresh Pencil
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चम्मच नमक
# Back-Translated (HI → EN): * 1/2 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Heat olive oil in a large skillet over medium heat.
# Translated (EN → HI): 1. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में तेल गर्म करें।
# Back-Translated (HI → EN): Heat the oil in a large skeleton above medium heat.
#
# Original: 2. Add onion and green bean and cook until tender, about 5 minutes.
# Translated (EN → HI): 2. अनाज और हरी बीन्स जोड़ें और पनीर तक पकाएं, लगभग 5 मिनट।
# Back-Translated (HI → EN): Add cereals and green beans and cook until cheese, about 5 minutes.
#
# Original: 3. Add eggs and cook until sunny-side up.
# Translated (EN → HI): 3. अंडे जोड़ें और सूरज के पक्ष तक पकाएं।
# Back-Translated (HI → EN): Add eggs and cook to the sun side.
#
# Original: 4. Add cheese, blueberries, lime juice, parsley, salt, and pepper to the skillet.
# Translated (EN → HI): 4. पनीर, ब्लूबेरी, लहसुन का रस, मक्खन, नमक और पेपर को स्केलिट में जोड़ें।
# Back-Translated (HI → EN): Add cheese, blueberry, cheese juice, butter, salt and paper to the skeleton.
#
# Original: 5. Cook for 5 minutes, or until the potatoes are tender and the sauce is heated through.
# Translated (EN → HI): 5. 5 मिनट के लिए पकाएं, या जब तक कि आलू तंग न हो जाएं और सॉस गर्म हो जाए।
# Back-Translated (HI → EN): Cook for 5 minutes, or until the potato becomes tight and the sauce becomes hot.
#
# Original: 6. Serve immediately.
# Translated (EN → HI): 6. तुरंत सेवा करें।
# Back-Translated (HI → EN): Service immediately.
#
# Original: Recipe 19:
# Translated (EN → HI): अनुच्छेद 19:
# Back-Translated (HI → EN): Article 19 :
#
# Original: **Blueberry-Cheese-Green Bean Hash with Potato and Spinach**
# Translated (EN → HI): **Blueberry-Cheese-Green Bean Hash के साथ आलू और स्पंज**
# Back-Translated (HI → EN): **Blueberry-Cheese-Green Bean Hash with Potato and Sponge**
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1 onion, diced
# Translated (EN → HI): * 1 ओनिओन, डाइक
# Back-Translated (HI → EN): 1 onion, dicks
#
# Original: * 1 green bean, diced
# Translated (EN → HI): * 1 ग्रीन बीन, डाइक
# Back-Translated (HI → EN): * 1 green bean, dick
#
# Original: * 1/2 pound potatoes, diced
# Translated (EN → HI): * 1/2 पाउंड आलू, पकाया
# Back-Translated (HI → EN): 1/2 pound of potato, cooked
#
# Original: * 1/2 pound fresh spinach
# Translated (EN → HI): * 1 पाउंड ताजा स्पंज
# Back-Translated (HI → EN): * 1 pound fresh sponge
#
# Original: * 1/4 cup grated mozzarella cheese
# Translated (EN → HI): * 1/4 कप ग्रेड मोज़ेरेला पनीर
# Back-Translated (HI → EN): 1/4 cup of grade mozzarella cheese
#
# Original: * 2 large eggs
# Translated (EN → HI): * 2 बड़े अंडे
# Back-Translated (HI → EN): 2 large eggs
#
# Original: * 1 tablespoon lime juice
# Translated (EN → HI): * 1 चम्मच लहसुन का रस
# Back-Translated (HI → EN): * 1 cup of cheese juice
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चम्मच नमक
# Back-Translated (HI → EN): * 1/2 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Heat olive oil in a large skillet over medium heat.
# Translated (EN → HI): 1. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में तेल गर्म करें।
# Back-Translated (HI → EN): Heat the oil in a large skeleton above medium heat.
#
# Original: 2. Add onion and green bean and cook until tender, about 5 minutes.
# Translated (EN → HI): 2. अनाज और हरी बीन्स जोड़ें और पनीर तक पकाएं, लगभग 5 मिनट।
# Back-Translated (HI → EN): Add cereals and green beans and cook until cheese, about 5 minutes.
#
# Original: 3. Add potatoes and spinach to the skillet and cook until tender, about 10 minutes.
# Translated (EN → HI): 3. आलू और स्पाइना को स्कीलेट में जोड़ें और लगभग 10 मिनट तक पकाएं।
# Back-Translated (HI → EN): Add the potato and spina to the skeleton and cook for about 10 minutes.
#
# Original: 4. Add eggs and lime juice to the skillet and cook until the eggs are cooked through.
# Translated (EN → HI): 4. अंडे और लहसुन का रस स्कीलेट में जोड़ें और तब तक पकाएं जब तक कि अंडे के माध्यम से पकाया नहीं जाता है।
# Back-Translated (HI → EN): Add the egg and cheese juice to the skeleton and cook until it is cooked through the egg.
#
# Original: 5. Season with salt and pepper to taste.
# Translated (EN → HI): 5. स्वाद के लिए नमक और पेपर के साथ मौसम।
# Back-Translated (HI → EN): Weather with salt and paper for taste.
#
# Original: 6. Serve immediately with cheese on top.
# Translated (EN → HI): 6. तुरंत शीर्ष पर पनीर के साथ सेवा करें।
# Back-Translated (HI → EN): Instantly serve with cheese on top.
#
# Original: Recipe 20:
# Translated (EN → HI): रेसिपी 20:
# Back-Translated (HI → EN): The Recipe 20:
#
# Original: **Blueberry Chicken with Green Bean Mash**
# Translated (EN → HI): ** ग्रीन बीन मश के साथ ब्लूबेरी चिकन**
# Back-Translated (HI → EN): *Blueberry chicken with green bean mush**
#
# Original: **Ingredients:**
# Translated (EN → HI): * सामग्री : *
# Back-Translated (HI → EN): • Materials : *
#
# Original: * 1 boneless, skinless chicken breast, cut into 4 equal pieces
# Translated (EN → HI): * 1 गंदे, त्वचाहीन चिकन स्तन, 4 समान टुकड़ों में काट दिया
# Back-Translated (HI → EN): * 1 dirty, skinless chicken breasts, cut into 4 equal pieces
#
# Original: * 1 tablespoon olive oil
# Translated (EN → HI): * 1 चम्मच जैतून का तेल
# Back-Translated (HI → EN): * 1 cup of olive oil
#
# Original: * 1/2 onion, diced
# Translated (EN → HI): * 1/2 ओनिओन, ड्रिल
# Back-Translated (HI → EN): 1/2 onion, drill
#
# Original: * 1/4 green bean, trimmed and cut into 1-inch pieces
# Translated (EN → HI): * 1/4 ग्रीन बीन, काट दिया और 1 इंच के टुकड़ों में काट दिया
# Back-Translated (HI → EN): 1/4 green bean, cut and cut into pieces of 1 inch
#
# Original: * 1/4 cup fresh spinach
# Translated (EN → HI): * 1/4 कप ताजा स्पंज
# Back-Translated (HI → EN): 1/4 cup of fresh sponge
#
# Original: * 1/4 cup grated mozzarella cheese
# Translated (EN → HI): * 1/4 कप ग्रेड मोज़ेरेला पनीर
# Back-Translated (HI → EN): 1/4 cup of grade mozzarella cheese
#
# Original: * 2 large eggs, beaten
# Translated (EN → HI): * 2 बड़े अंडे, हिट
# Back-Translated (HI → EN): 2 big eggs, hit
#
# Original: * 1 tablespoon lime juice
# Translated (EN → HI): * 1 चम्मच लहसुन का रस
# Back-Translated (HI → EN): * 1 cup of cheese juice
#
# Original: * 1 tablespoon flour
# Translated (EN → HI): * 1 टैबलेट फूल
# Back-Translated (HI → EN): 1 tablet of flowers
#
# Original: * 1/2 teaspoon salt
# Translated (EN → HI): * 1/2 चम्मच नमक
# Back-Translated (HI → EN): * 1/2 cup of salt
#
# Original: * 1/4 teaspoon black pepper
# Translated (EN → HI): * 1/4 चम्मच काले पेपर
# Back-Translated (HI → EN): 1/4 cup of black paper
#
# Original: **Instructions:**
# Translated (EN → HI): * निर्देशों के लिए: *
# Back-Translated (HI → EN): * for instructions: *
#
# Original: 1. Heat olive oil in a large skillet or Dutch oven over medium heat.
# Translated (EN → HI): 1. मध्यम गर्मी पर एक बड़े स्केलिट या नीदरलैंड ओवन में जैतून का तेल गर्म करें।
# Back-Translated (HI → EN): At medium heat, heat a large skeleton or olive oil in the Dutch oven.
#
# Original: 2. Season chicken with salt and pepper.
# Translated (EN → HI): 2. मौसम चिकन नमक और पेपर के साथ।
# Back-Translated (HI → EN): Weather chicken with salt and paper.
#
# Original: 3. Add chicken to the skillet and cook for 5-7 minutes per side, or until cooked through.
# Translated (EN → HI): 3. चिकन को स्कीलेट में जोड़ें और 5-7 मिनट के लिए पकाएं, या जब तक यह पकाया नहीं जाता है।
# Back-Translated (HI → EN): Add the chicken to the skeleton and cook for 5-7 minutes, or until it is cooked.
#
# Original: 4. Remove chicken from the skillet and set aside.
# Translated (EN → HI): 4. चिकन को स्केलिट से हटा दें और इसे एक तरफ रखें।
# Back-Translated (HI → EN): Remove the chicken from the skeleton and keep it on one side.
#
# Original: 5. Add onion and green bean to the skillet and cook until tender, about 5 minutes.
# Translated (EN → HI): 5. स्केलिट में अनाज और हरे बीन जोड़ें और लगभग 5 मिनट तक पकाएं।
# Back-Translated (HI → EN): Add grains and green beans to the skeleton and cook for about 5 minutes.
#
# Original: 6. Add spinach and cook until wilted, about 2 minutes.
# Translated (EN → HI): 6. स्पंज जोड़ें और लगभग 2 मिनट तक उबालने तक पकाएं।
# Back-Translated (HI → EN): Add sponge and cook until cooked for about 2 minutes.
#
# Original: 7. Add mozzarella cheese, eggs, lime juice, flour, and salt and pepper to the skillet.
# Translated (EN → HI): 7. मोज़ेरेला पनीर, अंडे, लहसुन का रस, फूल, और नमक और पेपर को स्कीलेट में जोड़ें।
# Back-Translated (HI → EN): 7.Mozerella cheese, eggs, cheese juice, flowers, and salt and paper add to the skeleton.
#
# Original: 8. Cook for 5 minutes, or until heated through.
# Translated (EN → HI): 8. 5 मिनट के लिए पकाएं, या गर्म होने तक।
# Back-Translated (HI → EN): Cook for 5 minutes, or until it is heated.
#
# Original: 9. Serve chicken over green bean mash.
# Translated (EN → HI): 9. ग्रीन बीन मश पर चिकन सेवा करें।
# Back-Translated (HI → EN): 9.Serving chicken on green beans.
#
# Translation and back-translation completed! Files saved:
# - Hindi Recipes: 'translated_recipe_hi.txt'
# - Back-Translated English Recipes: 'back_translated_recipe.txt'

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 1.5 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.1.1-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2.0.2)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.3.1)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 5.6 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.1.1-py3-none-any.whl (19 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.1.1 sacrebleu-2.5.1

# %%
import sacrebleu
from sentence_transformers import SentenceTransformer
from scipy.spatial.distance import cosine

# File paths
original_file = "/content/gemma-2b-it_recipes.txt"  # Original English recipes
back_translated_file = "back_translated_recipe.txt"  # Back-translated English recipes

# Read files
with open(original_file, "r", encoding="utf-8") as f:
    original_recipes = [line.strip() for line in f.readlines() if line.strip()]

with open(back_translated_file, "r", encoding="utf-8") as f:
    back_translated_recipes = [line.strip() for line in f.readlines() if line.strip()]

# Ensure both files have the same number of lines
assert len(original_recipes) == len(back_translated_recipes), "Mismatch in number of lines!"

# BLEU Score Evaluation
bleu = sacrebleu.corpus_bleu(back_translated_recipes, [original_recipes])
print(f"\nBLEU Score: {bleu.score:.2f}")

# CHRF Score Evaluation
chrf = sacrebleu.corpus_chrf(back_translated_recipes, [original_recipes])
print(f"CHRF Score: {chrf.score:.2f}")

# Cosine Similarity Evaluation using LaBSE
model = SentenceTransformer("sentence-transformers/LaBSE")

def get_similarity(text1, text2):
    emb1 = model.encode(text1, convert_to_tensor=True)
    emb2 = model.encode(text2, convert_to_tensor=True)
    return 1 - cosine(emb1, emb2)

# Compute similarity for all recipes
similarities = [get_similarity(orig, back) for orig, back in zip(original_recipes, back_translated_recipes)]
average_similarity = sum(similarities) / len(similarities)

print(f"Average Cosine Similarity: {average_similarity:.4f}")
# Out:
# BLEU Score: 34.17
# CHRF Score: 53.83
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.02k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/804 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.88G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/397 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/5.22M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.62M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/114 [00:00<?, ?B/s]
# Average Cosine Similarity: 0.8364

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install --upgrade transformers
# Out:
# Found existing installation: torch 2.6.0+cu124
# Uninstalling torch-2.6.0+cu124:
#   Successfully uninstalled torch-2.6.0+cu124
# Found existing installation: torchvision 0.21.0+cu124
# Uninstalling torchvision-0.21.0+cu124:
#   Successfully uninstalled torchvision-0.21.0+cu124
# Found existing installation: torchaudio 2.6.0+cu124
# Uninstalling torchaudio-2.6.0+cu124:
#   Successfully uninstalled torchaudio-2.6.0+cu124
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (26 kB)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.21.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl (178.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 MB 7.5 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchvision-0.21.0%2Bcpu-cp311-cp311-linux_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 56.7 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 57.2 MB/s eta 0:00:00
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-2.6.0+cpu torchaudio-2.6.0+cpu torchvision-0.21.0+cpu
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.0)
# Collecting transformers
#   Downloading transformers-4.50.2-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Downloading transformers-4.50.2-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 61.5 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.50.0
#     Uninstalling transformers-4.50.0:
# ERROR: Operation cancelled by user
# ^C

# %%
# !pip install laserembeddings
# Out:
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# Collecting laserembeddings
#   Downloading laserembeddings-1.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy<2.0.0,>=1.15.4 (from laserembeddings)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.4 MB/s eta 0:00:00
# Collecting sacremoses==0.0.35 (from laserembeddings)
#   Downloading sacremoses-0.0.35.tar.gz (859 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.8/859.8 kB 15.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting subword-nmt<0.4.0,>=0.3.6 (from laserembeddings)
#   Downloading subword_nmt-0.3.8-py3-none-any.whl.metadata (9.2 kB)
# Collecting torch<2.0.0,>=1.0.1.post2 (from laserembeddings)
#   Downloading torch-1.13.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting transliterate==1.10.2 (from laserembeddings)
#   Downloading transliterate-1.10.2-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from sacremoses==0.0.35->laserembeddings) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from sacremoses==0.0.35->laserembeddings) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from sacremoses==0.0.35->laserembeddings) (1.4.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from sacremoses==0.0.35->laserembeddings) (4.67.1)
# Collecting mock (from subword-nmt<0.4.0,>=0.3.6->laserembeddings)
#   Downloading mock-5.2.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch<2.0.0,>=1.0.1.post2->laserembeddings) (4.12.2)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<2.0.0,>=1.0.1.post2->laserembeddings)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<2.0.0,>=1.0.1.post2->laserembeddings)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<2.0.0,>=1.0.1.post2->laserembeddings)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<2.0.0,>=1.0.1.post2->laserembeddings)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.0.1.post2->laserembeddings) (75.1.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.0.1.post2->laserembeddings) (0.45.1)
# Downloading laserembeddings-1.1.2-py3-none-any.whl (13 kB)
# Downloading transliterate-1.10.2-py2.py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.1 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 43.2 MB/s eta 0:00:00
# Downloading subword_nmt-0.3.8-py3-none-any.whl (27 kB)
# Downloading torch-1.13.1-cp311-cp311-manylinux1_x86_64.whl (887.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 MB 567.1 kB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 77.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 39.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 1.8 MB/s eta 0:00:00
# Downloading mock-5.2.0-py3-none-any.whl (31 kB)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.35-py3-none-any.whl size=883961 sha256=208a2ff1c26e1c48776a7eb3d6e289334e28201e5c477cac99b6d1297e6a6951
#   Stored in directory: /root/.cache/pip/wheels/38/dd/61/9feb9767a39c2d6683b4cf2eb4e568d9c0a8228e9120c80e27
# Successfully built sacremoses
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# Installing collected packages: transliterate, sacremoses, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, mock, subword-nmt, nvidia-cudnn-cu11, torch, laserembeddings
#   Attempting uninstall: numpy
#     WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: torch
#     WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
#     Found existing installation: torch 2.6.0+cpu
#     Uninstalling torch-2.6.0+cpu:
#       Successfully uninstalled torch-2.6.0+cpu
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cpu requires torch==2.6.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.21.0+cpu requires torch==2.6.0, but you have torch 1.13.1 which is incompatible.
# accelerate 1.5.2 requires torch>=2.0.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed laserembeddings-1.1.2 mock-5.2.0 numpy-1.26.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 sacremoses-0.0.35 subword-nmt-0.3.8 torch-1.13.1 transliterate-1.10.2

# %%
# !pip uninstall torch torchvision torchaudio -y
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# !pip install --upgrade transformers
# Out:
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping torchaudio as it is not installed.
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (26 kB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cpu/torchvision-0.21.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Using cached https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl (178.7 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchvision-0.21.0%2Bcpu-cp311-cp311-linux_x86_64.whl (1.8 MB)
# Using cached https://download.pytorch.org/whl/cpu/torchaudio-2.6.0%2Bcpu-cp311-cp311-linux_x86_64.whl (1.7 MB)
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# Installing collected packages: torch, torchvision, torchaudio
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# laserembeddings 1.1.2 requires torch<2.0.0,>=1.0.1.post2, but you have torch 2.6.0+cpu which is incompatible.
# Successfully installed torch-2.6.0+cpu torchaudio-2.6.0+cpu torchvision-0.21.0+cpu
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.50.0)
# Collecting transformers
#   Using cached transformers-4.50.2-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.29.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.26.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.1.31)
# Using cached transformers-4.50.2-py3-none-any.whl (10.2 MB)
# WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     WARNING: Skipping /usr/local/lib/python3.11/dist-packages/~ransformers-4.50.0.dist-info due to invalid metadata entry 'name'
#     Found existing installation: transformers 4.50.0
#     Uninstalling transformers-4.50.0:
#       Successfully uninstalled transformers-4.50.0
# Successfully installed transformers-4.50.2

# %%
# !python -m laserembeddings download-models
# Out:
# Downloading models into /usr/local/lib/python3.11/dist-packages/laserembeddings/data
#
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/93langs.fcodes
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/93langs.fvocab
# ✅   Downloaded https://dl.fbaipublicfiles.com/laser/models/bilstm.93langs.2018-12-26.pt
#
# ✨ You're all set!

# %%
import torch
from transformers import AutoModel, AutoTokenizer
import numpy as np
from sentence_transformers import SentenceTransformer
from laserembeddings import Laser
from sklearn.metrics.pairwise import cosine_similarity

# Load Recipe Texts
def load_text(file_path):
    with open(file_path, "r", encoding="utf-8") as f:
        return [line.strip() for line in f.readlines() if line.strip()]

# Load English and Hindi recipes
english_recipes = load_text("/content/gemma-2b-it_recipes.txt")
hindi_recipes = load_text("/content/translated_recipe_hi.txt")

assert len(english_recipes) == len(hindi_recipes), "Mismatch in number of recipes!"

# ------------------- LaBSE -------------------
def get_labse_embeddings(sentences):
    model_name = "sentence-transformers/LaBSE"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)

    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1)  # Average pooling
    return embeddings.numpy()

# ------------------- XLM-R -------------------
def get_xlmr_embeddings(sentences):
    model_name = "xlm-roberta-large"
    tokenizer = AutoTokenizer.from_pretrained(model_name)
    model = AutoModel.from_pretrained(model_name)

    inputs = tokenizer(sentences, padding=True, truncation=True, return_tensors="pt")
    with torch.no_grad():
        outputs = model(**inputs)
    embeddings = outputs.last_hidden_state.mean(dim=1)  # Average pooling
    return embeddings.numpy()

# ------------------- LASER -------------------
def get_laser_embeddings(sentences):
    laser = Laser()
    return laser.embed_sentences(sentences, lang="en")  # Detects language automatically

# ------------------- Compute Similarity -------------------
def compute_similarity(embeddings1, embeddings2):
    return cosine_similarity(embeddings1, embeddings2).diagonal()

# ------------------- Run All Models -------------------
labse_en = get_labse_embeddings(english_recipes)
labse_hi = get_labse_embeddings(hindi_recipes)
labse_sim = compute_similarity(labse_en, labse_hi)

xlmr_en = get_xlmr_embeddings(english_recipes)
xlmr_hi = get_xlmr_embeddings(hindi_recipes)
xlmr_sim = compute_similarity(xlmr_en, xlmr_hi)

laser_en = get_laser_embeddings(english_recipes)
laser_hi = get_laser_embeddings(hindi_recipes)
laser_sim = compute_similarity(laser_en, laser_hi)

# ------------------- Display Results -------------------
for i, (eng, hin, s1, s2, s3) in enumerate(zip(english_recipes, hindi_recipes, labse_sim, xlmr_sim, laser_sim)):
    print(f"🔹 Recipe {i+1}")
    print(f"   English: {eng}")
    print(f"   Hindi: {hin}")
    print(f"   🔹 LaBSE Similarity: {s1:.4f}")
    print(f"   🔹 XLM-R Similarity: {s2:.4f}")
    print(f"   🔹 LASER Similarity: {s3:.4f}")
    print("-" * 50)

# ------------------- Summary -------------------
print("\n✅ Average Similarity Scores:")
print(f"   🔹 LaBSE: {np.mean(labse_sim):.4f}")
print(f"   🔹 XLM-R: {np.mean(xlmr_sim):.4f}")
print(f"   🔹 LASER: {np.mean(laser_sim):.4f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/616 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# 🔹 Recipe 1
#    English: Recipe 1:
#    Hindi: नुस्खा 1 :
#    🔹 LaBSE Similarity: 0.9398
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8767
# --------------------------------------------------
# 🔹 Recipe 2
#    English: **The Dish:**
#    Hindi: * डिश के बारे में: *
#    🔹 LaBSE Similarity: 0.8229
#    🔹 XLM-R Similarity: 0.9961
#    🔹 LASER Similarity: 0.8010
# --------------------------------------------------
# 🔹 Recipe 3
#    English: **Spicy Carrot Bread with Strawberry Glaze**
#    Hindi: ** स्ट्रॉबेरी ग्लेज़ के साथ स्वादिष्ट कार्बोहाइड्रेट रोटी**
#    🔹 LaBSE Similarity: 0.8793
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8314
# --------------------------------------------------
# 🔹 Recipe 4
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 5
#    English: * 1 loaf (12 slices) bread, sliced into 1/2-inch thick slices
#    Hindi: * 1 लहसुन (12 स्लाइड्स) रोटी, 1/2 इंच मोटी स्लाइड्स में स्लाइड
#    🔹 LaBSE Similarity: 0.9058
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8828
# --------------------------------------------------
# 🔹 Recipe 6
#    English: * 1 large carrot, diced
#    Hindi: * 1 बड़ा कार्बोहाइड्रेट, कटा हुआ
#    🔹 LaBSE Similarity: 0.8633
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.8026
# --------------------------------------------------
# 🔹 Recipe 7
#    English: * 1/2 cup chocolate chips
#    Hindi: 1/2 कप चॉकलेट चिप्स
#    🔹 LaBSE Similarity: 0.9000
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.9016
# --------------------------------------------------
# 🔹 Recipe 8
#    English: * 1 tablespoon flour
#    Hindi: * 1 टैबलेट फूल
#    🔹 LaBSE Similarity: 0.7778
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.8142
# --------------------------------------------------
# 🔹 Recipe 9
#    English: * 1 tablespoon green_beans, chopped
#    Hindi: * 1 टैबलेट green_beans, चॉपिंग
#    🔹 LaBSE Similarity: 0.8988
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.9325
# --------------------------------------------------
# 🔹 Recipe 10
#    English: * 1 tablespoon ground_beef
#    Hindi: * 1 टैबलेट मिट्टी_बीईएफ
#    🔹 LaBSE Similarity: 0.8489
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7980
# --------------------------------------------------
# 🔹 Recipe 11
#    English: * 1/2 lime, juiced
#    Hindi: * 1/2 लहसुन, जूस
#    🔹 LaBSE Similarity: 0.9029
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.7785
# --------------------------------------------------
# 🔹 Recipe 12
#    English: * 1/4 cup strawberries, diced
#    Hindi: * 1/4 गिलास अनाज, पकाया
#    🔹 LaBSE Similarity: 0.8502
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.8248
# --------------------------------------------------
# 🔹 Recipe 13
#    English: * 1 tablespoon sugars
#    Hindi: * 1 टैबलेट शर्करा
#    🔹 LaBSE Similarity: 0.8554
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.7963
# --------------------------------------------------
# 🔹 Recipe 14
#    English: * 1 tablespoon tomato paste
#    Hindi: * 1 टैबलेट टमाटर पेस्ट
#    🔹 LaBSE Similarity: 0.9123
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.7816
# --------------------------------------------------
# 🔹 Recipe 15
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 16
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
#    🔹 LaBSE Similarity: 0.9420
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8737
# --------------------------------------------------
# 🔹 Recipe 17
#    English: 2. In a large skillet, cook the carrot and green_beans over medium heat until tender and slightly browned.
#    Hindi: 2. एक बड़े स्केलिट में, मध्यम गर्मी पर कार्बोहाइड्रेट और ग्रीन_बेन को पकाएं, जब तक कि यह तंग और थोड़ा चमकदार न हो।
#    🔹 LaBSE Similarity: 0.9026
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8821
# --------------------------------------------------
# 🔹 Recipe 18
#    English: 3. Add the ground_beef to the skillet and cook until browned.
#    Hindi: 3. स्केलिट में भूमि_बईफ जोड़ें और चमक तक पकाएं।
#    🔹 LaBSE Similarity: 0.8858
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7327
# --------------------------------------------------
# 🔹 Recipe 19
#    English: 4. Add the lime juice, strawberries, and sugars to the skillet and simmer for 5 minutes.
#    Hindi: 4. स्कील में लहसुन का रस, मक्खन, और चीनी जोड़ें और 5 मिनट के लिए तैरें।
#    🔹 LaBSE Similarity: 0.9044
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8083
# --------------------------------------------------
# 🔹 Recipe 20
#    English: 5. Spread the mixture evenly over the bread slices.
#    Hindi: 5. मिश्रण को ब्रेड स्लाइड्स के ऊपर समान रूप से फैलाएं।
#    🔹 LaBSE Similarity: 0.8943
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7997
# --------------------------------------------------
# 🔹 Recipe 21
#    English: 6. Bake for 10 minutes, or until the bread is golden brown and the filling is cooked through.
#    Hindi: 6. 10 मिनट के लिए पकाएं, या जब तक कि रोटी सोने का काला हो और भरने के माध्यम से पकाया जाता है।
#    🔹 LaBSE Similarity: 0.9006
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8534
# --------------------------------------------------
# 🔹 Recipe 22
#    English: 7. Serve with a drizzle of strawberry glaze.
#    Hindi: 7. स्ट्रॉबेरी ग्लेज़ के एक ड्रिज़ल के साथ सेवा करें।
#    🔹 LaBSE Similarity: 0.9325
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.7933
# --------------------------------------------------
# 🔹 Recipe 23
#    English: **Tips:**
#    Hindi: * टिप्स : *
#    🔹 LaBSE Similarity: 0.9320
#    🔹 XLM-R Similarity: 0.9956
#    🔹 LASER Similarity: 0.9302
# --------------------------------------------------
# 🔹 Recipe 24
#    English: * For a richer bread, use high-quality bread.
#    Hindi: * एक अमीर रोटी के लिए, उच्च गुणवत्ता वाले रोटी का उपयोग करें।
#    🔹 LaBSE Similarity: 0.9186
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8867
# --------------------------------------------------
# 🔹 Recipe 25
#    English: * To make a gluten-free bread, use gluten-free flour.
#    Hindi: * ग्लूटेन-मुक्त रोटी बनाने के लिए, ग्लूटेन-मुक्त फूल का उपयोग करें।
#    🔹 LaBSE Similarity: 0.8671
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8563
# --------------------------------------------------
# 🔹 Recipe 26
#    English: * Serve with a side of your favorite dipping sauce, such as ranch dressing or pesto.
#    Hindi: * अपने पसंदीदा डाइपिंग सॉस के एक तरफ से सेवा करें, जैसे कि रैंच ड्रेसिंग या पेस्टो।
#    🔹 LaBSE Similarity: 0.9231
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8571
# --------------------------------------------------
# 🔹 Recipe 27
#    English: Recipe 2:
#    Hindi: रेसिपी 2 :
#    🔹 LaBSE Similarity: 0.9611
#    🔹 XLM-R Similarity: 0.9964
#    🔹 LASER Similarity: 0.8289
# --------------------------------------------------
# 🔹 Recipe 28
#    English: **Beef and Vegetable Stir-Fry with Sweet and Spicy Glaze**
#    Hindi: ** बीयर और सब्जियां मिठाई और चमकदार ग्लास के साथ ठंडा-फ्री**
#    🔹 LaBSE Similarity: 0.7657
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8908
# --------------------------------------------------
# 🔹 Recipe 29
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 30
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 चम्मच जैतून का तेल
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7149
# --------------------------------------------------
# 🔹 Recipe 31
#    English: * 1 pound beef, thinly sliced
#    Hindi: * 1 पाउंड अनाज, पतली पतली
#    🔹 LaBSE Similarity: 0.8777
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8335
# --------------------------------------------------
# 🔹 Recipe 32
#    English: * 1 tablespoon chopped onion, diced
#    Hindi: * 1 टैबलेट चॉपिंग ओनिओन, डाइक
#    🔹 LaBSE Similarity: 0.7146
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8363
# --------------------------------------------------
# 🔹 Recipe 33
#    English: * 1 tablespoon chopped carrots, diced
#    Hindi: * 1 टैबलेट चॉकलेट, ड्रिलिंग
#    🔹 LaBSE Similarity: 0.7661
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7761
# --------------------------------------------------
# 🔹 Recipe 34
#    English: * 1 tablespoon chopped chicken, diced
#    Hindi: * 1 चॉकलेट चॉकलेट चिकन, पकाया
#    🔹 LaBSE Similarity: 0.7917
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.7916
# --------------------------------------------------
# 🔹 Recipe 35
#    English: * 1 tablespoon chopped ground beef
#    Hindi: * 1 चम्मच चोपड़ा भूमि बीफ
#    🔹 LaBSE Similarity: 0.8145
#    🔹 XLM-R Similarity: 0.9983
#    🔹 LASER Similarity: 0.7700
# --------------------------------------------------
# 🔹 Recipe 36
#    English: * 1 tablespoon chopped spinach
#    Hindi: * 1 चम्मच चॉपिंग स्पाइन
#    🔹 LaBSE Similarity: 0.9037
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.7873
# --------------------------------------------------
# 🔹 Recipe 37
#    English: * 1 tablespoon chopped strawberries
#    Hindi: * 1 चम्मच चॉकलेट स्ट्रॉबेरी
#    🔹 LaBSE Similarity: 0.8365
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8114
# --------------------------------------------------
# 🔹 Recipe 38
#    English: * 1 tablespoon sugar
#    Hindi: * 1 टैबलेट शर्करा
#    🔹 LaBSE Similarity: 0.8420
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.7969
# --------------------------------------------------
# 🔹 Recipe 39
#    English: * 1 tablespoon soy sauce
#    Hindi: * 1 चम्मच सोया सॉस
#    🔹 LaBSE Similarity: 0.9723
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.7678
# --------------------------------------------------
# 🔹 Recipe 40
#    English: * 1 tablespoon honey
#    Hindi: * 1 चम्मच शहद
#    🔹 LaBSE Similarity: 0.9555
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7046
# --------------------------------------------------
# 🔹 Recipe 41
#    English: * 1 tablespoon sesame oil
#    Hindi: * 1 टैबलेट सीज़ैम तेल
#    🔹 LaBSE Similarity: 0.8938
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8353
# --------------------------------------------------
# 🔹 Recipe 42
#    English: * 1 tablespoon ground black pepper
#    Hindi: * 1 चम्मच भूमि काले पेपर
#    🔹 LaBSE Similarity: 0.8624
#    🔹 XLM-R Similarity: 0.9984
#    🔹 LASER Similarity: 0.7905
# --------------------------------------------------
# 🔹 Recipe 43
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 44
#    English: 1. Heat the olive oil in a large skillet or wok over medium-high heat.
#    Hindi: 1. एक बड़े स्केलिट में जैतून का तेल गर्म करें या मध्यम-उच्च गर्मी से ऊपर झुकें।
#    🔹 LaBSE Similarity: 0.9128
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8604
# --------------------------------------------------
# 🔹 Recipe 45
#    English: 2. Add the beef and cook until browned on all sides.
#    Hindi: 2. अनाज को जोड़ें और हर तरफ चमगादड़ तक पकाएं।
#    🔹 LaBSE Similarity: 0.8664
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7524
# --------------------------------------------------
# 🔹 Recipe 46
#    English: 3. Add the onion, carrots, and chicken to the skillet and cook until tender and slightly browned.
#    Hindi: 3. अनाज, मक्खन, और चिकन को स्कीलेट में जोड़ें और तब तक पकाएं जब तक कि तंग और थोड़ा चमकदार न हो।
#    🔹 LaBSE Similarity: 0.8609
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8773
# --------------------------------------------------
# 🔹 Recipe 47
#    English: 4. Add the ground beef, spinach, and strawberries to the skillet and cook until heated through.
#    Hindi: 4. मिट्टी के बीन्स, स्पाइना और मक्खन को स्कील में जोड़ें और गर्म होने तक पकाएं।
#    🔹 LaBSE Similarity: 0.8786
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8560
# --------------------------------------------------
# 🔹 Recipe 48
#    English: 5. In a small bowl, whisk together the sugar, soy sauce, honey, and sesame oil.
#    Hindi: 5. एक छोटे से बोतल में, शर्करा, सोया सॉस, शहद, और ससैम तेल को मिलाएं।
#    🔹 LaBSE Similarity: 0.9252
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8133
# --------------------------------------------------
# 🔹 Recipe 49
#    English: 6. Add the sauce to the skillet and cook until heated through.
#    Hindi: 6. सॉस को स्कीलेट में जोड़ें और गर्म होने तक पकाएं।
#    🔹 LaBSE Similarity: 0.9257
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7637
# --------------------------------------------------
# 🔹 Recipe 50
#    English: 7. Serve over rice and garnish with fresh cilantro.
#    Hindi: 7. चावल के ऊपर सेवा करें और ताजा सिलेंट्रो के साथ ग्रेनाइज़ करें।
#    🔹 LaBSE Similarity: 0.9125
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7897
# --------------------------------------------------
# 🔹 Recipe 51
#    English: Recipe 3:
#    Hindi: रेसिपी 3 :
#    🔹 LaBSE Similarity: 0.9601
#    🔹 XLM-R Similarity: 0.9966
#    🔹 LASER Similarity: 0.8271
# --------------------------------------------------
# 🔹 Recipe 52
#    English: **Beef and Green Bean Stuffed Sweet Potatoes**
#    Hindi: ** बीफ और ग्रीन बीन स्टुफेड मीठे आलू**
#    🔹 LaBSE Similarity: 0.9191
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8594
# --------------------------------------------------
# 🔹 Recipe 53
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 54
#    English: * 2 tablespoons of butter
#    Hindi: * 2 चम्मच मक्खन
#    🔹 LaBSE Similarity: 0.9344
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7760
# --------------------------------------------------
# 🔹 Recipe 55
#    English: * 1 large egg, beaten
#    Hindi: * 1 बड़ा अंडे, हिट
#    🔹 LaBSE Similarity: 0.9369
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8927
# --------------------------------------------------
# 🔹 Recipe 56
#    English: * 1/2 cup of chopped green beans
#    Hindi: * 1/2 कप चॉकलेट ग्रीन बीन्स
#    🔹 LaBSE Similarity: 0.8783
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.8230
# --------------------------------------------------
# 🔹 Recipe 57
#    English: * 1 pound of ground beef
#    Hindi: * 1 पाउंड भूमि गाय
#    🔹 LaBSE Similarity: 0.9098
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8414
# --------------------------------------------------
# 🔹 Recipe 58
#    English: * 1/2 cup of chopped mushrooms
#    Hindi: * 1/2 कप चॉकलेट मशरूम
#    🔹 LaBSE Similarity: 0.8489
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8478
# --------------------------------------------------
# 🔹 Recipe 59
#    English: * 1/4 cup of chopped onions
#    Hindi: * 1 / 4 कप चॉकलेट
#    🔹 LaBSE Similarity: 0.7715
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8104
# --------------------------------------------------
# 🔹 Recipe 60
#    English: * 1/4 cup of chopped spinach
#    Hindi: * 1/4 कप चॉपिंग स्पाइन
#    🔹 LaBSE Similarity: 0.9122
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.8698
# --------------------------------------------------
# 🔹 Recipe 61
#    English: * 1/4 cup of chopped strawberries
#    Hindi: * 1 / 4 कप चॉकलेट का रस
#    🔹 LaBSE Similarity: 0.8169
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8235
# --------------------------------------------------
# 🔹 Recipe 62
#    English: * 1/2 cup of heavy cream
#    Hindi: * 1/2 कप भारी क्रीम
#    🔹 LaBSE Similarity: 0.9548
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8561
# --------------------------------------------------
# 🔹 Recipe 63
#    English: * 1 tablespoon of chopped fresh parsley
#    Hindi: * 1 चम्मच चोपड़ा ताजा मक्खन
#    🔹 LaBSE Similarity: 0.8342
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7350
# --------------------------------------------------
# 🔹 Recipe 64
#    English: * Salt and pepper to taste
#    Hindi: * स्वाद के लिए नमक और पेपर
#    🔹 LaBSE Similarity: 0.8682
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7456
# --------------------------------------------------
# 🔹 Recipe 65
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 66
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
#    🔹 LaBSE Similarity: 0.9420
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8737
# --------------------------------------------------
# 🔹 Recipe 67
#    English: 2. In a large skillet over medium heat, melt the butter.
#    Hindi: 2. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में, मक्खन को मिलाएं।
#    🔹 LaBSE Similarity: 0.8788
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8114
# --------------------------------------------------
# 🔹 Recipe 68
#    English: 3. Add the egg and cook until cooked through.
#    Hindi: 3. अंडे को जोड़ें और पकाने तक पकाएं।
#    🔹 LaBSE Similarity: 0.9244
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7676
# --------------------------------------------------
# 🔹 Recipe 69
#    English: 4. Add the green beans, mushrooms, onions, and spinach to the skillet and cook until tender.
#    Hindi: 4. ग्रीन बीन्स, मशरूम, अनाज, और स्पाइना को स्कीलेट में जोड़ें और तंग तक पकाएं।
#    🔹 LaBSE Similarity: 0.8965
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8595
# --------------------------------------------------
# 🔹 Recipe 70
#    English: 5. Add the ground beef to the skillet and cook until browned.
#    Hindi: 5. मिट्टी के बीज को स्केलिट में जोड़ें और चमकने तक पकाएं।
#    🔹 LaBSE Similarity: 0.8337
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7821
# --------------------------------------------------
# 🔹 Recipe 71
#    English: 6. Add the heavy cream, parsley, salt, and pepper to the skillet and simmer for 5 minutes.
#    Hindi: 6. भारी क्रीम, मक्खन, नमक और पेपर को स्कीलेट में जोड़ें और 5 मिनट के लिए तैरें।
#    🔹 LaBSE Similarity: 0.8845
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8528
# --------------------------------------------------
# 🔹 Recipe 72
#    English: 7. Transfer the filling to a baking dish.
#    Hindi: 7. भंडार को एक पके हुए व्यंजन में स्थानांतरित करें।
#    🔹 LaBSE Similarity: 0.8353
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7356
# --------------------------------------------------
# 🔹 Recipe 73
#    English: 8. Top with the sweet potatoes and bake for 20 minutes, or until the potatoes are golden brown and the filling is heated through.
#    Hindi: 8. 20 मिनट के लिए मीठे आलू और बकरी के साथ ऊपर, या जब तक आलू सोने का काला हो जाता है और भरने के माध्यम से गर्म हो जाता है।
#    🔹 LaBSE Similarity: 0.8506
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8512
# --------------------------------------------------
# 🔹 Recipe 74
#    English: 9. Serve immediately.
#    Hindi: 9. तुरंत सेवा करें।
#    🔹 LaBSE Similarity: 0.9259
#    🔹 XLM-R Similarity: 0.9984
#    🔹 LASER Similarity: 0.9216
# --------------------------------------------------
# 🔹 Recipe 75
#    English: Recipe 4:
#    Hindi: रेसिपी 4 :
#    🔹 LaBSE Similarity: 0.9622
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.8229
# --------------------------------------------------
# 🔹 Recipe 76
#    English: **Blueberry Bread with Sweet Potato Filling**
#    Hindi: ** ब्लूबेरी रोटी के साथ मीठा आलू भरने**
#    🔹 LaBSE Similarity: 0.8932
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8342
# --------------------------------------------------
# 🔹 Recipe 77
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 78
#    English: * 1 loaf (1 pound) white bread, sliced into 1-inch thick slices
#    Hindi: * 1 लहसुन (1 पाउंड) सफेद रोटी, 1 इंच मोटी स्लाइड्स में स्लाइड
#    🔹 LaBSE Similarity: 0.9329
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8790
# --------------------------------------------------
# 🔹 Recipe 79
#    English: * 1 cup blueberries
#    Hindi: 1 कप ब्लूबेरी
#    🔹 LaBSE Similarity: 0.8514
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8119
# --------------------------------------------------
# 🔹 Recipe 80
#    English: * 1/2 cup sugar
#    Hindi: * 1/2 कप शर्करा
#    🔹 LaBSE Similarity: 0.9316
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.8536
# --------------------------------------------------
# 🔹 Recipe 81
#    English: * 1/4 teaspoon salt
#    Hindi: * 1/4 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9751
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.6727
# --------------------------------------------------
# 🔹 Recipe 82
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8915
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.7743
# --------------------------------------------------
# 🔹 Recipe 83
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 चम्मच जैतून का तेल
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7149
# --------------------------------------------------
# 🔹 Recipe 84
#    English: * 1/2 teaspoon vanilla extract
#    Hindi: * 1/2 चम्मच वेनिला निकालने
#    🔹 LaBSE Similarity: 0.9595
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7574
# --------------------------------------------------
# 🔹 Recipe 85
#    English: * 1/4 cup chopped onion
#    Hindi: * 1/4 कप चॉपिंग ओयोन
#    🔹 LaBSE Similarity: 0.8382
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.8723
# --------------------------------------------------
# 🔹 Recipe 86
#    English: * 1/2 cup chopped spinach
#    Hindi: * 1/2 कप चॉकलेट स्पाइन
#    🔹 LaBSE Similarity: 0.8339
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8248
# --------------------------------------------------
# 🔹 Recipe 87
#    English: * 1/4 cup chopped strawberries
#    Hindi: * 1 / 4 कप चॉकलेट मक्खन
#    🔹 LaBSE Similarity: 0.7866
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.8242
# --------------------------------------------------
# 🔹 Recipe 88
#    English: * 1/4 cup chocolate chips
#    Hindi: 1/4 कप चॉकलेट चिप्स
#    🔹 LaBSE Similarity: 0.9110
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.9043
# --------------------------------------------------
# 🔹 Recipe 89
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 90
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
#    🔹 LaBSE Similarity: 0.9420
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8737
# --------------------------------------------------
# 🔹 Recipe 91
#    English: 2. In a large bowl, combine the bread slices, blueberries, sugar, salt, and black pepper.
#    Hindi: 2. एक बड़े बोतल में, रोटी स्लाइड्स, ब्लूबेरी, चीनी, नमक और काले पेपर को जोड़ें।
#    🔹 LaBSE Similarity: 0.8778
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.8866
# --------------------------------------------------
# 🔹 Recipe 92
#    English: 3. In a separate bowl, whisk together the olive oil, vanilla extract, onion, spinach, and strawberries.
#    Hindi: 3. एक अलग बोतल में, जैतून का तेल, वेनिला निकालने, अनाज, स्पाइन, और मक्खन के साथ मिलाएं।
#    🔹 LaBSE Similarity: 0.8310
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8674
# --------------------------------------------------
# 🔹 Recipe 93
#    English: 4. Add the wet ingredients to the dry ingredients and stir until just combined. Do not overmix.
#    Hindi: 4. सूखे अवयवों में गीले अवयवों को जोड़ें और मिश्रित होने तक मिश्रण करें. अति मिश्रण न करें.
#    🔹 LaBSE Similarity: 0.9430
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.7909
# --------------------------------------------------
# 🔹 Recipe 94
#    English: 5. Pour the batter into a greased 9x13-inch baking dish.
#    Hindi: 5. बैटरी को एक गीला 9x13-इंच पाक व्यंजन में डालें।
#    🔹 LaBSE Similarity: 0.8559
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8701
# --------------------------------------------------
# 🔹 Recipe 95
#    English: 6. Bake for 30-35 minutes, or until the bread is golden brown and the filling is set.
#    Hindi: 6. 30-35 मिनट के लिए पकाएं, या जब तक रोटी सोने का काला नहीं है और भरने सेट किया जाता है।
#    🔹 LaBSE Similarity: 0.9122
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8681
# --------------------------------------------------
# 🔹 Recipe 96
#    English: 7. Serve warm with a scoop of vanilla ice cream or whipped cream.
#    Hindi: 7. वेनिला आइसक्रीम या गीला क्रीम के एक स्कोप के साथ गर्म करें।
#    🔹 LaBSE Similarity: 0.8658
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8356
# --------------------------------------------------
# 🔹 Recipe 97
#    English: Recipe 5:
#    Hindi: रेसिपी 5 :
#    🔹 LaBSE Similarity: 0.9628
#    🔹 XLM-R Similarity: 0.9959
#    🔹 LASER Similarity: 0.8283
# --------------------------------------------------
# 🔹 Recipe 98
#    English: **Chicken and Sweet Potato Hash with Chocolate Glaze**
#    Hindi: ** चॉकलेट ग्लास के साथ चिकन और मीठा आलू हैश**
#    🔹 LaBSE Similarity: 0.9125
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8491
# --------------------------------------------------
# 🔹 Recipe 99
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 100
#    English: * 1 loaf of bread, sliced into 1/2-inch thick slices
#    Hindi: * 1 कटोरा रोटी, 1/2 इंच मोटी स्लाइड्स में घुमाया
#    🔹 LaBSE Similarity: 0.9322
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8576
# --------------------------------------------------
# 🔹 Recipe 101
#    English: * 1/2 pound of chicken breast, cut into 1-inch cubes
#    Hindi: * 1/2 पाउंड चिकन स्तन, 1 इंच क्यूब में काट दिया
#    🔹 LaBSE Similarity: 0.9332
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8829
# --------------------------------------------------
# 🔹 Recipe 102
#    English: * 1/4 cup of grated cheese
#    Hindi: * 1/4 कप ग्रेड पनीर
#    🔹 LaBSE Similarity: 0.8897
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8009
# --------------------------------------------------
# 🔹 Recipe 103
#    English: * 1/4 cup of chopped chocolate
#    Hindi: * 1/4 कप चॉकलेट
#    🔹 LaBSE Similarity: 0.9337
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.8936
# --------------------------------------------------
# 🔹 Recipe 104
#    English: * 2 large eggs, beaten
#    Hindi: * 2 बड़े अंडे, हिट
#    🔹 LaBSE Similarity: 0.9423
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.9129
# --------------------------------------------------
# 🔹 Recipe 105
#    English: * 1/2 cup of chopped potato
#    Hindi: * 1/2 कप चूपित आलू
#    🔹 LaBSE Similarity: 0.9586
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8432
# --------------------------------------------------
# 🔹 Recipe 106
#    English: * 1/4 cup of chopped strawberries
#    Hindi: * 1 / 4 कप चॉकलेट का रस
#    🔹 LaBSE Similarity: 0.8169
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8235
# --------------------------------------------------
# 🔹 Recipe 107
#    English: * 1 tablespoon of sugar
#    Hindi: * 1 चम्मच शर्करा
#    🔹 LaBSE Similarity: 0.9211
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.6684
# --------------------------------------------------
# 🔹 Recipe 108
#    English: * 1 tablespoon of sweet potato, mashed and cooled
#    Hindi: * 1 चम्मच मीठा आलू, मसालेदार और ठंडा
#    🔹 LaBSE Similarity: 0.8818
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8264
# --------------------------------------------------
# 🔹 Recipe 109
#    English: * 1 tablespoon of melted chocolate
#    Hindi: * 1 चॉकलेट का मिश्रण
#    🔹 LaBSE Similarity: 0.8488
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.7822
# --------------------------------------------------
# 🔹 Recipe 110
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 111
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
#    🔹 LaBSE Similarity: 0.9420
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8737
# --------------------------------------------------
# 🔹 Recipe 112
#    English: 2. Toast the bread slices lightly on both sides until golden brown.
#    Hindi: 2. रोटी को धीरे-धीरे दोनों तरफ झुकाएं जब तक कि सोने का काला न हो जाए।
#    🔹 LaBSE Similarity: 0.8612
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7903
# --------------------------------------------------
# 🔹 Recipe 113
#    English: 3. In a large skillet over medium heat, cook the chicken for 5-7 minutes per side, or until cooked through.
#    Hindi: 3. मध्यम गर्मी पर एक बड़े स्कील में, चिकन को 5-7 मिनट के लिए पकाया जाता है, या जब तक कि इसे पकाया जाता है।
#    🔹 LaBSE Similarity: 0.9232
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.9133
# --------------------------------------------------
# 🔹 Recipe 114
#    English: 4. Add the cheese, chocolate, eggs, potato, and strawberries to a baking dish.
#    Hindi: 4. पनीर, चॉकलेट, अंडे, आलू और मक्खन को एक पके हुए व्यंजन में जोड़ें।
#    🔹 LaBSE Similarity: 0.8948
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.8594
# --------------------------------------------------
# 🔹 Recipe 115
#    English: 5. Pour the chicken over the topping.
#    Hindi: 5. चिकन को ऊपर की ओर डालें।
#    🔹 LaBSE Similarity: 0.8661
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7326
# --------------------------------------------------
# 🔹 Recipe 116
#    English: 6. Bake for 20-25 minutes, or until the chicken is cooked through and the vegetables are tender.
#    Hindi: 6. 20-25 मिनट के लिए पकाएं, या जब तक कि चिकन के माध्यम से पकाया जाता है और सब्जियां तंग हो जाती हैं।
#    🔹 LaBSE Similarity: 0.9103
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.9064
# --------------------------------------------------
# 🔹 Recipe 117
#    English: 7. Serve with a drizzle of chocolate glaze.
#    Hindi: 7. चॉकलेट ग्लास के एक ड्रिज़ल के साथ सेवा करें।
#    🔹 LaBSE Similarity: 0.8861
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8578
# --------------------------------------------------
# 🔹 Recipe 118
#    English: Recipe 6:
#    Hindi: नुस्खा 6 :
#    🔹 LaBSE Similarity: 0.9469
#    🔹 XLM-R Similarity: 0.9956
#    🔹 LASER Similarity: 0.8373
# --------------------------------------------------
# 🔹 Recipe 119
#    English: **Blueberry Chicken with Green Bean Mash**
#    Hindi: ** ग्रीन बीन मश के साथ ब्लूबेरी चिकन**
#    🔹 LaBSE Similarity: 0.9284
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8488
# --------------------------------------------------
# 🔹 Recipe 120
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 121
#    English: * 1 pound boneless, skinless chicken breasts, cut into 1-inch pieces
#    Hindi: * 1 पाउंड बेकार, त्वचाहीन चिकन स्तन, 1 इंच के टुकड़ों में कटौती
#    🔹 LaBSE Similarity: 0.9292
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8987
# --------------------------------------------------
# 🔹 Recipe 122
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 चम्मच जैतून का तेल
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7149
# --------------------------------------------------
# 🔹 Recipe 123
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9741
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.6611
# --------------------------------------------------
# 🔹 Recipe 124
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8915
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.7743
# --------------------------------------------------
# 🔹 Recipe 125
#    English: * 1 cup blueberries
#    Hindi: 1 कप ब्लूबेरी
#    🔹 LaBSE Similarity: 0.8514
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8119
# --------------------------------------------------
# 🔹 Recipe 126
#    English: * 1 tablespoon lemon juice
#    Hindi: * 1 चम्मच नींबू का रस
#    🔹 LaBSE Similarity: 0.9690
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.7029
# --------------------------------------------------
# 🔹 Recipe 127
#    English: * 1 tablespoon butter
#    Hindi: * 1 चम्मच मक्खन
#    🔹 LaBSE Similarity: 0.9362
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7650
# --------------------------------------------------
# 🔹 Recipe 128
#    English: * 1 tablespoon flour
#    Hindi: * 1 टैबलेट फूल
#    🔹 LaBSE Similarity: 0.7778
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.8142
# --------------------------------------------------
# 🔹 Recipe 129
#    English: * 1/2 cup green beans, trimmed and cut into 1-inch pieces
#    Hindi: * 1/2 कप ग्रीन बीन्स, कटौती और 1 इंच टुकड़ों में कटौती
#    🔹 LaBSE Similarity: 0.9462
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8896
# --------------------------------------------------
# 🔹 Recipe 130
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9741
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.6611
# --------------------------------------------------
# 🔹 Recipe 131
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8915
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.7743
# --------------------------------------------------
# 🔹 Recipe 132
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 133
#    English: 1. Preheat oven to 400 degrees F (200 degrees C).
#    Hindi: 1. ओवन 400 डिग्री एफ (200 डिग्री सेल्सियस) तक पूर्व गर्म करें।
#    🔹 LaBSE Similarity: 0.9659
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8384
# --------------------------------------------------
# 🔹 Recipe 134
#    English: 2. In a large skillet over medium heat, heat olive oil. Season chicken with salt and pepper. Cook chicken for 5 minutes per side, or until cooked through.
#    Hindi: 2. मध्यम गर्मी पर एक बड़े स्केलिट में, जैतून का तेल गर्म करें. नमक और पेपर के साथ मौसमी चिकन. चिकन को 5 मिनट के लिए पकाएं, या जब तक कि इसे पकाया न जाए।
#    🔹 LaBSE Similarity: 0.9181
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8974
# --------------------------------------------------
# 🔹 Recipe 135
#    English: 3. Transfer chicken to a baking dish. Top with blueberries, lemon juice, and butter.
#    Hindi: 3. चिकन को एक पके हुए व्यंजन में स्थानांतरित करें. ब्लूबेरी, नींबू का रस, और मक्खन के साथ शीर्ष।
#    🔹 LaBSE Similarity: 0.9067
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8762
# --------------------------------------------------
# 🔹 Recipe 136
#    English: 4. Bake for 20-25 minutes, or until the chicken is cooked through and the blueberries are tender.
#    Hindi: 4. 20-25 मिनट के लिए पकाएं, या जब तक कि चिकन के माध्यम से पकाया जाता है और ब्लूबेरी तंग हो जाते हैं।
#    🔹 LaBSE Similarity: 0.9101
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.9067
# --------------------------------------------------
# 🔹 Recipe 137
#    English: 5. Serve with green beans and mashed potatoes.
#    Hindi: 5. हरी बीन्स और मसालेदार आलू के साथ सेवा करें।
#    🔹 LaBSE Similarity: 0.8918
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8384
# --------------------------------------------------
# 🔹 Recipe 138
#    English: **Tips:**
#    Hindi: * टिप्स : *
#    🔹 LaBSE Similarity: 0.9320
#    🔹 XLM-R Similarity: 0.9956
#    🔹 LASER Similarity: 0.9302
# --------------------------------------------------
# 🔹 Recipe 139
#    English: * For a more flavorful dish, use a variety of different berries, such as raspberries or strawberries.
#    Hindi: * एक अधिक स्वादिष्ट व्यंजन के लिए, विभिन्न व्यंजनों की एक किस्म का उपयोग करें, जैसे कि मक्खन या मक्खन।
#    🔹 LaBSE Similarity: 0.8058
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8793
# --------------------------------------------------
# 🔹 Recipe 140
#    English: * Serve with a dipping sauce, such as a balsamic glaze or a honey mustard sauce.
#    Hindi: * एक डाइपिंग सॉस के साथ सेवा करें, जैसे कि एक बल्सैमिक ग्लास या एक मेनू मटार सॉस।
#    🔹 LaBSE Similarity: 0.8774
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8501
# --------------------------------------------------
# 🔹 Recipe 141
#    English: * Serve with a side of crusty bread to soak up the juices.
#    Hindi: * जूस को पकाने के लिए क्रस्टी रोटी के एक पक्ष के साथ सेवा करें।
#    🔹 LaBSE Similarity: 0.8643
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8208
# --------------------------------------------------
# 🔹 Recipe 142
#    English: Recipe 7:
#    Hindi: रेसिपी 7 :
#    🔹 LaBSE Similarity: 0.9629
#    🔹 XLM-R Similarity: 0.9958
#    🔹 LASER Similarity: 0.8171
# --------------------------------------------------
# 🔹 Recipe 143
#    English: **Chicken and Cheese Stuffed Corn with Heavy Cream Sauce**
#    Hindi: ** चिकन और पनीर भारी क्रीम सॉस के साथ कच्चे मक्खन**
#    🔹 LaBSE Similarity: 0.9059
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.8595
# --------------------------------------------------
# 🔹 Recipe 144
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 145
#    English: * 1 boneless, skinless chicken breast, cut into 1-inch cubes
#    Hindi: * 1 बेकार, त्वचाहीन चिकन स्तन, 1 इंच क्यूब में काट दिया
#    🔹 LaBSE Similarity: 0.9325
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8571
# --------------------------------------------------
# 🔹 Recipe 146
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 चम्मच जैतून का तेल
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7149
# --------------------------------------------------
# 🔹 Recipe 147
#    English: * 1 onion, diced
#    Hindi: * 1 ओनिओन, डाइक
#    🔹 LaBSE Similarity: 0.7786
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8600
# --------------------------------------------------
# 🔹 Recipe 148
#    English: * 2 cloves garlic, minced
#    Hindi: * 2 चम्मच ग्रीनहाउस, मिनी
#    🔹 LaBSE Similarity: 0.8157
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7538
# --------------------------------------------------
# 🔹 Recipe 149
#    English: * 1/2 teaspoon black pepper
#    Hindi: 1/2 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8024
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.7349
# --------------------------------------------------
# 🔹 Recipe 150
#    English: * 1/4 teaspoon salt
#    Hindi: * 1/4 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9751
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.6727
# --------------------------------------------------
# 🔹 Recipe 151
#    English: * 1/4 cup heavy cream
#    Hindi: * 1/4 कप भारी क्रीम
#    🔹 LaBSE Similarity: 0.9655
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8422
# --------------------------------------------------
# 🔹 Recipe 152
#    English: * 1/2 cup grated mozzarella cheese
#    Hindi: * 1/2 कप ग्रेड मोज़ेरेला पनीर
#    🔹 LaBSE Similarity: 0.9032
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.8310
# --------------------------------------------------
# 🔹 Recipe 153
#    English: * 1/2 cup chopped fresh corn
#    Hindi: * 1/2 कप चॉकलेट ताजा मक्खन
#    🔹 LaBSE Similarity: 0.8223
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.8599
# --------------------------------------------------
# 🔹 Recipe 154
#    English: * 1/2 cup chopped mushrooms
#    Hindi: * 1/2 कप चॉकलेट चॉकलेट
#    🔹 LaBSE Similarity: 0.7550
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.7880
# --------------------------------------------------
# 🔹 Recipe 155
#    English: * 1/2 teaspoon dried oregano
#    Hindi: * 1/2 चम्मच सूखे ओरेगानो
#    🔹 LaBSE Similarity: 0.9539
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.7805
# --------------------------------------------------
# 🔹 Recipe 156
#    English: * 1/4 teaspoon salt
#    Hindi: * 1/4 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9751
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.6727
# --------------------------------------------------
# 🔹 Recipe 157
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8915
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.7743
# --------------------------------------------------
# 🔹 Recipe 158
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 159
#    English: 1. Heat olive oil in a large skillet over medium heat.
#    Hindi: 1. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में तेल गर्म करें।
#    🔹 LaBSE Similarity: 0.9168
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7720
# --------------------------------------------------
# 🔹 Recipe 160
#    English: 2. Season chicken with black pepper and salt.
#    Hindi: 2. काले पेपर और नमक के साथ मौसम चिकन।
#    🔹 LaBSE Similarity: 0.8619
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.8582
# --------------------------------------------------
# 🔹 Recipe 161
#    English: 3. Add chicken to the skillet and cook until browned on all sides.
#    Hindi: 3. चिकन को स्केलिट में जोड़ें और सभी पक्षों पर चमकने तक पकाएं।
#    🔹 LaBSE Similarity: 0.9096
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8360
# --------------------------------------------------
# 🔹 Recipe 162
#    English: 4. Add onion and garlic to the skillet and cook until softened, about 5 minutes.
#    Hindi: 4. स्केलिट में अनाज और मक्खन जोड़ें और लगभग 5 मिनट के लिए नरम होने तक पकाएं।
#    🔹 LaBSE Similarity: 0.8504
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7919
# --------------------------------------------------
# 🔹 Recipe 163
#    English: 5. Add mushrooms and potato to the skillet and cook until tender, about 10 minutes.
#    Hindi: 5. मूंगफली और आलू को स्कीलेट में जोड़ें और लगभग 10 मिनट तक पकाएं।
#    🔹 LaBSE Similarity: 0.9127
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8377
# --------------------------------------------------
# 🔹 Recipe 164
#    English: 6. Add heavy cream, mozzarella cheese, and oregano to the skillet.
#    Hindi: 6. भारी क्रीम, मोज़ेरेला पनीर और ओरेगानो को स्कीलेट में जोड़ें।
#    🔹 LaBSE Similarity: 0.9261
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7905
# --------------------------------------------------
# 🔹 Recipe 165
#    English: 7. Bring to a simmer and cook for 5 minutes, or until the cheese is melted and bubbly.
#    Hindi: 7. एक स्विमर में लाएं और 5 मिनट के लिए पकाएं, या जब तक कि पनीर मिट जाए और ब्लेड हो जाए।
#    🔹 LaBSE Similarity: 0.8923
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8442
# --------------------------------------------------
# 🔹 Recipe 166
#    English: 8. Serve over a bed of roasted corn.
#    Hindi: 8. एक बिस्तर पर चमकदार मक्खन का सेवन करें।
#    🔹 LaBSE Similarity: 0.7732
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.7777
# --------------------------------------------------
# 🔹 Recipe 167
#    English: Recipe 8:
#    Hindi: रेसिपी 8 :
#    🔹 LaBSE Similarity: 0.9566
#    🔹 XLM-R Similarity: 0.9963
#    🔹 LASER Similarity: 0.8295
# --------------------------------------------------
# 🔹 Recipe 168
#    English: **Chicken and Sweet Potato Hash with Green Beans**
#    Hindi: ** चिकन और मीठे आलू हश ग्रीन बीन्स के साथ**
#    🔹 LaBSE Similarity: 0.9121
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8745
# --------------------------------------------------
# 🔹 Recipe 169
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 170
#    English: * 1 loaf of bread, sliced into 1/2-inch thick slices
#    Hindi: * 1 कटोरा रोटी, 1/2 इंच मोटी स्लाइड्स में घुमाया
#    🔹 LaBSE Similarity: 0.9322
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8576
# --------------------------------------------------
# 🔹 Recipe 171
#    English: * 1/4 cup of butter
#    Hindi: * 1/4 कप मक्खन
#    🔹 LaBSE Similarity: 0.9444
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8827
# --------------------------------------------------
# 🔹 Recipe 172
#    English: * 1/2 pound of chicken_breast, cut into 1-inch pieces
#    Hindi: * 1/2 पाउंड चिकन_ब्रेस्ट, 1 इंच टुकड़ों में काट दिया
#    🔹 LaBSE Similarity: 0.9401
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.9039
# --------------------------------------------------
# 🔹 Recipe 173
#    English: * 1/4 cup of green_beans, trimmed and cut into 1/2-inch pieces
#    Hindi: * 1/4 कप ग्रीन_बेन, कटौती और 1/2 इंच टुकड़ों में कटौती
#    🔹 LaBSE Similarity: 0.9448
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.8917
# --------------------------------------------------
# 🔹 Recipe 174
#    English: * 1/4 cup of chopped strawberries
#    Hindi: * 1 / 4 कप चॉकलेट का रस
#    🔹 LaBSE Similarity: 0.8169
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8235
# --------------------------------------------------
# 🔹 Recipe 175
#    English: * 1/4 cup of chopped sweet_potato, diced
#    Hindi: * 1/4 कप चूपित मिठाई - आलू, पकाया
#    🔹 LaBSE Similarity: 0.9158
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8265
# --------------------------------------------------
# 🔹 Recipe 176
#    English: * 1/4 cup of flour
#    Hindi: * 1 / 4 कप फूल
#    🔹 LaBSE Similarity: 0.8550
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8971
# --------------------------------------------------
# 🔹 Recipe 177
#    English: * 1/2 teaspoon of salt
#    Hindi: * 1/2 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9709
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.6517
# --------------------------------------------------
# 🔹 Recipe 178
#    English: * 1/4 teaspoon of black pepper
#    Hindi: * 1/4 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8909
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7620
# --------------------------------------------------
# 🔹 Recipe 179
#    English: * 1/4 cup of milk
#    Hindi: * 1/4 कप दूध
#    🔹 LaBSE Similarity: 0.9617
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.9463
# --------------------------------------------------
# 🔹 Recipe 180
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 181
#    English: 1. Preheat oven to 375 degrees F (190 degrees C).
#    Hindi: 1. ओवन को 375 डिग्री एफ (190 डिग्री सी) तक गर्म करें।
#    🔹 LaBSE Similarity: 0.9420
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8737
# --------------------------------------------------
# 🔹 Recipe 182
#    English: 2. In a large skillet over medium heat, melt the butter.
#    Hindi: 2. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में, मक्खन को मिलाएं।
#    🔹 LaBSE Similarity: 0.8788
#    🔹 XLM-R Similarity: 0.9973
#    🔹 LASER Similarity: 0.8114
# --------------------------------------------------
# 🔹 Recipe 183
#    English: 3. Add the chicken and cook until browned on all sides.
#    Hindi: 3. चिकन जोड़ें और सभी पक्षों पर चमगादड़ तक पकाएं।
#    🔹 LaBSE Similarity: 0.9150
#    🔹 XLM-R Similarity: 0.9972
#    🔹 LASER Similarity: 0.8078
# --------------------------------------------------
# 🔹 Recipe 184
#    English: 4. Add the green beans and cook until tender and slightly crisp.
# ...
#    Hindi: **Blueberry-Cheese-Green Bean Hash के साथ आलू और स्पंज**
#    🔹 LaBSE Similarity: 0.9440
#    🔹 XLM-R Similarity: 0.9984
#    🔹 LASER Similarity: 0.9207
# --------------------------------------------------
# 🔹 Recipe 401
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 402
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 चम्मच जैतून का तेल
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7149
# --------------------------------------------------
# 🔹 Recipe 403
#    English: * 1 onion, diced
#    Hindi: * 1 ओनिओन, डाइक
#    🔹 LaBSE Similarity: 0.7786
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8600
# --------------------------------------------------
# 🔹 Recipe 404
#    English: * 1 green bean, diced
#    Hindi: * 1 ग्रीन बीन, डाइक
#    🔹 LaBSE Similarity: 0.8937
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.8682
# --------------------------------------------------
# 🔹 Recipe 405
#    English: * 4 eggs, beaten
#    Hindi: * 4 अंडे, हिट
#    🔹 LaBSE Similarity: 0.9449
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.8892
# --------------------------------------------------
# 🔹 Recipe 406
#    English: * 1/2 cup shredded cheese
#    Hindi: * 1/2 चम्मच पकाया पनीर
#    🔹 LaBSE Similarity: 0.9372
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.7679
# --------------------------------------------------
# 🔹 Recipe 407
#    English: * 1/4 cup chopped blueberries
#    Hindi: * 1/4 कप चॉपिंग ब्लूबेरी
#    🔹 LaBSE Similarity: 0.9266
#    🔹 XLM-R Similarity: 0.9983
#    🔹 LASER Similarity: 0.8851
# --------------------------------------------------
# 🔹 Recipe 408
#    English: * 1 tablespoon lime juice
#    Hindi: * 1 चम्मच लहसुन का रस
#    🔹 LaBSE Similarity: 0.9164
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.6937
# --------------------------------------------------
# 🔹 Recipe 409
#    English: * 1 tablespoon chopped fresh parsley
#    Hindi: * 1 चॉकलेट चॉकलेट ताजा पेंसिल
#    🔹 LaBSE Similarity: 0.7592
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.7373
# --------------------------------------------------
# 🔹 Recipe 410
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9741
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.6611
# --------------------------------------------------
# 🔹 Recipe 411
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8915
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.7743
# --------------------------------------------------
# 🔹 Recipe 412
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 413
#    English: 1. Heat olive oil in a large skillet over medium heat.
#    Hindi: 1. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में तेल गर्म करें।
#    🔹 LaBSE Similarity: 0.9168
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7720
# --------------------------------------------------
# 🔹 Recipe 414
#    English: 2. Add onion and green bean and cook until tender, about 5 minutes.
#    Hindi: 2. अनाज और हरी बीन्स जोड़ें और पनीर तक पकाएं, लगभग 5 मिनट।
#    🔹 LaBSE Similarity: 0.8986
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8215
# --------------------------------------------------
# 🔹 Recipe 415
#    English: 3. Add eggs and cook until sunny-side up.
#    Hindi: 3. अंडे जोड़ें और सूरज के पक्ष तक पकाएं।
#    🔹 LaBSE Similarity: 0.9037
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7677
# --------------------------------------------------
# 🔹 Recipe 416
#    English: 4. Add cheese, blueberries, lime juice, parsley, salt, and pepper to the skillet.
#    Hindi: 4. पनीर, ब्लूबेरी, लहसुन का रस, मक्खन, नमक और पेपर को स्केलिट में जोड़ें।
#    🔹 LaBSE Similarity: 0.8961
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.8503
# --------------------------------------------------
# 🔹 Recipe 417
#    English: 5. Cook for 5 minutes, or until the potatoes are tender and the sauce is heated through.
#    Hindi: 5. 5 मिनट के लिए पकाएं, या जब तक कि आलू तंग न हो जाएं और सॉस गर्म हो जाए।
#    🔹 LaBSE Similarity: 0.9021
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8270
# --------------------------------------------------
# 🔹 Recipe 418
#    English: 6. Serve immediately.
#    Hindi: 6. तुरंत सेवा करें।
#    🔹 LaBSE Similarity: 0.9249
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.9121
# --------------------------------------------------
# 🔹 Recipe 419
#    English: Recipe 19:
#    Hindi: अनुच्छेद 19:
#    🔹 LaBSE Similarity: 0.7795
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.7616
# --------------------------------------------------
# 🔹 Recipe 420
#    English: **Blueberry-Cheese-Green Bean Hash with Potato and Spinach**
#    Hindi: **Blueberry-Cheese-Green Bean Hash के साथ आलू और स्पंज**
#    🔹 LaBSE Similarity: 0.9440
#    🔹 XLM-R Similarity: 0.9984
#    🔹 LASER Similarity: 0.9207
# --------------------------------------------------
# 🔹 Recipe 421
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 422
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 चम्मच जैतून का तेल
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7149
# --------------------------------------------------
# 🔹 Recipe 423
#    English: * 1 onion, diced
#    Hindi: * 1 ओनिओन, डाइक
#    🔹 LaBSE Similarity: 0.7786
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8600
# --------------------------------------------------
# 🔹 Recipe 424
#    English: * 1 green bean, diced
#    Hindi: * 1 ग्रीन बीन, डाइक
#    🔹 LaBSE Similarity: 0.8937
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.8682
# --------------------------------------------------
# 🔹 Recipe 425
#    English: * 1/2 pound potatoes, diced
#    Hindi: * 1/2 पाउंड आलू, पकाया
#    🔹 LaBSE Similarity: 0.9455
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8426
# --------------------------------------------------
# 🔹 Recipe 426
#    English: * 1/2 pound fresh spinach
#    Hindi: * 1 पाउंड ताजा स्पंज
#    🔹 LaBSE Similarity: 0.8668
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8515
# --------------------------------------------------
# 🔹 Recipe 427
#    English: * 1/4 cup grated mozzarella cheese
#    Hindi: * 1/4 कप ग्रेड मोज़ेरेला पनीर
#    🔹 LaBSE Similarity: 0.9103
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.8375
# --------------------------------------------------
# 🔹 Recipe 428
#    English: * 2 large eggs
#    Hindi: * 2 बड़े अंडे
#    🔹 LaBSE Similarity: 0.9840
#    🔹 XLM-R Similarity: 0.9985
#    🔹 LASER Similarity: 0.9443
# --------------------------------------------------
# 🔹 Recipe 429
#    English: * 1 tablespoon lime juice
#    Hindi: * 1 चम्मच लहसुन का रस
#    🔹 LaBSE Similarity: 0.9164
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.6937
# --------------------------------------------------
# 🔹 Recipe 430
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 चम्मच जैतून का तेल
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7149
# --------------------------------------------------
# 🔹 Recipe 431
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9741
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.6611
# --------------------------------------------------
# 🔹 Recipe 432
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8915
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.7743
# --------------------------------------------------
# 🔹 Recipe 433
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 434
#    English: 1. Heat olive oil in a large skillet over medium heat.
#    Hindi: 1. मध्यम गर्मी के ऊपर एक बड़े स्केलिट में तेल गर्म करें।
#    🔹 LaBSE Similarity: 0.9168
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7720
# --------------------------------------------------
# 🔹 Recipe 435
#    English: 2. Add onion and green bean and cook until tender, about 5 minutes.
#    Hindi: 2. अनाज और हरी बीन्स जोड़ें और पनीर तक पकाएं, लगभग 5 मिनट।
#    🔹 LaBSE Similarity: 0.8986
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8215
# --------------------------------------------------
# 🔹 Recipe 436
#    English: 3. Add potatoes and spinach to the skillet and cook until tender, about 10 minutes.
#    Hindi: 3. आलू और स्पाइना को स्कीलेट में जोड़ें और लगभग 10 मिनट तक पकाएं।
#    🔹 LaBSE Similarity: 0.9144
#    🔹 XLM-R Similarity: 0.9975
#    🔹 LASER Similarity: 0.8129
# --------------------------------------------------
# 🔹 Recipe 437
#    English: 4. Add eggs and lime juice to the skillet and cook until the eggs are cooked through.
#    Hindi: 4. अंडे और लहसुन का रस स्कीलेट में जोड़ें और तब तक पकाएं जब तक कि अंडे के माध्यम से पकाया नहीं जाता है।
#    🔹 LaBSE Similarity: 0.8944
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.7919
# --------------------------------------------------
# 🔹 Recipe 438
#    English: 5. Season with salt and pepper to taste.
#    Hindi: 5. स्वाद के लिए नमक और पेपर के साथ मौसम।
#    🔹 LaBSE Similarity: 0.8768
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7563
# --------------------------------------------------
# 🔹 Recipe 439
#    English: 6. Serve immediately with cheese on top.
#    Hindi: 6. तुरंत शीर्ष पर पनीर के साथ सेवा करें।
#    🔹 LaBSE Similarity: 0.9195
#    🔹 XLM-R Similarity: 0.9970
#    🔹 LASER Similarity: 0.7897
# --------------------------------------------------
# 🔹 Recipe 440
#    English: Recipe 20:
#    Hindi: रेसिपी 20:
#    🔹 LaBSE Similarity: 0.9587
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8463
# --------------------------------------------------
# 🔹 Recipe 441
#    English: **Blueberry Chicken with Green Bean Mash**
#    Hindi: ** ग्रीन बीन मश के साथ ब्लूबेरी चिकन**
#    🔹 LaBSE Similarity: 0.9284
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8488
# --------------------------------------------------
# 🔹 Recipe 442
#    English: **Ingredients:**
#    Hindi: * सामग्री : *
#    🔹 LaBSE Similarity: 0.8864
#    🔹 XLM-R Similarity: 0.9951
#    🔹 LASER Similarity: 0.8545
# --------------------------------------------------
# 🔹 Recipe 443
#    English: * 1 boneless, skinless chicken breast, cut into 4 equal pieces
#    Hindi: * 1 गंदे, त्वचाहीन चिकन स्तन, 4 समान टुकड़ों में काट दिया
#    🔹 LaBSE Similarity: 0.9317
#    🔹 XLM-R Similarity: 0.9987
#    🔹 LASER Similarity: 0.8930
# --------------------------------------------------
# 🔹 Recipe 444
#    English: * 1 tablespoon olive oil
#    Hindi: * 1 चम्मच जैतून का तेल
#    🔹 LaBSE Similarity: 0.9518
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.7149
# --------------------------------------------------
# 🔹 Recipe 445
#    English: * 1/2 onion, diced
#    Hindi: * 1/2 ओनिओन, ड्रिल
#    🔹 LaBSE Similarity: 0.8401
#    🔹 XLM-R Similarity: 0.9982
#    🔹 LASER Similarity: 0.8234
# --------------------------------------------------
# 🔹 Recipe 446
#    English: * 1/4 green bean, trimmed and cut into 1-inch pieces
#    Hindi: * 1/4 ग्रीन बीन, काट दिया और 1 इंच के टुकड़ों में काट दिया
#    🔹 LaBSE Similarity: 0.9382
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.8980
# --------------------------------------------------
# 🔹 Recipe 447
#    English: * 1/4 cup fresh spinach
#    Hindi: * 1/4 कप ताजा स्पंज
#    🔹 LaBSE Similarity: 0.9480
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.9181
# --------------------------------------------------
# 🔹 Recipe 448
#    English: * 1/4 cup grated mozzarella cheese
#    Hindi: * 1/4 कप ग्रेड मोज़ेरेला पनीर
#    🔹 LaBSE Similarity: 0.9103
#    🔹 XLM-R Similarity: 0.9969
#    🔹 LASER Similarity: 0.8375
# --------------------------------------------------
# 🔹 Recipe 449
#    English: * 2 large eggs, beaten
#    Hindi: * 2 बड़े अंडे, हिट
#    🔹 LaBSE Similarity: 0.9423
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.9129
# --------------------------------------------------
# 🔹 Recipe 450
#    English: * 1 tablespoon lime juice
#    Hindi: * 1 चम्मच लहसुन का रस
#    🔹 LaBSE Similarity: 0.9164
#    🔹 XLM-R Similarity: 0.9979
#    🔹 LASER Similarity: 0.6937
# --------------------------------------------------
# 🔹 Recipe 451
#    English: * 1 tablespoon flour
#    Hindi: * 1 टैबलेट फूल
#    🔹 LaBSE Similarity: 0.7778
#    🔹 XLM-R Similarity: 0.9968
#    🔹 LASER Similarity: 0.8142
# --------------------------------------------------
# 🔹 Recipe 452
#    English: * 1/2 teaspoon salt
#    Hindi: * 1/2 चम्मच नमक
#    🔹 LaBSE Similarity: 0.9741
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.6611
# --------------------------------------------------
# 🔹 Recipe 453
#    English: * 1/4 teaspoon black pepper
#    Hindi: * 1/4 चम्मच काले पेपर
#    🔹 LaBSE Similarity: 0.8915
#    🔹 XLM-R Similarity: 0.9986
#    🔹 LASER Similarity: 0.7743
# --------------------------------------------------
# 🔹 Recipe 454
#    English: **Instructions:**
#    Hindi: * निर्देशों के लिए: *
#    🔹 LaBSE Similarity: 0.8500
#    🔹 XLM-R Similarity: 0.9960
#    🔹 LASER Similarity: 0.8586
# --------------------------------------------------
# 🔹 Recipe 455
#    English: 1. Heat olive oil in a large skillet or Dutch oven over medium heat.
#    Hindi: 1. मध्यम गर्मी पर एक बड़े स्केलिट या नीदरलैंड ओवन में जैतून का तेल गर्म करें।
#    🔹 LaBSE Similarity: 0.9167
#    🔹 XLM-R Similarity: 0.9974
#    🔹 LASER Similarity: 0.8023
# --------------------------------------------------
# 🔹 Recipe 456
#    English: 2. Season chicken with salt and pepper.
#    Hindi: 2. मौसम चिकन नमक और पेपर के साथ।
#    🔹 LaBSE Similarity: 0.8625
#    🔹 XLM-R Similarity: 0.9983
#    🔹 LASER Similarity: 0.8565
# --------------------------------------------------
# 🔹 Recipe 457
#    English: 3. Add chicken to the skillet and cook for 5-7 minutes per side, or until cooked through.
#    Hindi: 3. चिकन को स्कीलेट में जोड़ें और 5-7 मिनट के लिए पकाएं, या जब तक यह पकाया नहीं जाता है।
#    🔹 LaBSE Similarity: 0.8956
#    🔹 XLM-R Similarity: 0.9976
#    🔹 LASER Similarity: 0.8696
# --------------------------------------------------
# 🔹 Recipe 458
#    English: 4. Remove chicken from the skillet and set aside.
#    Hindi: 4. चिकन को स्केलिट से हटा दें और इसे एक तरफ रखें।
#    🔹 LaBSE Similarity: 0.9100
#    🔹 XLM-R Similarity: 0.9967
#    🔹 LASER Similarity: 0.8275
# --------------------------------------------------
# 🔹 Recipe 459
#    English: 5. Add onion and green bean to the skillet and cook until tender, about 5 minutes.
#    Hindi: 5. स्केलिट में अनाज और हरे बीन जोड़ें और लगभग 5 मिनट तक पकाएं।
#    🔹 LaBSE Similarity: 0.9048
#    🔹 XLM-R Similarity: 0.9977
#    🔹 LASER Similarity: 0.8117
# --------------------------------------------------
# 🔹 Recipe 460
#    English: 6. Add spinach and cook until wilted, about 2 minutes.
#    Hindi: 6. स्पंज जोड़ें और लगभग 2 मिनट तक उबालने तक पकाएं।
#    🔹 LaBSE Similarity: 0.9021
#    🔹 XLM-R Similarity: 0.9978
#    🔹 LASER Similarity: 0.7730
# --------------------------------------------------
# 🔹 Recipe 461
#    English: 7. Add mozzarella cheese, eggs, lime juice, flour, and salt and pepper to the skillet.
#    Hindi: 7. मोज़ेरेला पनीर, अंडे, लहसुन का रस, फूल, और नमक और पेपर को स्कीलेट में जोड़ें।
#    🔹 LaBSE Similarity: 0.9113
#    🔹 XLM-R Similarity: 0.9980
#    🔹 LASER Similarity: 0.8551
# --------------------------------------------------
# 🔹 Recipe 462
#    English: 8. Cook for 5 minutes, or until heated through.
#    Hindi: 8. 5 मिनट के लिए पकाएं, या गर्म होने तक।
#    🔹 LaBSE Similarity: 0.8955
#    🔹 XLM-R Similarity: 0.9971
#    🔹 LASER Similarity: 0.8023
# --------------------------------------------------
# 🔹 Recipe 463
#    English: 9. Serve chicken over green bean mash.
#    Hindi: 9. ग्रीन बीन मश पर चिकन सेवा करें।
#    🔹 LaBSE Similarity: 0.8971
#    🔹 XLM-R Similarity: 0.9981
#    🔹 LASER Similarity: 0.8010
# --------------------------------------------------
#
# ✅ Average Similarity Scores:
#    🔹 LaBSE: 0.8957
#    🔹 XLM-R: 0.9973
#    🔹 LASER: 0.8241
